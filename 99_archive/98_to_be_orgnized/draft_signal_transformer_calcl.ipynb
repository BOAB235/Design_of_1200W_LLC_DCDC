# %%
from math import *
from handcalcs  import render

# %%
# %%render
# D=9 # mm +/-
# H=4 # mm +/-
# dD = 2 # mm +/-
# S= H*dD*1e-6# m2
# L= 1e-3*pi*(D-dD/2)/2 #m
# Bs=0.3 #hypothesis
# R=0.007 # Ohm
# Id=15 # A
# F= 60e3 # Hz
# dV = Id * R # V
# N= 5
# Flux = dV*(0.5/F)/N
# B = Flux /S
# ratio = 100*B/Bs # \%
# Out:
# \[
# \begin{aligned}
# D &= 9 \; \;\textrm{(mm +/-)}
# \\[10pt]
# H &= 4 \; \;\textrm{(mm +/-)}
# \\[10pt]
# \mathrm{dD} &= 2 \; \;\textrm{(mm +/-)}
# \\[10pt]
# S &= H \cdot \mathrm{dD} \cdot 1 \times 10 ^ {-6}  = 4 \cdot 2 \cdot 1 \times 10 ^ {-6} &= 0.000 \; \;\textrm{(m2)}
# \\[10pt]
# L &= 1 \times 10 ^ {-3} \cdot \pi \cdot \frac{ D - \frac{ \mathrm{dD} }{ 2 } }{ 2 }  = 1 \times 10 ^ {-3} \cdot 3.142 \cdot \frac{ 9 - \frac{ 2 }{ 2 } }{ 2 } &= 0.013 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Bs} &= 0.300 \; \;\textrm{(hypothesis)}
# \\[10pt]
# R &= 0.007 \; \;\textrm{(Ohm)}
# \\[10pt]
# \mathrm{Id} &= 15 \; \;\textrm{(A)}
# \\[10pt]
# F &= 60000.000 \; \;\textrm{(Hz)}
# \\[10pt]
# \mathrm{dV} &= \mathrm{Id} \cdot R  = 15 \cdot 0.007 &= 0.105 \; \;\textrm{(V)}
# \\[10pt]
# N &= 5 \;
# \\[10pt]
# \mathrm{Flux} &= \mathrm{dV} \cdot \frac{ \frac{ 0.5 }{ F } }{ N }  = 0.105 \cdot \frac{ \frac{ 0.5 }{ 60000.000 } }{ 5 } &= 0.000
# \\[10pt]
# ...
