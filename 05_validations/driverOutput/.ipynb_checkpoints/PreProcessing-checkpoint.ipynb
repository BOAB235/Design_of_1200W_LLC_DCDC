# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "2026-02-14_14-09-33-703.csv"
df=pd.read_csv(path)
t= df.time.values
vds=df.CH1.values

# %%
plt.plot(t, vds)

# %%
plt.plot(t, vds)
plt.ylim([-50,10])
# Out:
# (-50.0, 10.0)
