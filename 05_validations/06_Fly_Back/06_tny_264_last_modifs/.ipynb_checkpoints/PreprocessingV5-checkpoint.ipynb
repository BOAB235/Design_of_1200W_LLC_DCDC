# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df0= pd.read_csv('2026-01-06_17-17-57-819.csv')
df0.plot(x='time', y=['CH1','CH2','CH4'])
vals0={}
for c in ['CH1','CH2','CH4']: 
    vals0[c]=df0[c].mean() 
vals0
# Out:
# {'CH1': np.float64(-36.7106609375),
#  'CH2': np.float64(-0.40513034375),
#  'CH4': np.float64(-3.705905625)}

# %%
list_ = """351.2V
2026-01-06_17-43-30-844
377.5v
2026-01-06_17-45-21-093
401.9v
2026-01-06_17-46-24-611
427.4v
2026-01-06_17-48-22-544""".split("\n")
voltages = list_[::2][::-1]
files = list_[1::2][::-1]

# %%
from utils import *
trigger
# Out:
# <function utils.trigger(sig, thresh=None, transition='rise', marginI=20)>

# %%
import sklearn

# %%
fig , axs = plt.subplots(1,1, figsize=(12,7))
#axs = axs .flatten()
k=0
for vol, f in zip(voltages, files): 
    f=f+".csv"
    df= pd.read_csv(f)
    Vds= df.CH1.values-vals0["CH1"]
    Vs= df.CH4.values-vals0["CH4"]
    Is= df.CH2.values-vals0["CH2"]
    Is=Is-Is[:1000].mean()
    i= trigger(Vds, thresh=200, transition='fall')[0]+40
    j= trigger(Vds, thresh=200, transition='rise')[0]-60
    
    vds = Vds[i:j]
    t = time[i:j]
    m= sklearn.linear_model.LinearRegression()
    Rds =40
    m.fit(t.reshape((-1,1)),vds/Rds)
    ic=m.predict(t.reshape((-1,1)))
    iest=vds/Rds
    dt = t[-1]-t[0]
    di = ic[-1]-ic[0]
    V0= float(vol.lower().replace("v", ""))
    # v = L di/dt
    Lm= V0/(di/dt)
    
    axs.plot(t,iest-ic[0], label = f"Vin = {vol}", c=f"C{k}", alpha = 0.5)
    axs.plot(t,ic-ic[0], label =f'deltaI={1e3*(ic.max()-ic.min()):0.0f}mA  Lm= {Lm:0.0f}uH',
             linestyle= "--", linewidth=2)
    
    



    print(vol,f'{1e3*(ic.max()-ic.min()):0.0f}mA  Lm= {Lm:0.0f}uH')


    k=k+1

    
axs.legend()
# Out:
# 427.4v 366mA  Lm= 547uH
# 401.9v 373mA  Lm= 522uH
# 377.5v 356mA  Lm= 536uH
# 351.2V 295mA  Lm= 626uH

# %%
# Out:
# np.float64(625.6701157979318)

# %%
fig , axs = plt.subplots(2,3, figsize=(12,7))
axs = axs .flatten()
k=0
for vol, f in zip(voltages, files): 
    f=f+".csv"
    df= pd.read_csv(f)
    Vds= df.CH1.values-vals0["CH1"]
    Vs= df.CH4.values-vals0["CH4"]
    Is= df.CH2.values-vals0["CH2"]
    Is=Is-Is[:1000].mean()
    time = df.time.values*1e6
    axs[2].plot(time, Vds, label = f"Vin = {vol}")
    V0= float(vol.lower().replace("v" ,""))
    axs[1].plot(time,V0- Vds, label = f"Vin = {vol}")
    axs[0].plot(time, Vs, label = f"Vin = {vol}")
    axs[3].plot(time, Is, label = f"Vin = {vol}")




    i= trigger(Vds, thresh=200, transition='fall')[0]+40
    j= trigger(Vds, thresh=200, transition='rise')[0]-60
    
    vds = Vds[i:j]
    t = time[i:j]
    m= sklearn.linear_model.LinearRegression()
    Rds =40
    m.fit(t.reshape((-1,1)),vds/Rds)
    ic=m.predict(t.reshape((-1,1)))
    iest=vds/Rds
    dt = t[-1]-t[0]
    di = ic[-1]-ic[0]
    V0= float(vol.lower().replace("v", ""))
    # v = L di/dt
    Lm= V0/(di/dt)
    
    axs[4].plot(t,iest-ic[0], label = f"Vin = {vol}", c=f"C{k}", alpha = 0.5)
    axs[4].plot(t,ic-ic[0], label =f'deltaI={1e3*(ic.max()-ic.min()):0.0f}mA  Lm= {Lm:0.0f}uH',
             linestyle= "--", linewidth=2)
    k=k+1
    

    
axs[0].legend()
axs[4].legend()

# %%
0.7*4/26
# Out:
# 0.10769230769230768

# %%
vol = "401.9v"
f= "2026-01-06_17-46-24-611"
f=f+".csv"
df= pd.read_csv(f)
Vds= df.CH1.values-vals0["CH1"]
Vs= df.CH4.values-vals0["CH4"]
Is= df.CH2.values-vals0["CH2"]
Is=Is-Is[:1000].mean()
time = df.time.values*1e6

V0= float(vol.lower().replace("v" ,""))

plt.plot(time, Vds, label = f"Vin = {vol}")
plt.plot(time, 200*Is, label = f"Vin = {vol}")
plt.xlim([2.5,7])
t0=3.11
t1=4.32
dt=t1-t0
print(dt,"us")
plt.plot([t0,t0],[0,500])
plt.plot([t1,t1],[0,500])
#plt.plot(time, 1e2*Is, label = f"Vin = {vol}")
# Out:
# 1.2100000000000004 us

# %%
plt.plot(time, Is, label = f"Vin = {vol}")
plt.xlim([2.5,7])
t0=3.11
t1=4.285
dt=t1-t0
print(dt,"us")
plt.plot([t0,t0],[0,1])
plt.plot([t1,t1],[0,1])
# Out:
# 1.1750000000000003 us

# %%
fig , axs = plt.subplots(2,3, figsize=(12,7))
axs = axs .flatten()
for vol, f in zip(voltages, files): 
    f=f+".csv"
    df= pd.read_csv(f)
    Vds= df.CH1.values-vals0["CH1"]
    Vs= df.CH4.values-vals0["CH4"]
    Is= df.CH2.values-vals0["CH2"]
    Is=Is-Is[:1000].mean()
    time = df.time.values*1e6
    axs[2].plot(time, Vds, label = f"Vin = {vol}")
    V0= float(vol.lower().replace("v" ,""))
    axs[1].plot(time,V0- Vds, label = f"Vin = {vol}")
    axs[0].plot(time, Vs, label = f"Vin = {vol}")
    axs[3].plot(time, Is, label = f"Vin = {vol}")
    j= trigger(Vds, thresh=100, transition='rise')[0]
    i= trigger(Vds, thresh=100, transition='fall')[0]
    vds = Vds[i:j]
    t = time[i:j]
    axs[4].plot(t, vds, label = f"Vin = {vol}")
    
axs[0].legend()
