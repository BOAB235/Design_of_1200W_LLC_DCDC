# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("2025-11-28_18-06-40-341.csv")
vds = df.CH1.values*100  # x100 probe
iD =  df.CH2.values # x100 probe
df.head()
# Out:
#         CH1       CH2          time            Ts
# 0 -0.180000 -0.600313  0.000000e+00  2.000000e-09
# 1 -0.179844 -0.440937  2.000000e-09           NaN
# 2 -0.140000 -0.478125  4.000000e-09           NaN
# 3 -0.180000 -0.442188  6.000000e-09           NaN
# 4 -0.179844 -0.359375  8.000000e-09           NaN

# %%
fig, axs = plt.subplots(1,2, figsize=(10,5)
, gridspec_kw={'wspace':0.5#, 'hspace': 1.0
              })
axs[0].plot(vds)
axs[1].plot(iD)

# %%
vds_thre= vds.mean()
iD_thre= iD.mean()

# %%
df = pd.read_csv("2025-11-28_18-19-47-406.csv")
df.head()
# Out:
#         CH1       CH2          time            Ts
# 0  3.519531 -0.404062  0.000000e+00  2.000000e-09
# 1  3.540000 -0.360000  2.000000e-09           NaN
# 2  3.540000 -0.520312  4.000000e-09           NaN
# 3  3.539687 -0.399687  6.000000e-09           NaN
# 4  3.499375 -0.400000  8.000000e-09           NaN

# %%
Ts = df.Ts.values[0]
vds = df.CH1.values*100 -vds_thre # x100 probe
iD =  df.CH2.values-iD_thre # x100 probe
iD = iD -iD[:500].mean()
#diD =  df.CH2.values # x100 probe
#diD = diD -diD[:500].mean()

#vgs = df.CH4.values
#vgs = vgs-vgs[:500].mean()


fig, axs = plt.subplots(1,2, figsize=(10,5)
, gridspec_kw={'wspace':0.5#, 'hspace': 1.0
              })
axs[0].plot(vds)
axs[1].plot(iD)

# %% [raw]
# fig, axs = plt.subplots(1,2, figsize=(10,5)
# , gridspec_kw={'wspace':0.5#, 'hspace': 1.0
#               })
# ax1=axs[0]
# t= np.arange(0,len(vds)*Ts, Ts)
#
# # Primary y-axis
# ax1.plot(t, vds, color='C0')
# ax1.set_ylabel("Vds", color='C0')
#
# # Secondary y-axis
# ax2 = ax1.twinx()
# ax2.plot(t, vgs, color='C1', alpha = 0.7)
# ax2.set_ylabel("Driver in INA", color='C1')
#
#
#
#
#
# ax3=axs[1]
#
# # Primary y-axis
# ax3.plot(t, vds, color='C2')
# ax3.set_ylabel("Vds", color='C2')
#
# # Secondary y-axis
# ax4 = ax3.twinx()
# ax4.plot(t, iD, color='C3')
# ax4.set_ylabel("ID", color='C3')
#
# axs[1].set_xlabel("time s")
# axs[0].set_xlabel("time s")
# axs[1].grid()
# axs[0].grid()
#
#
# plt.show()

# %% [raw]
# df = pd.read_csv("2025-11-17_09-30-47-008.csv")
#
# Ts = df.Ts.values[0]
# vds = df.CH1.values*100 # x100 probe
# iD =  df.CH3.values # x100 probe
# iD = iD -iD[:500].mean()
# #diD =  df.CH2.values # x100 probe
# #diD = diD -diD[:500].mean()
#
#
#
#
# #plt.plot(diD)
# plt.plot(iD)
# #plt.ylim([-2,15])

# %% [raw]
# fig, axs = plt.subplots(1,2, figsize=(10,5)
# , gridspec_kw={'wspace':0.5#, 'hspace': 1.0
#               })
# ax1=axs[0]
#
#
#
#
#
# ax3=axs[1]
#
# # Primary y-axis
# ax3.plot(t, vds, color='C2')
# ax3.set_ylabel("Vds", color='C2')
#
# # Secondary y-axis
# ax4 = ax3.twinx()
# ax4.plot(t, iD, color='C3')
# ax4.set_ylabel("id", color='C3')
#
# axs[1].set_xlabel("time s")
# axs[0].set_xlabel("time s")
# axs[1].grid()
# axs[0].grid()
#
#
# plt.show()

# %%
plt.plot(iD)
k= 2.5e-5
iD2= iD + np.arange(0,len(iD))*k
plt.plot(iD2)
plt.grid()
plt.show()
# Primary y-axis
p = vds*iD2
p = p-p[:500].mean()
E =np.cumsum(p)*Ts
#plt.plot(t, p, color='C2')
#plt.show()
plt.plot( E)

# %%
#### Primary y-axis
p = vds*iD
p = p-p[:500].mean()
E =np.cumsum(p)*Ts
plt.plot( p, color='C2')
plt.show()
plt.plot( E)

# %% [raw]
# # Primary y-axis
# p = vds*iD2
# p = p-p[:500].mean()
# E =np.cumsum(p)*Ts
# plt.plot(t, p, color='C2')
# plt.show()
# plt.plot(t, E)

# %%
from math import *
arg=[0]
for i in range(10, len(vds)-10):
    if abs(vds[i+3]-vds[i-3])>20:
        if i-arg[-1]>100:
            arg.append(i) 
print(len(arg))
plt.plot(arg, len(arg)*[100], marker="x")
plt.plot(vds)
# Out:
# 21

# %%
def trigger (sig , thresh= None, transition= "rise", marginI = 20):
    arr=[0]
    if thresh is None: 
        thresh = (sig.max()+sig.min())/2
    for i in range(1, len(sig)):
        if transition =="rise":
            if sig[i-1] <thresh and sig[i] >= thresh and i > arr[-1]+marginI:
                arr.append(i)
        elif sig[i-1] >thresh and sig[i] <= thresh and i > arr[-1]+marginI:
            arr.append(i)
    return arr[1:]
idx_rise = trigger (vds, transition= "rise")
idx_fall= trigger (vds, transition= "fall")
plt.plot(idx_rise, len(idx_rise)*[100], marker="x", label = "rise")
plt.plot(idx_fall, len(idx_fall)*[150], marker="o", label = "fall")
plt.plot(vds, label = "Vds")
plt.legend()
plt.grid()

# %%
idx_rise = trigger (vds, transition= "rise")
idx_fall= trigger (vds, transition= "fall")

fig , axs= plt.subplots(3,2)
di=200
Eon={}
Eoff={}
for i in idx_rise: 
    
    I1 = iD[i-di-10:i-di].mean()

    I0 = iD[i+di-50:i+di].mean()
    p=vds[i-di:i+di]*(iD[i-di:i+di]-I0)
    E= np.sum(p)*Ts*1e6

    Eoff[I1]=E
    axs[0][0].plot(p)
    axs[1][0].plot(vds[i-di:i+di])
    axs[0][0].set_title("turn off")
    axs[2][0].plot(iD[i-di:i+di]-I0)
for i in idx_fall: 
    I1 = iD[i+10:i+di*2+10].mean()
    I0 = iD[i-di:i-di+50].mean()
    p=vds[i-di:i+di]*(iD[i-di:i+di]-I0)
    E= np.sum(p)*Ts*1e6
    

    axs[0][1].plot(p)
    axs[1][1].plot(vds[i-di:i+di])
    axs[0][1].set_title("turn on")
    axs[2][1].plot(iD[i-di:i+di]-I0)
    Eon[I1]=E
for ax in axs .flatten(): 
    ax.grid()

# %%
Eon
# Out:
# {np.float64(0.412885625): np.float64(28.03802095251563),
#  np.float64(1.4375504687499998): np.float64(163.4900334098369),
#  np.float64(2.3378332812500005): np.float64(224.50475397825102),
#  np.float64(3.14929265625): np.float64(267.55947717329207),
#  np.float64(3.92741765625): np.float64(303.8483971041191),
#  np.float64(4.7134473437499995): np.float64(341.6422173999326),
#  np.float64(5.497199687499999): np.float64(369.1910493893389),
#  np.float64(6.298939531249999): np.float64(390.7815364401925),
#  np.float64(7.054884062499999): np.float64(423.09961055813676),
#  np.float64(7.816304375): np.float64(445.38548450149415)}

# %%
Eoff
# Out:
# {np.float64(0.421645): np.float64(9.104061862875977),
#  np.float64(1.67752): np.float64(13.172117554586913),
#  np.float64(2.53367625): np.float64(13.705691717627937),
#  np.float64(3.14605125): np.float64(17.68185989822852),
#  np.float64(3.9533325000000006): np.float64(18.55165723924707),
#  np.float64(4.5304575): np.float64(21.989193955897456),
#  np.float64(5.2853325): np.float64(27.047742222249017),
#  np.float64(5.997988749999999): np.float64(28.73307743420508),
#  np.float64(6.849801249999999): np.float64(32.014462603809584),
#  np.float64(7.561426249999999): np.float64(38.43868722541503)}

# %%
R1= 10
R2 = 3
R1*R2/(R1+R2)
# Out:
# 2.3076923076923075

# %%
R1= 5
R2 = 3
R1*R2/(R1+R2)
# Out:
# 1.875

# %%
(-pd.Series(Eon)).plot(label = "Eon",marker="x")
plt.legend()
plt.show()
s=pd.Series(Eoff)
s=s[s.index>3]
s.plot(label = "Eoff",marker="x")
plt.legend()

# %% [markdown]
# # End

# %%
l = """10 ohm 
2025-11-28_18-16-13-175
5 ohm 
2025-11-28_18-17-36-908
3 ohm 
2025-11-28_18-18-15-605
10//5 ohm 
2025-11-28_18-19-08-573
10//3 ohm 
2025-11-28_18-19-47-406
5//3 ohm 
2025-11-28_18-44-01-262""".replace(" ", "").split("\n")
names = l[1::2]
labels=l[0::2]
print(names), print(labels)
# Out:
# ['2025-11-28_18-16-13-175', '2025-11-28_18-17-36-908', '2025-11-28_18-18-15-605', '2025-11-28_18-19-08-573', '2025-11-28_18-19-47-406', '2025-11-28_18-44-01-262']
# ['10ohm', '5ohm', '3ohm', '10//5ohm', '10//3ohm', '5//3ohm']
# (None, None)

# %%
#list={}
dic  = {}
for i in range(len(names)):
    data ={}
    path  = names[i]+".csv"
    label = labels[i]
    print(path, label)
    df = pd.read_csv(path)
    Ts = df.Ts.values[0]
    vds = df.CH1.values*100 -vds_thre # x100 probe
    iD =  df.CH2.values-iD_thre # x100 probe
    iD = iD -iD[:500].mean()
    
    
    iD2= iD + np.arange(0,len(iD))*k
    
    p = vds*iD2
    p = p-p[:500].mean()
    E =np.cumsum(p)*Ts
    
    p = vds*iD
    p = p-p[:500].mean()
    E =np.cumsum(p)*Ts
    p = vds*iD2
    p = p-p[:500].mean()
    E =np.cumsum(p)*Ts
    
    
    from math import *
    arg=[0]
    for i in range(10, len(vds)-10):
        if abs(vds[i+3]-vds[i-3])>20:
            if i-arg[-1]>100:
                arg.append(i) 
    print(len(arg))
    #plt.plot(arg, len(arg)*[100], marker="x")
    #plt.plot(vds)
    #plt.show()
    
    #fig , axs= plt.subplots(3,2)
    di=100
    Eon={}
    Eoff={}






    di=300
    Eon={}
    Eoff={}
    for i in arg:
        I1 = iD[i+10:i+di*2+10].mean()
        I2 = iD[i-di*2-10:i-10].mean()
        #print(I1, I2)
        if I2> I1:
            I1= I2
        
        
        if len(iD[i-di*2-10:i-10]) ==0: 
            print("empty", label)
        if vds[i-di] > vds[i+di]: # turn on
            
            I0 = iD[i-di:i-di+50].mean()
            p=vds[i-di:i+di]*(iD[i-di:i+di]-I0)
            E= np.sum(p)*Ts*1e6
            Eon[I1]=E
        else : # turn off
            I0 = iD[i+di-50:i+di].mean()
            p=vds[i-di:i+di]*(iD[i-di:i+di]-I0)
            E= np.sum(p)*Ts*1e6
            Eoff[I1]=E
    
        #print(I0) 
    
    
    
    
        
            

        
        
        
    #plt.show()  
    data["Eon"]=Eon
    #(-pd.Series(Eon)).plot(label = "Eon",marker="x")
    #s.plot(label = "Eoff",marker="x")
    data["Eoff"]= Eoff
    #plt.legend()
    #plt.show()
    dic[label]= data
# Out:
# 2025-11-28_18-16-13-175.csv 10ohm
# 21
# empty 10ohm
# 2025-11-28_18-17-36-908.csv 5ohm
# 21
# empty 5ohm
# 2025-11-28_18-18-15-605.csv 3ohm
# 21
# empty 3ohm
# 2025-11-28_18-19-08-573.csv 10//5ohm
# 21
# empty 10//5ohm
# 2025-11-28_18-19-47-406.csv 10//3ohm
# 21
# empty 10//3ohm
# 2025-11-28_18-44-01-262.csv 5//3ohm
# 21
# empty 5//3ohm
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\a037702\AppData\Local\Temp\ipykernel_20040\1492406441.py:55: RuntimeWarning: Mean of empty slice.
#   I2 = iD[i-di*2-10:i-10].mean()
# C:\Users\a037702\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
dic
# Out:
# {'10ohm': {'Eon': {},
#   'Eoff': {np.float64(8.338953125): np.float64(50.157762635234384)}},
#  '5ohm': {'Eon': {},
#   'Eoff': {np.float64(8.082224375000001): np.float64(38.32523164426661)}},
#  '3ohm': {'Eon': {},
#   'Eoff': {np.float64(8.0254059375): np.float64(33.255352884074206)}},
#  '10//5ohm': {'Eon': {},
#   'Eoff': {np.float64(8.026780625): np.float64(36.123589971819335)}},
#  '10//3ohm': {'Eon': {},
#   'Eoff': {np.float64(7.9915840624999985): np.float64(33.72948812031251)}},
#  '5//3ohm': {'Eon': {},
#   'Eoff': {np.float64(8.003614375): np.float64(26.810085656764656)}}}

# %%
dic.keys()
# Out:
# dict_keys(['10ohm', '5ohm', '3ohm', '10//5ohm', '10//3ohm', '5//3ohm'])

# %%
dic['10ohm'].keys()
# Out:
# dict_keys(['Eon', 'Eoff'])

# %%
dic['10ohm']
# Out:
# {'Eon': {}, 'Eoff': {np.float64(8.338953125): np.float64(50.157762635234384)}}

# %%
fig, axs = plt.subplots(1,2, figsize=(10,5)
, gridspec_kw={'wspace':0.5#, 'hspace': 1.0
              })
for kk, v in dic.items():
    Eon = v["Eon"]
    Eon = Eon[Eon.index>1]

    (-Eon).plot(ax = axs[0], label = kk)
    (-v["Eoff"]).plot(ax = axs[1], label = kk)
axs[0].set_title("Eon (µJ)")
axs[1].set_title("Eoff (µJ)")
axs[0].set_xlabel("Id (A)")
axs[1].set_xlabel("Id (A)")
axs[0].grid()
axs[1].grid()
axs[0].legend()
axs[1].legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 8
#       5     Eon = v["Eon"]
#       6     Eon = Eon[Eon.index>1]
# ----> 8     (-Eon).plot(ax = axs[0], label = kk)
#       9     (-v["Eoff"]).plot(ax = axs[1], label = kk)
#      10 axs[0].set_title("Eon (µJ)")
#
# File ~\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~\NotSynchronized\VirtualEnvs\venv1\Lib\site-packages\pandas\plotting\_matplotlib\core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
