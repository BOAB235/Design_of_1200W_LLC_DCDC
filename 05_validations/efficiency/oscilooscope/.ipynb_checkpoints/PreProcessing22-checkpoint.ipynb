# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "2026-02-14_11-05-54-493.csv"
df=pd.read_csv(path)
t= df.time.values
vds=df.CH1.values
vgs = df.CH4.values

# %%
df
# Out:
#              CH1        CH4          time            Ts
# 0     321.703125  -0.597656  0.000000e+00  4.000000e-10
# 1     323.562500  -0.700000  4.000000e-10           NaN
# 2     328.171875  -0.595313  8.000000e-10           NaN
# 3     320.296875  -0.501563  1.200000e-09           NaN
# 4     323.593750  -0.702344  1.600000e-09           NaN
# ...          ...        ...           ...           ...
# 9995  -10.015625  11.796875  3.998000e-06           NaN
# 9996   -6.000000  11.791406  3.998400e-06           NaN
# 9997  -10.015625  11.400781  3.998800e-06           NaN
# 9998   -4.031250  11.802344  3.999200e-06           NaN
# 9999   -2.015625  11.499219  3.999600e-06           NaN
#
# [10000 rows x 4 columns]

# %%
plt.plot(t, vds)

# %%
plt.plot(t, vds)
plt.ylim([-50,15])
plt.xlim([2e-6,2.5e-6])
plt.plot(t,vgs)
