# %% [markdown]
# # PI design

# %% [raw]
# ## RC system
# ########### freq
# Vo = Vi * Zc/Zc+R
# H = Vo/Vi = 1/(1+R/Zc) = 1/(1+jRCw)
#
# ########## Time
# Vi = R*i + Vo and i=CdVc/dt = C*dVo/dt
# Vi = RC dVo/dt + Vo
# integ(Vi-Vo)= RC (Vo-Vo0)
# Vo = 1/To integ(Vi-Vo) + Vo0
#
# ## PI controler
# Vo = Kp*Vi + Ki*integ(Vi)

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
def integ_Euler(Vi, Vo0, Ts): 
    Vo = np.zeros(Vi.shape)
    Vo[0]=Vo0
    for i in range(1, len(Vo)):
        Vo[i]= Vo[i-1]+Vi[i]*Ts


    # Backward Euler (right Riemann): 
    # Vo[i] = Vo[i-1] + Ts * Vi[i]
    # Forward Euler (left Riemann): 
    # Vo[i] = Vo[i-1] + Ts * Vi[i-1]

    return Vo

Ts= 1e-3
Vi = np.zeros(100)+1 # step 
time = np.arange(0,Ts*len(Vi), Ts)

Vo0= 0.1
Vo= integ_Euler(Vi, Vo0, Ts)
plt.plot(time, Vo)

# %%
Vi = np.zeros(100)+1 # step 
time = np.arange(0,Ts*len(Vi), Ts)
Ts= 1e-3
Vo0= 0
def PI_controler (Vi,Vo0, Ts, Kp , Ki): 
    return Ki*integ_Euler(Vi, Vo0, Ts)+Kp*Vi
Vo= PI_controler(Vi,Vo0, Ts, Kp=2 , Ki=5e-1)
plt.plot(time, Vo)

# %%
def first_order_backward_euler(Vi, Vo0, Ts, To, gain = 1):
    a = Ts / To
    Vo = np.empty_like(Vi, dtype=float)
    Vo[0] = Vo0
    for i in range(1, len(Vi)):
        Vo[i] = (Vo[i-1] + a*Vi[i]) / (1 + a)
    return gain*Vo



Vi = np.zeros(100)+1 # step 
time = np.arange(0,Ts*len(Vi), Ts)
Ts= 1e-3
Vo0= 0
To = 1e-2

Vo = first_order_backward_euler(Vi, Vo0, Ts, To)
plt.plot(time , Vo)

# %%
import pandas as pd
df = pd.read_csv("../IP_V1/data/2025-12-12_11-18-16-855.csv")
df.head()
# Out:
#     CH1  CH2  CH3  CH4          time            Ts
# 0  0.56 -0.3 -0.8 -5.2  0.000000e+00  4.000000e-07
# 1  0.56 -0.7 -1.2 -5.4  4.000000e-07           NaN
# 2  0.60 -0.5 -1.0 -5.0  8.000000e-07           NaN
# 3  0.48 -0.5 -0.6 -5.4  1.200000e-06           NaN
# 4  0.56 -0.4 -0.6 -5.4  1.600000e-06           NaN

# %%
Ts= df.Ts.iloc[0]
CH1 = df.CH1.values
CH1 = CH1-CH1[200].mean()
plt.plot(CH1)

# %%
plt.plot(CH1[:800])

# %%
df.Ts.iloc[0],Ts
# Out:
# (np.float64(4e-07), np.float64(4e-07))

# %%
Ts= df.Ts.iloc[0]
i0= 600
vout = CH1[i0:]
time = np.arange(0,len(vout)*Ts, Ts)
plt.plot(time, vout)




Vi = np.zeros(len(time))+1
time = np.arange(0,Ts*len(Vi), Ts)

Vo0= 0
To = 3.2e-4

Vo = first_order_backward_euler(Vi, Vo0, Ts, To, gain = 11)
plt.plot(time , Vo)

# %%
import numpy as np

# --- Blocks (one-step) ---

def integ_step(x, v, Ts):
    """One-step integrator (forward Euler): x_{k+1} = x_k + Ts * v_k"""
    return x + Ts * v

def pi_step(e, I, Kp, Ti, Ts):
    """PI controller one step using the integrator block."""
    I = integ_step(I, e / Ti, Ts)   # integrate error/Ti
    u = Kp * (e + I)                # PI = Kp*e + Kp*∫(e/Ti)dt
    return u, I

def first_order_step(u, y, Ts, To):
    """First-order plant y' = (u - y)/To, one step using the integrator block."""
    dy = (u - y) / To
    y  = integ_step(y, dy, Ts)
    return y

# --- Simulation loop ---

def simulate_pi_first_order(r, Ts, To, Kp, Ti, y0=0.0):
    """
    r: 1D input (reference), length N
    returns: y (same length), u
    """
    r = np.asarray(r, dtype=float)
    N = len(r)
    y = np.empty(N); u = np.empty(N)

    yk = y0     # plant state/output
    I  = 0.0    # PI integrator state

    for k in range(N):
        e  = r[k] - yk           # error
        uk, I = pi_step(e, I, Kp, Ti, Ts)
        yk = first_order_step(uk, yk, Ts, To)
        u[k] = uk
        y[k] = yk

    return y, u

# --- Example ---
#if __name__ == "__main__":
#if 0: 
    
#r = np.ones(1000)            # 1D input array
#y, u = simulate_pi_first_order(r, Ts, To, Kp, Ti)  # y has same length as r

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

#Ts = 1e-3
#To = 1e-2

# Discretize plant G(s) = 1/(To s + 1)
numG = np.array([1.0])
denG = np.array([To, 1.0])
numd, dend, _ = signal.cont2discrete((numG, denG), Ts, method='bilinear')[:3]
numd = numd.ravel(); dend = dend.ravel()

# Your actuator input array (arbitrary)
N = 40000
u = np.zeros(N)

u[N//15: N//4] = 1.0
u[2*N//4 : 3*N//4] = 0.5

# Output by filtering
y = signal.lfilter(numd, dend, u)

# Or with dlsim
sysd = signal.dlti(numd, dend, dt=Ts)
t, y2 = signal.dlsim(sysd, u)
t = t.squeeze(); y2 = y2.squeeze()

plt.figure(figsize=(7,4))
plt.plot(t, u, label='u')
plt.plot(t, y, label='y open loop')





Kp = 3 # 3 time more fast
Ti = To


y, u = simulate_pi_first_order(u, Ts, To, Kp, Ti)

plt.plot(t, y, label='y PI')

plt.grid(True); plt.legend(); plt.tight_layout(); #plt.show()

# %%
vout = CH1[i0:]
time = np.arange(0,len(vout)*Ts, Ts)
plt.plot(time, vout)




Vi = np.zeros(len(time))+1
time = np.arange(0,Ts*len(Vi), Ts)

Vo0= 0
To = 3.2e-4

Vo = first_order_backward_euler(Vi, Vo0, Ts, To, gain = 11)
plt.plot(time , Vo)

Kp = 3 # 3 time more fast
Ti = To
y, u = simulate_pi_first_order(Vi, Ts, To, Kp, Ti)
time = np.arange(0,len(y)*Ts, Ts)
plt.plot(time, 11*y)

# %%
Ki = Kp/Ti 
Ti , Kp, Ki 
# (0.00032, 3, 9375.0)
# Out:
# (0.00032, 3, 9375.0)

# %% [markdown]
#  The system
#  $ G(s) = \frac {1}{1+T_o . s}$
#  <br>
#  The controler
# $ PI(s) = K_p + \frac{K_i}{s} = Kp \frac {1+T_i.s}{T_i.s} $
# <br> with $ T_i = \frac{K_p}{K_i}$
# Open loop <br>
# $ H(s)= G(s).PI(s)= \frac {1}{1+T_o . s}  Kp \frac {1+T_i.s}{T_i.s} = \frac {Kp }{T_i.s}\frac {1+T_i.s}{1+T_o . s} : (I)$
#  <br>
# **Methode 1: Cancellation and Dominant Pole Approximation**
# $T_o = T_i$
#  <br>
# $ H(s)= \frac {K_p}{T_i.s}$
#  <br>
# claused loop
#  <br>
# $H_c(s)= \frac{H(s) }{ 1+H(s)}= \frac{1 }{ 1+\frac {1}{H(s)}} : (II)$
#  <br>
# $H_c(s)= \frac{1 }{ 1+\frac {T_i}{K_p}.s}= \frac{1 }{ 1+T_{oc}.s}$
#  <br>
# With $ T_{oc} = \frac {T_i}{K_p}$
#  <br>
# Example make the system n time more fast
# $ T_{oc} =\frac {T_o}{3}$
#  <br>
# $ Ki= \frac {n}{T_o} $
#  <br>
# $ T_o = T_i = \frac{K_p}{K_i}$
#  <br>
# $ K_p = T_o.K_i = n$
#  <br>
# **Methode 2: Dominant Pole Approximation**
#  <br>
# $ Hc(s) = \frac{1}{1+ \frac {T_i.s}{K_p} \frac {1+T_o . s}{1+T_i.s} }  = \frac{1+T_i.s}{1+(T_i+\frac{T_i}{K_p}).s+\frac{T_i.T_o}{K_p}.s^2}$
#  <br>
# $Hc(s) ≈\frac{1}{1+2\zeta\frac{s}{w_n}+\frac{s^2}{w_n^2}} $
#  <br>
# if $ Ti.wn <<1 $
# $ w_n^2 = \frac{K_p}{T_i.T_o} $
#  <br>
# $ 2\zeta\frac{1}{w_n} = (T_i+\frac{T_i}{K_p}) $
#  <br>
# $ K_p = 2.\zeta.w_n.T_o-1$
#  <br>
# $ T_i= \frac{K_p}{w_n^2.T_o} $
# <br>
# $ T_i.w_n ≪ 1  \Rightarrow  T_i.w_n = \frac{K_p}{w_n.T_o}=2*\zeta -\frac{1}{w_n.T_o} ≪ 1 $
# <br>
# for $ \zeta=1 \Rightarrow  w_n ≪ T_o $

# %%
import pandas as pd
df = pd.read_csv("../IP_V1/data/2025-12-12_11-18-16-855.csv")
df.head()
Ts= df.Ts.iloc[0]
CH3 = df.CH3.values
CH3 = CH3-CH3[200].mean()
plt.plot(CH3)

# %%
plt.plot(CH3[:1000])

# %%
Ts= df.Ts.iloc[0]
i0= 800
vout2 = CH3[i0:]
time2 = np.arange(0,len(vout2)*Ts, Ts)

# %%
plt.plot(time, vout)
plt.plot(time2, vout2)

# %%
import pandas as pd
df = pd.read_csv("2025-12-15_17-41-12-749.csv")

Ts= df.Ts.iloc[0]
CH1 = df.CH1.values

plt.plot(CH1)

# %%
plt.plot(CH1[:100])

# %%
CH1.max(), CH1.min()
# Out:
# (np.float64(50.8), np.float64(-6.4))

# %%
CH1.max(), CH1.min()

# %%
def trigger (sig , thresh= None, transition= "rise", marginI = 20):
    arr=[0]
    if thresh is None: 
        thresh = (sig.max()+sig.min())/2
    for i in range(1, len(sig)):
        if transition =="rise":
            if sig[i-1] <thresh and sig[i] >= thresh and i > arr[-1]+marginI:
                arr.append(i)
        elif sig[i-1] >thresh and sig[i] <= thresh and i > arr[-1]+marginI:
            arr.append(i)
    return arr[1:]

# %%
#trigger (sig=CH1 , thresh= None, transition= "rise", marginI = 5)
idx_rise = trigger (CH1, transition= "rise", marginI = 5)
idx_fall= trigger (CH1, transition= "fall", marginI = 5)
plt.plot(idx_rise, len(idx_rise)*[10], marker="x", label = "rise")
plt.plot(idx_fall, len(idx_fall)*[20], marker="o", label = "fall")
plt.plot(CH1[:200], label = "Vds")
plt.legend()
plt.grid()
plt.xlim((0, 200))
# Out:
# (0.0, 200.0)

# %% [raw]
# N = min((len(idx_rise), len(idx_fall)))
# print(N , len(idx_rise), len(idx_fall))
# [for i in range(N)]

# %%
Ts= df.Ts.iloc[0]
Ts
# Out:
# np.float64(4e-07)

# %%
arr = idx_rise
freqskhz  = [1e-3/(Ts*(arr[i] -arr[i-1])) for i in range(1, len(idx_rise))]
print(freqskhz [:2])
plt.plot(freqskhz )
# Out:
# [np.float64(147.0588235294118), np.float64(147.0588235294118)]

# %%
import pandas as pd
df = pd.read_csv("2025-12-15_17-38-27-575.csv")

Ts= df.Ts.iloc[0]
CH1 = df.CH1.values

plt.plot(CH1)

# %%
CH1 = df.CH1.values
    
i=np.where(CH1>40)[0][0]
CH1= CH1 [i:]

#trigger (sig=CH1 , thresh= None, transition= "rise", marginI = 5)
idx_rise = trigger (CH1, transition= "rise", marginI = 5)
idx_fall= trigger (CH1, transition= "fall", marginI = 5)
plt.plot(idx_rise, len(idx_rise)*[10], marker="x", label = "rise")
plt.plot(idx_fall, len(idx_fall)*[20], marker="o", label = "fall")
plt.plot(CH1[:200], label = "Vds")
plt.legend()
plt.grid()
plt.xlim((0, 200))
# Out:
# (0.0, 200.0)

# %%
arr = idx_rise
freqskhz  = [1e-3/(Ts*(arr[i] -arr[i-1])) for i in range(1, len(idx_rise))]
print(freqskhz [:2])
plt.plot(freqskhz )
# Out:
# [np.float64(156.25), np.float64(147.0588235294118)]

# %% [markdown]
# # Draft

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
# First order sys: G(s) = 1/(1+To*s)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

Ts = 1e-3
To = 1e-2

# Discretize plant G(s) = 1/(To s + 1)
numG = np.array([1.0])
denG = np.array([To, 1.0])
numd, dend, _ = signal.cont2discrete((numG, denG), Ts, method='bilinear')[:3]
numd = numd.ravel(); dend = dend.ravel()

# Your actuator input array (arbitrary)
N = 1500
u = np.zeros(N)
u[100:600] = 1.0
u[900:1200] = 0.5

# Output by filtering
y = signal.lfilter(numd, dend, u)

# Or with dlsim
sysd = signal.dlti(numd, dend, dt=Ts)
t, y2 = signal.dlsim(sysd, u)
t = t.squeeze(); y2 = y2.squeeze()

plt.figure(figsize=(7,4))
plt.plot(t, u, label='u[k] (input)')
plt.plot(t, y, label='y[k] (output)')
plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()

# %%
import numpy as np
from scipy.signal import cont2discrete

def simulate_pi_first_order(
    r, Ts, To, Kp, Ti, y0=0.0,
    umin=None, umax=None,
    method='backward_diff'  # or 'bilinear'
):
    r = np.asarray(r, dtype=float)
    N = len(r)
    
    # Continuous plant in SS form
    Ac = np.array([[-1.0/To]])
    Bc = np.array([[1.0/To]])
    Cc = np.array([[1.0]])
    Dc = np.array([[0.0]])
    
    # Discretize
    Ad, Bd, Cd, Dd, _ = cont2discrete((Ac, Bc, Cc, Dc), Ts, method=method)

    y = np.zeros(N)
    u = np.zeros(N)
    e = np.zeros(N)
    x = np.array([[y0]])  # plant state
    I = 0.0  # integrator term

    def sat(v):
        if umin is not None: v = max(umin, v)
        if umax is not None: v = min(umax, v)
        return v

    # Initial step
    y[0] = (Cc @ x + Dd * 0.0).item()
    e[0] = r[0] - y[0]
    I += (Ts/Ti) * e[0]          # backward Euler for integrator
    u[0] = sat(Kp * (e[0] + I))

    # Simulation loop
    for k in range(1, N):
        # Plant update
        x = Ad @ x + Bd * u[k-1]
        y[k] = (Cc @ x + Dd * u[k-1]).item()

        # PI control
        e[k] = r[k] - y[k]
        I += (Ts/Ti) * e[k]
        u[k] = sat(Kp * (e[k] + I))

    t = np.arange(N) * Ts
    return t, y, u, e

# %%
def sys_first_order(
    r, Ts, To , y0=0.0,
    umin=None, umax=None,
    method='backward_diff'  # 'bilinear' also OK
):
    r = np.asarray(r, dtype=float)
    N = len(r)
    # Continuous plant in SS form
    Ac = np.array([[-1.0/To]]); Bc = np.array([[1.0/To]])
    Cc = np.array([[1.0]]);     Dc = np.array([[0.0]])
    Ad, Bd, Cd, Dd, _ = cont2discrete((Ac, Bc, Cc, Dc), Ts, method=method)

    y = np.empty(N); u = np.empty(N); e = np.empty(N)
    x = np.array([[y0]])  # plant state
    I = 0.0

    def sat(v):
        if umin is not None: v = max(umin, v)
        if umax is not None: v = min(umax, v)
        return v

    # k=0
    y[0] = (Cc @ x + Dd * 0.0).item()
    e[0] = r[0] - y[0]
    I += (Ts/Ti) * e[0]          # backward Euler for integrator
    u_star = Kp * (e[0] + I)
    u[0] = sat(u_star)

    for k in range(1, N):
        # plant step with previous control
        x = Ad @ x + Bd * u[k-1]
        y[k] = (Cc @ x + Dd * u[k-1]).item()

        e[k] = r[k] - y[k]
        I += (Ts/Ti) * e[k]      # PI integrator
        u_star = Kp * (e[k] + I)
        u[k] = sat(u_star)

    t = np.arange(N) * Ts
    return t, y, u, e

# %%
import numpy as np

def sys_first_order(r, Ts, To, y0=0.0, method='backward_diff'):
    """
    Simulate first-order system: G(s) = 1 / (1 + To*s)
    
    r : array-like, input signal
    Ts: sampling time
    To: time constant
    y0: initial output
    method: 'backward_diff' or 'bilinear'
    """
    r = np.asarray(r, dtype=float)
    N = len(r)
    y = np.zeros(N)
    y[0] = y0

    if method == 'backward_diff':  # Backward Euler
        a = Ts / (To + Ts)
    elif method == 'bilinear':    # Tustin
        a = Ts / (2*To + Ts)
    else:
        raise ValueError("method must be 'backward_diff' or 'bilinear'")
    
    for k in range(1, N):
        if method == 'backward_diff':
            y[k] = y[k-1] + a * (r[k] - y[k-1])
        else:  # bilinear
            y[k] = ((1 - (Ts/(2*To))) * y[k-1] + a * (r[k] + r[k-1])) / (1 + Ts/(2*To))

    t = np.arange(N) * Ts
    return t, y

# %%
Ts, To, Kp, Ti = 1e-3, 1e-2, 0.6, 1e-2
r = np.ones(2000); r[700:1000] = 0.2; r[1400:] = 1.1

t, y, u, e = simulate_pi_first_order(r, Ts, To, Kp, Ti, umin=0.0, umax=1.0)
plt.figure(figsize=(7,4))
plt.plot(t, r)
#plt.plot(t, u, label='u[k] (input)')
plt.plot(t, y, label='y[k] (output)')
t, y_sys= sys_first_order(r, Ts, To, y0=0.0)
plt.plot(t, y_sys, label='y sys')

plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()

# %%
Ts, To, Kp, Ti = 1e-5, 1e-2, 0.6, 1e-2
Tsim = 0.1
N = int(Tsim/Ts)
r = np.ones(N)

t, y, u, e = simulate_pi_first_order(r, Ts, To, Kp, Ti, umin=0.0, umax=1.0)
plt.figure(figsize=(7,4))
plt.plot(t, r)
#plt.plot(t, u, label='u[k] (input)')
plt.plot(t, y, label='y[k] (output)')
t, y_sys= sys_first_order(r, Ts, To, y0=0.0)
plt.plot(t, y_sys, label='y sys')

plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
#  The system
#  $ G(s) = \frac {1}{1+T_o . s}$
#  <br>
#  The controler
# $ PI(s) = K_p + \frac{K_i}{s} = Kp \frac {1+T_i.s}{T_i.s} $
# <br> with $ T_i = \frac{K_p}{K_i}$
# Open loop <br>
# $ H(s)= G(s).PI(s)= \frac {1}{1+T_o . s}  Kp \frac {1+T_i.s}{T_i.s} = \frac {Kp }{T_i.s}\frac {1+T_i.s}{1+T_o . s} : (I)$
#  <br>
# **Methode 1: Cancellation and Dominant Pole Approximation**
# $T_o = T_i$
#  <br>
# $ H(s)= \frac {K_p}{T_i.s}$
#  <br>
# claused loop
#  <br>
# $H_c(s)= \frac{H(s) }{ 1+H(s)}= \frac{1 }{ 1+\frac {1}{H(s)}} : (II)$
#  <br>
# $H_c(s)= \frac{1 }{ 1+\frac {T_i}{K_p}.s}= \frac{1 }{ 1+T_{oc}.s}$
#  <br>
# With $ T_{oc} = \frac {T_i}{K_p}$
#  <br>
# Example make the system n time more fast
# $ T_{oc} =\frac {T_o}{3}$
#  <br>
# $ Ki= \frac {n}{T_o} $
#  <br>
# $ T_o = T_i = \frac{K_p}{K_i}$
#  <br>
# $ K_p = T_o.K_i = n$
#  <br>
# **Methode 2: Dominant Pole Approximation**
#  <br>
# $ Hc(s) = \frac{1}{1+ \frac {T_i.s}{K_p} \frac {1+T_o . s}{1+T_i.s} }  = \frac{1+T_i.s}{1+(T_i+\frac{T_i}{K_p}).s+\frac{T_i.T_o}{K_p}.s^2}$
#  <br>
# $Hc(s) ≈\frac{1}{1+2\zeta\frac{s}{w_n}+\frac{s^2}{w_n^2}} $
#  <br>
# if $ Ti.wn <<1 $
# $ w_n^2 = \frac{K_p}{T_i.T_o} $
#  <br>
# $ 2\zeta\frac{1}{w_n} = (T_i+\frac{T_i}{K_p}) $
#  <br>
# $ K_p = 2.\zeta.w_n.T_o-1$
#  <br>
# $ T_i= \frac{K_p}{w_n^2.T_o} $
# <br>
# $ T_i.w_n ≪ 1  \Rightarrow  T_i.w_n = \frac{K_p}{w_n.T_o}=2*\zeta -\frac{1}{w_n.T_o} ≪ 1 $
# <br>
# for $ \zeta=1 \Rightarrow  w_n ≪ T_o $

# %% [markdown]
# $ escaped brackets $

# %% [markdown]
# Method 1 is simple and widely used for PI tuning when the plant is well approximated by a first-order system.
# Method 2 is more accurate for higher performance or when you want to control overshoot (via ζ).

# %%
Ts, To = 1e-5, 1e-2
#Kp, Ti  = 0.6, 1e-2
Kp= 100
Ti   =  To/5

Tsim = 0.1
N = int(Tsim/Ts)
r = np.ones(N)

t, y, u, e = simulate_pi_first_order(r, Ts, To, Kp, Ti, umin=0.0, umax=1.0)
plt.figure(figsize=(7,4))
plt.plot(t, r)
#plt.plot(t, u, label='u[k] (input)')
plt.plot(t, y, label='y[k] (output)')
t, y_sys= sys_first_order(r, Ts, To, y0=0.0)
plt.plot(t, y_sys, label='y sys', linestyle = "--")

plt.grid(True); plt.legend(); plt.tight_layout(); plt.show()

# %%
import numpy as np

# --- Blocks (one-step) ---

def integ_step(x, v, Ts):
    """One-step integrator (forward Euler): x_{k+1} = x_k + Ts * v_k"""
    return x + Ts * v

def pi_step(e, I, Kp, Ti, Ts):
    """PI controller one step using the integrator block."""
    I = integ_step(I, e / Ti, Ts)   # integrate error/Ti
    u = Kp * (e + I)                # PI = Kp*e + Kp*∫(e/Ti)dt
    return u, I

def first_order_step(u, y, Ts, To):
    """First-order plant y' = (u - y)/To, one step using the integrator block."""
    dy = (u - y) / To
    y  = integ_step(y, dy, Ts)
    return y

# --- Simulation loop ---

def simulate_pi_first_order(r, Ts, To, Kp, Ti, y0=0.0):
    """
    r: 1D input (reference), length N
    returns: y (same length), u
    """
    r = np.asarray(r, dtype=float)
    N = len(r)
    y = np.empty(N); u = np.empty(N)

    yk = y0     # plant state/output
    I  = 0.0    # PI integrator state

    for k in range(N):
        e  = r[k] - yk           # error
        uk, I = pi_step(e, I, Kp, Ti, Ts)
        yk = first_order_step(uk, yk, Ts, To)
        u[k] = uk
        y[k] = yk

    return y, u

# --- Example ---
if __name__ == "__main__":
    
    r = np.ones(1000)            # 1D input array
    y, u = simulate_pi_first_order(r, Ts, To, Kp, Ti)  # y has same length as r

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Ts, To, Kp, Ti = 1e-3, 1e-2, 0.6, 1e-2

y, u = simulate_pi_first_order(r, Ts, To, Kp, Ti)  # y has same length as r

# %%
plt.plot(r)
plt.plot(y)
#plt.plot(u)

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
class FirstOrder:
    def __init__(self, To, Ts, y0=0.0):
        self.a = Ts / To
        self.y = y0
    def step(self, u):
        self.y += self.a * (u - self.y)
        return self.y
To = 1e-3
Ts = 1e-5
Tsim = 1e-2
N = int(Tsim/Ts)
time = np.arange(0,Ts*N, Ts)
u = np.ones(N)
G = FirstOrder(To, Ts)
y = []
for i in range (N): 
    y_val = G.step(u[i])
    y.append(y_val)
plt.plot(time, y)

# %%
import numpy as np
import matplotlib.pyplot as plt

class FirstOrder:
    def __init__(self, To, Ts, y0=0.0):
        self.a = Ts / To
        self.y = y0

    def step(self, u):
        self.y += self.a * (u - self.y)
        return self.y

class PI_cont:
    def __init__(self, Kp, Ki, Ts, y0=0.0):
        # Ti = Kp/Ki
        self.Kp = Kp
        self.Ki = Ki
        self.Ts = Ts
        self.integral = 0.0
        self.y = y0

    def step(self, error):
        self.integral += error * self.Ts
        self.y = self.Kp * error + self.Ki * self.integral
        return self.y

# Paramètres
To = 1e-3
Ts = 1e-5
Tsim = 1e-2
N = int(Tsim / Ts)
time = np.arange(0, Ts * N, Ts)

# Entrée de consigne
u = np.ones(N)

# Système et régulateur
Kp = 3 # 3 time more fast 
Ti = To 
Ki = Kp/Ti 
G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts)

y1 = []
y2 = []


for i in range(N):
    # without controler
    y_val = G1.step(u[i])
    y1.append(y_val)

    # claused loop 
    error = u[i] - G2.y
    control = C.step(error)
    y_val = G2.step(control)
    y2.append(y_val)


# Affichage
plt.figure(figsize=(10, 5))
plt.plot(time, y1, label='Sortie du système 1')
plt.plot(time, y2, label='Sortie du système 2')
plt.plot(time, u, '--', label='Consigne')
plt.xlabel('Temps (s)')
plt.ylabel('Amplitude')
plt.title('Réponse du système avec régulateur PI')
plt.legend()
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt

class FirstOrder:
    def __init__(self, To, Ts, y0=0.0):
        self.a = Ts / To
        self.y = y0

    def step(self, u):
        self.y += self.a * (u - self.y)
        return self.y

class PI_cont:
    def __init__(self, Kp, Ki, Ts, y0=0.0):
        # Ti = Kp/Ki
        self.Kp = Kp
        self.Ki = Ki
        self.Ts = Ts
        self.integral = 0.0
        self.y = y0

    def step(self, error):
        self.integral += error * self.Ts
        self.y = self.Kp * error + self.Ki * self.integral
        return self.y

# Paramètres

Ts = 1e-5
Tsim = 1e-2
N = int(Tsim / Ts)
time = np.arange(0, Ts * N, Ts)

# Entrée de consigne
u = np.ones(N)

# Système et régulateur
#Kp = 3 # 3 time more fast 
#Ti = To 
#Ki = Kp/Ti 

# 20% OVERSHOT 
Kp = 1.75;
Ki = 405; 

G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts)

y1 = []
y2 = []


for i in range(N):
    # without controler
    y_val = G1.step(u[i])
    y1.append(y_val)

    # claused loop 
    error = u[i] - G2.y
    control = C.step(error)
    y_val = G2.step(control)
    y2.append(y_val)


# Affichage
plt.figure(figsize=(10, 5))
plt.plot(time, y1, label='Sortie du système 1')
plt.plot(time, y2, label='Sortie du système 2')
plt.plot(time, u, '--', label='Consigne')
plt.xlabel('Temps (s)')
plt.ylabel('Amplitude')
plt.title('Réponse du système avec régulateur PI')
plt.legend()
plt.grid(True)

# %% [markdown]
# #### RC SIM

# %%
# Out:
# 0.02223752

# %%
import numpy as np
import matplotlib.pyplot as plt

# Params
Ts = 37e-6          # plant step
Ts_ctrl = 10*Ts     # controller update every 10*Ts

N = 10000
time = np.arange(0, Ts * N, Ts)

# Input
u = np.ones(N)

# System & controller
Kp = 3
Ti = To
Ki = Kp/Ti          # or Ki = Kp*Ts_ctrl/Ti if PI_cont expects discrete gain
G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C  = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts_ctrl)

y1, y2 = [], []
control2 = 0.0

for i in range(N):
    # open-loop
    y1.append(G1.step(u[i]))

    # closed-loop with controller update every 10 steps (ZOH in between)
    e = u[i] - G2.y
    if i % 10 == 0:
        control2 = C.step(e)
    y2.append(G2.step(control2))

# Plot
plt.figure(figsize=(10,5))
plt.plot(time, y1, label='System 1 (open-loop)')
plt.plot(time, y2, label='System 2 (PI, update each 10·Ts)')
plt.plot(time, u, '--', label='Setpoint')
plt.xlabel('Time (s)'); plt.ylabel('Amplitude')
plt.title('First-order response with PI')
plt.legend(); plt.tight_layout()
plt.show()

# %% [raw]
# // 20% of overshot SINCE To = 0.02223752
# const float Kp = 1.75;
# const float Ki = 405;

# %%
import numpy as np
import matplotlib.pyplot as plt

# RC sys
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C


# Params
Ts = 37e-6          # plant step
Ts_ctrl = 10*Ts     # controller update every 10*Ts

N = 10000
time = np.arange(0, Ts * N, Ts)

# Input
u = np.ones(N)

# System & controller
Kp = 3
Ti = To
Ki = Kp/Ti          # or Ki = Kp*Ts_ctrl/Ti if PI_cont expects discrete gain

# 20% overshot 
Kp = 1.75;
Ki = 405;  


G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C  = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts_ctrl)

y1, y2 = [], []
control2 = 0.0

for i in range(N):
    # open-loop
    y1.append(G1.step(u[i]))

    # closed-loop with controller update every 10 steps (ZOH in between)
    e = u[i] - G2.y
    if i % 10 == 0:
        control2 = C.step(e)
    y2.append(G2.step(control2))

# Plot
plt.figure(figsize=(10,5))
plt.plot(time, y1, label='System 1 (open-loop)')
plt.plot(time, y2, label='System 2 (PI, update each 10·Ts)')
plt.plot(time, u, '--', label='Setpoint')
plt.xlabel('Time (s)'); plt.ylabel('Amplitude')
plt.title('First-order response with PI')
plt.legend(); plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# RC sys
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C

# Params
Ts = 37e-6          # plant step
Ts_ctrl = 10*Ts     # controller update every 10*Ts

N = 10000
time = np.arange(0, Ts * N, Ts)

# Input
u = np.ones(N)

# System & controller
# methode 2
zeta = 1
wn = 3/To
Kp = 2*zeta*wn*To-1
Ti=Kp/(To*wn**2)



G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C  = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts_ctrl)

y1, y2 = [], []
control2 = 0.0

for i in range(N):
    # open-loop
    y1.append(G1.step(u[i]))

    # closed-loop with controller update every 10 steps (ZOH in between)
    e = u[i] - G2.y
    if i % 10 == 0:
        control2 = C.step(e)
    y2.append(G2.step(control2))

# Plot
plt.figure(figsize=(10,5))
plt.plot(time, y1, label='System 1 (open-loop)')
plt.plot(time, y2, label='System 2 (PI, update each 10·Ts)')
plt.plot(time, u, '--', label='Setpoint')
plt.xlabel('Time (s)'); plt.ylabel('Amplitude')
plt.title('First-order response with PI')
plt.legend(); plt.tight_layout()
plt.show()

# %%
np.array(y2).max()
# Out:
# np.float64(1.0551464971272853)

# %%
# Ti*wn << 1
Ti*wn
# Out:
# 1.6666666666666665

# %%
import numpy as np
import matplotlib.pyplot as plt

class FirstOrder:
    def __init__(self, To, Ts, y0=0.0):
        self.a = Ts / To
        self.y = y0

    def step(self, u):
        self.y += self.a * (u - self.y)
        return self.y

class PI_cont:
    def __init__(self, Kp, Ki, Ts, y0=0.0):
        # Ti = Kp/Ki
        self.Kp = Kp
        self.Ki = Ki
        self.Ts = Ts
        self.integral = 0.0
        self.y = y0

    def step(self, error):
        self.integral += error * self.Ts
        self.y = self.Kp * error + self.Ki * self.integral
        return self.y




import numpy as np
import matplotlib.pyplot as plt

# RC sys
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C


# Params
Ts = 37e-6          # plant step
Ts_ctrl = 10*Ts     # controller update every 10*Ts

N = 10000
time = np.arange(0, Ts * N, Ts)

# Input
u = np.ones(N)

# System & controller
Kp = 3
Ti = To
Ki = Kp/Ti          # or Ki = Kp*Ts_ctrl/Ti if PI_cont expects discrete gain

# 20% overshot 
Kp = 1.75;
Ki = 405;  


G1 = FirstOrder(To, Ts)
G2 = FirstOrder(To, Ts)
C  = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts_ctrl)

y1, y2 = [], []
control2 = 0.0

for i in range(N):
    # open-loop
    y1.append(G1.step(u[i]))

    # closed-loop with controller update every 10 steps (ZOH in between)
    e = u[i] - G2.y
    if i % 10 == 0:
        control2 = C.step(e)
    y2.append(G2.step(control2))

# Plot
plt.figure(figsize=(10,5))
plt.plot(time, y1, label='System 1 (open-loop)')
plt.plot(time, y2, label='System 2 (PI, update each 10·Ts)')
plt.plot(time, u, '--', label='Setpoint')
plt.xlabel('Time (s)'); plt.ylabel('Amplitude')
plt.title('First-order response with PI')
plt.legend(); plt.tight_layout()
plt.show()

# %%
# Params
Ts = 37e-6          # plant step
Ts_ctrl = 10*Ts     # controller update every 10*Ts

# %%
N = 10000
time = np.arange(0, Ts * N, Ts)

# Input
u = np.ones(N)

# %% [markdown]
# ### ONE CLASS

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class FirstOrder:
    def __init__(self, To, Ts, y0=0.0):
        self.a = Ts / To
        self.y = y0

    def step(self, u):
        self.y += self.a * (u - self.y)
        return self.y

class PI_cont:
    def __init__(self, Kp, Ki, Ts, y0=0.0):
        # Ti = Kp/Ki
        self.Kp = Kp
        self.Ki = Ki
        self.Ts = Ts
        self.integral = 0.0
        self.y = y0

    def step(self, error):
        self.integral += error * self.Ts
        self.y = self.Kp * error + self.Ki * self.integral
        return self.y
        
class sim_first_1_controller_PI: 
    def __init__(self, Ts_sim, Ts_ctrl, Kp, Ki):
        self.Ts_sim = Ts_sim
        self.Ts_ctrl = Ts_ctrl
        self.Kp = Kp 
        self.Ki = Ki
    def sim(self, u):
        N = len(u)
        Ts = self.Ts_sim
        Ts_ctrl = self.Ts_ctrl
        Ts_n = int(Ts_ctrl/Ts)


        G1 = FirstOrder(To, Ts)
        G2 = FirstOrder(To, Ts)
        C  = PI_cont(Kp=Kp, Ki=Ki, Ts=Ts_ctrl)
        
        y1, y2 = [], []
        control2 = 0.0
        
        for i in range(N):
            # open-loop
            y1.append(G1.step(u[i]))
        
            # closed-loop with controller update every 10 steps (ZOH in between)
            e = u[i] - G2.y
            if i % Ts_n  == 0:
                control2 = C.step(e)
            y2.append(G2.step(control2))
        return np.array(y1), np.array(y2)

# %%
# RC sys
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C

# System & controller
Kp = 3
Ti = To
Ki = Kp/Ti         

 
# simulation params
Ts_sim = 1e-6
Ts_ctrl = 100*Ts_sim

Sim_Model= sim_first_1_controller_PI(Ts_sim = Ts_sim , Ts_ctrl=Ts_ctrl, Kp=Kp, Ki=Ki)

# %%
Tsimulation  = 0.1

# %%
N = int(Tsimulation/Ts_sim)
time = np.arange(0, Ts_sim  * N, Ts_sim )
u = np.ones(N)
u[0:N//10]=0
y1, y2 = Sim_Model.sim(u)

# %%
# Plot
plt.figure(figsize=(7,4))
plt.plot(time, y1, label='System 1 (open-loop)')
plt.plot(time, y2, label='System 2 (PI, update each 10·Ts)')
plt.plot(time, u, '--', label='Setpoint')
plt.xlabel('Time (s)'); plt.ylabel('Amplitude')
plt.title('First-order response with PI')
plt.legend(); plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # END

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1870676.0  129.0
# 1     1870810.0  129.0
# 2     1870942.0  130.0
# 3     1871074.0  131.0
# 4     1871206.0  132.0
# ...         ...    ...
# 9995  3187397.0   51.0
# 9996  3187528.0   51.0
# 9997  3187660.0   51.0
# 9998  3187791.0   51.0
# 9999  3187923.0   51.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(68.26212621262127)

# %%
#df.to_csv("dfPI.csv")

# %%
df = pd.read_csv("df.csv")

# %%
df.plot(x="t", y="v")
plt.grid()
#plt.ylim([None , 100])

# %%
df.t.diff()
# Out:
# 0        NaN
# 1       32.0
# 2       31.0
# 3       31.0
# 4       31.0
#         ...
# 9995    31.0
# 9996    31.0
# 9997    31.0
# 9998    31.0
# 9999    31.0
# Name: t, Length: 10000, dtype: float64

# %%
df.t=(df.t-df.t.iloc[0])*1e-6

# %%
df.plot(x="t", y="v")
plt.grid()
lim = 0.01
plt.ylim([-lim, lim])
# Out:
# (-0.01, 0.01)

# %%
m= df.v>lim
i = int(m[m].index[0])
t0= df.loc[i, "t"]

# %%
n= len(df)
E0= df[(9*n)//10: n].v.mean()

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C

# %%
vsim= 1-np.exp(-(df.t-t0)/To)
vsim*=E0
df["v2"]=vsim

# %%
df.plot(x="t", y=["v", "v2"])
plt.grid()

# %%
#include "driver/adc.h"
#include <Arduino.h>  // Required for ESP32 LEDC functions
#include "driver/ledc.h"

#define INP 14   // ADC2_CHANNEL_6
#define pwmPin 25
//#define PWM 25
#define PWM_GPIO 25
#include "driver/ledc.h"

#define PWM_GPIO 25


#define N 10000




// PWM configuration
const int freq = 100000;     // 100 kHz
const int ledChannel = 0;    // LEDC channel (0-15)
const int resolution = 8;    // 8-bit resolution (0-255)



int tab[N];
unsigned long ttab[N];//micros()

void setup() {
  Serial.begin(115200);
  //pinMode(PWM, OUTPUT); 
  adc2_config_channel_atten(ADC2_CHANNEL_6, ADC_ATTEN_DB_11); // GPIO14, 0-3.3V



  // Configure PWM timer: 100 kHz, 8-bit resolution
  ledc_timer_config_t t = {
    .speed_mode = LEDC_LOW_SPEED_MODE,
    .duty_resolution = LEDC_TIMER_8_BIT,
    .timer_num = LEDC_TIMER_0,
    .freq_hz = 100000,
    .clk_cfg = LEDC_AUTO_CLK
  };
  ledc_timer_config(&t);

  // Configure PWM channel
  ledc_channel_config_t c = {
    .gpio_num = PWM_GPIO,
    .speed_mode = LEDC_LOW_SPEED_MODE,
    .channel = LEDC_CHANNEL_0,
    .timer_sel = LEDC_TIMER_0,
    .duty = 0,  // 20% of 255
    .hpoint = 0
  };
  ledc_channel_config(&c);


}

void loop() {
  // wait for user to send '#'
  while (true) {
    if (Serial.available() > 0) {
      char c = Serial.read();
      if (c == '#') break; // exit loop when '#' is received
    }
  }



      ledc_set_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0, 51);
    ledc_update_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0);


  // Sampling loop
  for(int i = 0; i < N; i++){

    int val;
    adc2_get_raw(ADC2_CHANNEL_6, ADC_WIDTH_BIT_12, &val);  // ADC2 read
    tab[i] = val;
      ttab[i] = micros();  // sample index
  }
      ledc_set_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0, 0);
    ledc_update_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0);
  //digitalWrite(PWM, 0);

  // Print after sampling — safe for ADC2
  for(int i = 0; i < N; i++){
    Serial.print(ttab[i]);
    Serial.print("\t");
    Serial.println(tab[i]);
  }

  Serial.print("END");
  while(1); // stop here
}

# %%
#include "driver/adc.h"
#include <Arduino.h>  // Required for ESP32 LEDC functions
#include "driver/ledc.h"

#define INP 14   // ADC2_CHANNEL_6
#define pwmPin 25
//#define PWM 25
#define PWM_GPIO 25
#include "driver/ledc.h"

#define PWM_GPIO 25


#define N 10000




// PWM configuration
const int freq = 100000;     // 100 kHz
const int ledChannel = 0;    // LEDC channel (0-15)
const int resolution = 8;    // 8-bit resolution (0-255)



int tab[N];
int ttab[N];

void setup() {
  Serial.begin(115200);
  //pinMode(PWM, OUTPUT); 
  adc2_config_channel_atten(ADC2_CHANNEL_6, ADC_ATTEN_DB_11); // GPIO14, 0-3.3V



  // Configure PWM timer: 100 kHz, 8-bit resolution
  ledc_timer_config_t t = {
    .speed_mode = LEDC_LOW_SPEED_MODE,
    .duty_resolution = LEDC_TIMER_8_BIT,
    .timer_num = LEDC_TIMER_0,
    .freq_hz = 100000,
    .clk_cfg = LEDC_AUTO_CLK
  };
  ledc_timer_config(&t);

  // Configure PWM channel
  ledc_channel_config_t c = {
    .gpio_num = PWM_GPIO,
    .speed_mode = LEDC_LOW_SPEED_MODE,
    .channel = LEDC_CHANNEL_0,
    .timer_sel = LEDC_TIMER_0,
    .duty = 0,  // 20% of 255
    .hpoint = 0
  };
  ledc_channel_config(&c);


}

void loop() {
  // wait for user to send '#'
  while (true) {
    if (Serial.available() > 0) {
      char c = Serial.read();
      if (c == '#') break; // exit loop when '#' is received
    }
  }



      ledc_set_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0, 51);
    ledc_update_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0);


  // Sampling loop
  for(int i = 0; i < N; i++){
    ttab[i] = i;  // sample index
    int val;
    adc2_get_raw(ADC2_CHANNEL_6, ADC_WIDTH_BIT_12, &val);  // ADC2 read
    tab[i] = val;
  }
      ledc_set_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0, 0);
    ledc_update_duty(LEDC_LOW_SPEED_MODE, LEDC_CHANNEL_0);
  //digitalWrite(PWM, 0);

  // Print after sampling — safe for ADC2
  for(int i = 0; i < N; i++){
    Serial.print(ttab[i]);
    Serial.print("\t");
    Serial.println(tab[i]);
  }

  Serial.print("END");
  while(1); // stop here
}

# %%
#define DAC1 25       //Define Pin no 25 for DAC Output

void setup(){}

void loop() {
  dacWrite(25,125); //1.608v 3.271 not 3.3v
  dacWrite(26,200); //2.509v
/*
* here we are using 8 bit DAC so 2^8=255
* Means 0 = 0V and 255=3.3V
*/
 for (int i=0; i<255; i++){
   dacWrite(DAC1, i);          //write on DAC Pin
 }

 for (int i=255; i>=0; i--){
   dacWrite(DAC1, i);          //write on DAC Pin
 }
}

# %%
#include "driver/adc.h"

#define INP 14   // ADC2_CHANNEL_6
#define PWM 25
#define N 10000

int tab[N];
int ttab[N];

void setup() {
  Serial.begin(115200);
  pinMode(PWM, OUTPUT); 
  adc2_config_channel_atten(ADC2_CHANNEL_6, ADC_ATTEN_DB_11); // GPIO14, 0-3.3V
}

void loop() {
  digitalWrite(PWM, 1);

  // Sampling loop
  for(int i = 0; i < N; i++){
    ttab[i] = i;  // sample index
    int val;
    adc2_get_raw(ADC2_CHANNEL_6, ADC_WIDTH_BIT_12, &val);  // ADC2 read
    tab[i] = val;
  }

  digitalWrite(PWM, 0);

  // Print after sampling — safe for ADC2
  for(int i = 0; i < N; i++){
    Serial.print(ttab[i]);
    Serial.print("\t");
    Serial.println(tab[i]);
  }

  while(1); // stop here
}

# %% [raw]
# #include "driver/adc.h"
#
# #define INP 14   // ADC2_CHANNEL_6
# #define PWM 25
# #define N 10000
#
# int tab[N];
# int ttab[N];
#
# void setup() {
#   Serial.begin(115200);
#   pinMode(PWM, OUTPUT);
#   adc2_config_channel_atten(ADC2_CHANNEL_6, ADC_ATTEN_DB_11); // GPIO14, 0-3.3V
# }
#
# void loop() {
#   // wait for user to send '#'
#   while (true) {
#     if (Serial.available() > 0) {
#       char c = Serial.read();
#       if (c == '#') break; // exit loop when '#' is received
#     }
#   }
#
#
#   digitalWrite(PWM, 1);
#
#   // Sampling loop
#   for(int i = 0; i < N; i++){
#     ttab[i] = i;  // sample index
#     int val;
#     adc2_get_raw(ADC2_CHANNEL_6, ADC_WIDTH_BIT_12, &val);  // ADC2 read
#     tab[i] = val;
#   }
#
#   digitalWrite(PWM, 0);
#
#   // Print after sampling — safe for ADC2
#   for(int i = 0; i < N; i++){
#     Serial.print(ttab[i]);
#     Serial.print("\t");
#     Serial.println(tab[i]);
#   }
#
#   while(1); // stop here
# }

# %% [raw]
# #include "driver/adc.h"
#
# #define INP 14   // ADC2_CHANNEL_6
# #define PWM 25
# #define N 3000
#
# int tab[N];
# int ttab[N];
#
# void setup() {
#   Serial.begin(115200);
#   pinMode(PWM, OUTPUT);
#   adc2_config_channel_atten(ADC2_CHANNEL_6, ADC_ATTEN_DB_11); // GPIO14, 0-3.3V
# }
#
# void loop() {
#   // wait for user to send '#'
#   while (true) {
#     if (Serial.available() > 0) {
#       char c = Serial.read();
#       if (c == '#') break; // exit loop when '#' is received
#     }
#   }
#
#
#   digitalWrite(PWM, 1);
#
#   // Sampling loop
#   for(int i = 0; i < N; i++){
#     ttab[i] = i;  // sample index
#     int val;
#     adc2_get_raw(ADC2_CHANNEL_6, ADC_WIDTH_BIT_12, &val);  // ADC2 read
#     tab[i] = val;
#   }
#
#   digitalWrite(PWM, 0);
#
#   // Print after sampling — safe for ADC2
#   for(int i = 0; i < N; i++){
#     Serial.print(ttab[i]);
#     Serial.print("\t");
#     Serial.println(tab[i]);
#   }
#
#   Serial.print("END");
#   while(1); // stop here
# }

# %% [markdown]
# # PI ARDUINO

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // for adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
# // ----------------- Plant & PI -----------------
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;               // speed-up factor
# const float Kp = n;
# const float Ki = Kp / To;            // 1/s
#
# // ----------------- Targets & scaling -----------------
# const float V_SUPPLY  = 3.3f;        // effective high level
# const float v_target  = 1.10f;       // target voltage (V)
# const float ADC_SCALE = V_SUPPLY / 4095.0f;  // 12-bit -> volts
#
# // ----------------- State & buffers -----------------
# float integral = 0.0f;
# int tab[N];                // store PWM duty [0..255]
# unsigned long ttab[N];     // store time stamps (micros)
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3V on GPIO14
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC one-liner (replaces ledcSetup/ledcAttachPin from v2.x)
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // --- Preserve your start trigger ---
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
# void loop() {
#   uint32_t t_prev = micros();
#
#   // --------- Sampling loop (fast as possible) ----------
#   for (int i = 0; i < N; i++) {
#     // Time stamp at start of iteration
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;
#
#     // Sample time
#     float dt = (t_now - t_prev) * 1e-6f;  // seconds
#     t_prev = t_now;
#
#     // PI regulator (volts in, volts out)
#     float e = v_target - v_meas;
#     integral += e * dt;
#     float v_cmd = Kp * e + Ki * integral;
#
#     // Clamp to 0..V_SUPPLY and convert to duty 0..255
#     if (v_cmd < 0.0f)     v_cmd = 0.0f;
#     if (v_cmd > V_SUPPLY) v_cmd = V_SUPPLY;
#     int duty = (int)lroundf((v_cmd / V_SUPPLY) * 255.0f);
#
#     // Apply PWM (v3.x API writes by pin)
#     ledcWrite(PWM_PIN, duty);
#
#     // --- Preserve your logging buffers ---
#     tab[i]  = duty;
#     ttab[i] = t_now;
#   }
#
#   // After capture, stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1870930.0    0.0
# 1     1871038.0    0.0
# 2     1871075.0    0.0
# 3     1871111.0    0.0
# 4     1871151.0    0.0
# ...         ...    ...
# 9995  2236433.0  239.0
# 9996  2236470.0  240.0
# 9997  2236506.0  240.0
# 9998  2236542.0  240.0
# 9999  2236579.0  240.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.43144314431441)

# %%
df.to_csv("dfPI.csv")

# %%
df = pd.read_csv("dfPI.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %%
v= df.v.values
v= v-v.max()
v= v/v.min()
n= len(v)
E= v[(9*n)//10:].mean()
v= v/E
t = (df.t*1e-6).values

plt.plot(t, v)


v2 = (1-np.exp(-t/To))
plt.plot(t, v2)

v2 = (1-np.exp(-t*3/To))
plt.plot(t, v2,linestyle= "--", c= "r")

# %% [markdown]
# # PI ARDUINO pols cancel

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
# // ----------------- Plant & PI -----------------
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;               // speed-up factor
# const float Kp = n;
# const float Ki = Kp / To;            // 1/s
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# const float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
# float integral = 0.0f;
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
# void loop() {
#   uint32_t t_prev = micros();
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#
#     // PI controller (volts in, volts out)
#     float e = v_target - v_meas;
#     integral += e * dt;
#     float v_cmd = Kp * e + Ki * integral;
#
#     // Clamp to 0..V_SUPPLY and convert to duty 0..255
#     if (v_cmd < 0.0f)     v_cmd = 0.0f;
#     if (v_cmd > V_SUPPLY) v_cmd = V_SUPPLY;
#     int duty = (int)lroundf((v_cmd / V_SUPPLY) * 255.0f);
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1871144.0    0.0
# 1     1871252.0    0.0
# 2     1871290.0    0.0
# 3     1871326.0    0.0
# 4     1871363.0    0.0
# ...         ...    ...
# 9995  2237006.0  363.0
# 9996  2237044.0  363.0
# 9997  2237081.0  363.0
# 9998  2237117.0  363.0
# 9999  2237153.0  364.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.3954395439544)

# %%
df.to_csv("dfPI2.csv")

# %%
df = pd.read_csv("dfPI2.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %%
v= df.v.values
v= v-v.min()
v= v/v.max()
n= len(v)
E= v[(9*n)//10:].mean()
v= v/E
t = (df.t*1e-6).values

plt.plot(t, v)


v2 = (1-np.exp(-t/To))
plt.plot(t, v2)

v2 = (1-np.exp(-t*3/To))
plt.plot(t, v2,linestyle= "--", c= "r")

# %% [markdown]
# # PI ARDUINO 20% overshot

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
# // ----------------- Plant & PI -----------------
# // 20% of overshot SINCE To = 0.02223752
# const float Kp = 1.75;
# const float Ki = 405;
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# const float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
# float integral = 0.0f;
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
# void loop() {
#   uint32_t t_prev = micros();
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#
#     // PI controller (volts in, volts out)
#     float e = v_target - v_meas;
#     integral += e * dt;
#     float v_cmd = Kp * e + Ki * integral;
#
#     // Clamp to 0..V_SUPPLY and convert to duty 0..255
#     if (v_cmd < 0.0f)     v_cmd = 0.0f;
#     if (v_cmd > V_SUPPLY) v_cmd = V_SUPPLY;
#     int duty = (int)lroundf((v_cmd / V_SUPPLY) * 255.0f);
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1871334.0    0.0
# 1     1871438.0    0.0
# 2     1871476.0    0.0
# 3     1871512.0    0.0
# 4     1871549.0    0.0
# ...         ...    ...
# 9995  2237069.0  363.0
# 9996  2237105.0  363.0
# 9997  2237142.0  363.0
# 9998  2237182.0  363.0
# 9999  2237218.0  363.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.40794079407942)

# %%
df.to_csv("dfPI3.csv")

# %%
df = pd.read_csv("dfPI3.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %%
df.t.diff()
# Out:
# 0         NaN
# 1       104.0
# 2        38.0
# 3        36.0
# 4        37.0
#         ...
# 9995     36.0
# 9996     36.0
# 9997     37.0
# 9998     40.0
# 9999     36.0
# Name: t, Length: 10000, dtype: float64

# %%
v= df.v.values
v= v-v.min()
v= v/v.max()
n= len(v)
E= v[(9*n)//10:].mean()
v= v/E
t = (df.t*1e-6).values

plt.plot(t, v)


v2 = (1-np.exp(-t/To))
plt.plot(t, v2)

#v2 = (1-np.exp(-t*3/To))
#plt.plot(t, v2,linestyle= "--", c= "r")








Kp = 1.75;
Ki = 405;  
wn= np.sqrt(Ki/To)
m = (1+Kp)/(2*np.sqrt(Ki*To))
wd = wn*np.sqrt(1-m**2)
#y = 1-np.exp(-m*wn*t)*np.sin(wd*t+np.arctan(np.sqrt(1-m**2)/m))/np.sqrt(1-m**2)

y = 1-np.exp(-m*wn*t)*np.sin(wd*t + np.arctan2(np.sqrt(1-m**2), m)) / np.sqrt(1 - m**2)

plt.plot(t, y,linestyle= "--", c= "r")

# %%
v.max(), y.max()
# Out:
# (np.float64(1.293607651551641), np.float64(1.19802220809595))

# %% [markdown]
# # PI ARDUINO CHANGE REF

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
# // ----------------- Plant & PI -----------------
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;               // speed-up factor
# const float Kp = n;
# const float Ki = Kp / To;            // 1/s
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
# float integral = 0.0f;
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
# void loop() {
#   uint32_t t_prev = micros();
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#     if (i>N/3) v_target= 0.3;
#     // PI controller (volts in, volts out)
#     float e = v_target - v_meas;
#     integral += e * dt;
#     float v_cmd = Kp * e + Ki * integral;
#
#     // Clamp to 0..V_SUPPLY and convert to duty 0..255
#     if (v_cmd < 0.0f)     v_cmd = 0.0f;
#     if (v_cmd > V_SUPPLY) v_cmd = V_SUPPLY;
#     int duty = (int)lroundf((v_cmd / V_SUPPLY) * 255.0f);
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1873272.0    0.0
# 1     1873374.0    0.0
# 2     1873411.0    0.0
# 3     1873448.0    0.0
# 4     1873484.0    0.0
# ...         ...    ...
# 9995  2239567.0  273.0
# 9996  2239603.0  272.0
# 9997  2239640.0  272.0
# 9998  2239676.0  275.0
# 9999  2239713.0  273.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.35223522352234)

# %%
df.to_csv("dfPI4.csv")

# %%
df = pd.read_csv("dfPI4.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %% [markdown]
# # PI ARDUINO CHANGE REF 2

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
# // ----------------- Plant & PI -----------------
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;               // speed-up factor
# const float Kp = n;
# const float Ki = Kp / To;            // 1/s
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
# float integral = 0.0f;
# float integral_ = 0.0f;
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
# void loop() {
#   uint32_t t_prev = micros();
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#     if (i>N/3) v_target= 0.3;
#
#
#     // PI controller (volts in, volts out)
#     float v_cmd_, v_cmd;
#     float v_cmd_upper   = 3.3f;
#     float v_cmd_lower = 0.0f;
#
#     float e = v_target - v_meas;
#     integral += e * dt;
#     v_cmd_ = Kp * e + Ki * integral;
#
#     // Clamp to 0..V_SUPPLY and convert to duty 0..255
#     if (v_cmd_ > v_cmd_upper) v_cmd= v_cmd_upper;
#     else if (v_cmd_ < v_cmd_lower) v_cmd= v_cmd_lower;
#     else
#     {
#       v_cmd = v_cmd_ ;
#       integral = integral_;
#     }
#
#
#
#     int duty = (int)lroundf((v_cmd / V_SUPPLY) * 255.0f);
#
#
#
#
#
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1871030.0    0.0
# 1     1871137.0    0.0
# 2     1871178.0    0.0
# 3     1871214.0    0.0
# 4     1871250.0    0.0
# ...         ...    ...
# 9995  2238495.0  181.0
# 9996  2238532.0  181.0
# 9997  2238568.0  180.0
# 9998  2238605.0  181.0
# 9999  2238641.0  182.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.23522352235224)

# %%
df.to_csv("dfPI5.csv")

# %%
df = pd.read_csv("dfPI5.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %% [markdown]
# # PI ARDUINO CHANGE REF 3

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
#
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
#
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
#
#
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;
#
# ////////////////////////  PI controller /////////////////////////
# float integral = 0.0f;
# float integral_ = 0.0f;
# float PI_cont(float v_target , float v_meas_in, float dt){
#
#     const float Kp = n;
#     const float Ki = Kp / To;
#
#     float PI_out_;
#     float PI_out_upper   = 1.0f;
#     float PI_out_lower = 0.0f;
#
#     float  PI_out;
#
#     float e = v_target - v_meas_in;
#     integral += e * dt;
#     PI_out_ = Kp * e + Ki * integral;
#
#     // Clamp
#     if (PI_out_ > PI_out_upper) PI_out= PI_out_upper;
#     else if (PI_out_ < PI_out_lower) PI_out= PI_out_lower;
#     else
#     {
#       PI_out = PI_out_ ;
#       integral = integral_;
#     }
#     return PI_out;
# }
# ///////////////////////////////////////////////////////////////////////
#
# // void main_loop(void){}
# /*
# const int sampling_time_us = 100;
# while (1){
#   uint32_t t_now = micros();
#   // CODE HERE
#   while ((micros()-t_now)<sampling_time_us);
#
# }
# */
#
# void loop() {
#   uint32_t t_prev = micros();
#   float  PI_out;
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#     if (i>N/3) v_target= 0.3;
#
#
#
#
#     PI_out = PI_cont(v_target , v_meas,dt);
#
#     int duty = (int)lroundf(PI_out  * 255.0f);
#
#
#
#
#
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
ser.close()

# %%
import serial
import time

# Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
ser = serial.Serial('COM5', 115200, timeout=1)  # baud rate must match Arduino
time.sleep(2)  # wait for Arduino reset
arr=[]


# Send '#' to Arduino
ser.write(b"#")  # sends the byte '#' to Arduino


try:
    while True:
        line = ser.readline().decode('utf-8').strip()  # read a line
        if line:
            #print(line)
            arr.append(line)
        if "END" in line:
            break
except KeyboardInterrupt:
    ser.close()

# %%
ser.close()

# %%
2**12
# Out:
# 4096

# %%
prin = False 
vol=[]
time=[]
for i in range(len(arr)):
    l = arr[i]
    if 'END' in l: 
        break
    if "entry" in l:
        prin=True 

    elif prin: 
        vals = arr[i].split('\t')
        time .append(float(vals[0]))
        vol .append(float(vals[1]))
plt.plot(time, vol)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import pandas as pd

# %%
df=pd.DataFrame({"t":time,"v":vol})
df
# Out:
#               t      v
# 0     1870291.0    0.0
# 1     1870398.0    0.0
# 2     1870434.0    0.0
# 3     1870471.0    0.0
# 4     1870507.0    0.0
# ...         ...    ...
# 9995  2236006.0  240.0
# 9996  2236045.0  239.0
# 9997  2236081.0  240.0
# 9998  2236117.0  240.0
# 9999  2236158.0  238.0
#
# [10000 rows x 2 columns]

# %%
100-(df.t.diff().mean()-100)
# Out:
# np.float64(163.4096409640964)

# %%
#df.to_csv("dfPI5.csv")

# %%
#df = pd.read_csv("dfPI5.csv")

# %%
df.t=df.t-df.t.iloc[0]
df.plot(x='t',y='v')
# Out:
# <Axes: xlabel='t'>

# %% [markdown]
# # PI ARDUINO CHANGE REF 4

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
R=4660#meas
C=4.772e-6# nom 4.7uF
To=R*C
To
# Out:
# 0.02223752

# %% [raw]
# float To = 0.02223752
# float n= 3 // 3 time more fast
# float Kp = n
# float Ti = To
# float Ki  =Kp/Ti

# %%
int(255*1.1/3.3)
# Out:
# 85

# %% [raw]
# #include <Arduino.h>
# #include "driver/adc.h"  // adc2_get_raw()
#
# // ----------------- Pins -----------------
# #define ADC_PIN_CH  ADC2_CHANNEL_6   // GPIO14 (ADC2)
# #define PWM_PIN     25               // PWM output
#
# // ----------------- Capture size -----------------
# constexpr int N = 10000;
#
# // ----------------- PWM (v3.x API) -----------------
# const uint32_t PWM_FREQ = 100000;    // 100 kHz
# const uint8_t  PWM_RES  = 8;         // 8-bit (0..255)
#
#
#
# // ----------------- Targets & scaling -----------------
# // v_target: desired RC output voltage (in volts)
# float v_target   = 0.40f;      // volts
#
# // Convert raw ADC (12-bit) to volts for ADC2 @ 11 dB (~0..3.3 V)
# const float V_SUPPLY   = 3.3f;               // effective PWM high voltage
# const float ADC_SCALE  = V_SUPPLY / 4095.0f; // raw -> volts
#
# // Choose the top-of-scale for logging in tab[] (0..1000):
# //   - Set to 1.10f to match your 1.1 V scaling
# //   - Set to 3.30f if you want the log scaled to 3.3 V
# const float V_SCALE_TOP = 1.10f;     // volts -> mapped to 0..1000
#
# // ----------------- State & buffers -----------------
#
# int tab[N];                // store MEASUREMENT scaled to 0..1000 (not duty)
# unsigned long ttab[N];     // store time stamps (micros)
#
# static inline int clampi(int x, int lo, int hi) {
#   return (x < lo) ? lo : (x > hi) ? hi : x;
# }
#
# void setup() {
#   Serial.begin(115200);
#
#   // ADC ~0..3.3 V on GPIO14 with 11 dB attenuation
#   adc2_config_channel_atten(ADC_PIN_CH, ADC_ATTEN_DB_11);
#
#   // v3.x LEDC API: attach pin with desired freq & resolution
#   if (!ledcAttach(PWM_PIN, PWM_FREQ, PWM_RES)) {
#     Serial.println("LEDC attach failed");
#     while (1) {}
#   }
#
#   // Wait for '#' start trigger (preserved)
#   while (true) {
#     if (Serial.available() > 0 && Serial.read() == '#') break;
#   }
# }
#
#
#
# const float To = 0.0222f;            // RC time constant (s)
# const float n  = 3.0f;
#
# ////////////////////////  PI controller /////////////////////////
# float integral = 0.0f;
# float integral_ = 0.0f;
# float PI_cont(float v_target , float v_meas_in, float dt){
#
#     const float Kp = n;
#     const float Ki = Kp / To;
#
#     float PI_out_;
#     float PI_out_upper   = 1.0f;
#     float PI_out_lower = 0.0f;
#
#     float  PI_out;
#
#     float e = v_target - v_meas_in;
#     integral += e * dt;
#     PI_out_ = Kp * e + Ki * integral;
#
#     // Clamp
#     if (PI_out_ > PI_out_upper) PI_out= PI_out_upper;
#     else if (PI_out_ < PI_out_lower) PI_out= PI_out_lower;
#     else
#     {
#       PI_out = PI_out_ ;
#       integral = integral_;
#     }
#     return PI_out;
# }
# ///////////////////////////////////////////////////////////////////////
#
# // void main_loop(void){}
# /*
# const int sampling_time_us = 100;
# while (1){
#   uint32_t t_now = micros();
#   // CODE HERE
#   while ((micros()-t_now)<sampling_time_us);
#
# }
# */
#
# void loop() {
#   uint32_t t_prev = micros();
#   float  PI_out;
#
#   // --------- Sampling loop ----------
#   for (int i = 0; i < N; i++) {
#     uint32_t t_now = micros();
#
#     // Measure RC output (volts)
#     int raw = 0;
#     adc2_get_raw(ADC_PIN_CH, ADC_WIDTH_BIT_12, &raw);
#     float v_meas = raw * ADC_SCALE;   // volts
#
#     // Sample time for PI
#     float dt = (t_now - t_prev) * 1e-6f;
#     t_prev = t_now;
#     if (i>N/3) v_target= 0.3;
#
#
#
#
#     PI_out = PI_cont(v_target , v_meas,dt);
#
#     int duty = (int)lroundf(PI_out  * 255.0f);
#
#
#
#
#
#
#     // Apply PWM
#     ledcWrite(PWM_PIN, duty);
#
#     // --- LOGGING: store MEASUREMENT (not duty), scaled to 0..1000 ---
#     // Scale v_meas so that V_SCALE_TOP -> 1000
#     float scaled = (V_SCALE_TOP > 0.0f) ? (v_meas / V_SCALE_TOP) : 0.0f;
#     int meas1000 = clampi((int)lroundf(scaled * 1000.0f), 0, 1000);
#
#     tab[i]  = meas1000;
#     ttab[i] = t_now;
#     while(micros() < t_now +50);
#   }
#
#   // Stop PWM and print (preserved format)
#   ledcWrite(PWM_PIN, 0);
#
#   for (int i = 0; i < N; i++) {
#     Serial.print(ttab[i]);
#     Serial.print('\t');
#     Serial.println(tab[i]);  // 0..1000 scaled measurement
#   }
#   Serial.println("END");
#
#   while (1) {}  // stop here
# }

# %%
#%pip install pyserial

# %%
import serial
import time
import matplotlib.pyplot as plt 
import numpy as np
def Get_Data(port = 'COM5', bps= 115200):
    # Replace 'COM3' with your Arduino port (on Linux it may be '/dev/ttyUSB0')
    ser = serial.Serial(port, bps, timeout=1)  # baud rate must match Arduino
    time.sleep(2)  # wait for Arduino reset
    arr=[]
    
    
    # Send '#' to Arduino
    ser.write(b"#")  # sends the byte '#' to Arduino
    
    
    try:
        while True:
            line = ser.readline().decode('utf-8').strip()  # read a line
            if line:
                #print(line)
                arr.append(line)
            if "END" in line:
                break
    except KeyboardInterrupt:
        ser.close()
    
    
    ser.close()
    return arr

# %% [raw]
# 2**12

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
# prin = False
# vol=[]
# time=[]
# for i in range(len(arr)):
#     l = arr[i]
#     if 'END' in l:
#         break
#     if "entry" in l:
#         prin=True
#
#     elif prin:
#         vals = arr[i].split('\t')
#         time .append(float(vals[0]))
#         vol .append(float(vals[1]))
# plt.plot(time, vol)
# plt.plot

# %%
import pandas as pd 
def arr_to_df(arr, cols = None):
    arr2= []
    for x in arr[::-1]: 
        if x=="END": 
            continue 
        try: 
            arr2.append(np.array(x.split('\t')).astype("int"))
        except: 
            break
    if cols is None: 
        df = pd.DataFrame(arr2)
    else : 
        df = pd.DataFrame(arr2, columns = cols)
    return df

# %%
arr =Get_Data( 'COM5')
df = arr_to_df(arr, cols =["t", "v"])
df.plot(x="t", y="v")
# Out:
# <Axes: xlabel='t'>

# %%
len(df)
# Out:
# 10000

# %%
df.iloc[:-9*len(df)//10].plot(x="t", y="v")
# Out:
# <Axes: xlabel='t'>

# %%
df.t.diff()
# Out:
# 0         NaN
# 1       -50.0
# 2       -51.0
# 3       -51.0
# 4       -50.0
#         ...
# 9995    -50.0
# 9996    -50.0
# 9997    -50.0
# 9998    -50.0
# 9999   -105.0
# Name: t, Length: 10000, dtype: float64

# %%
df.head()
# Out:
#          t    v
# 0  2371879  241
# 1  2371829  239
# 2  2371778  239
# 3  2371727  240
# 4  2371677  241
