# %% [raw]
# https://www.mouser.fr/datasheet/3/70/1/Infineon-IPW60R037CM8-DataSheet-v02_01-EN.pdf
#
#
# RDS (norm) RDS = 37mOhm
# 25 deg => 1 (37mOhm) at 10A ==> 370mV
# 125 deg ==> 1.9 (70.3mOhm) at 10A > 703mV
#
#
# Vf =0.7v 8A 125°C
# Vf= 0.83V 8A 25°C

# %% [markdown]
# <img width="600" src="data:image/png;base64,..." />

# %%
37*1.9
# Out:
# 70.3
