# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "2026-02-16_11-29-17-563.csv"
df=pd.read_csv(path)
t= df.time.values
vds=df.CH1.values
vgs = df.CH4.values

# %%
df.CH3.plot()
# Out:
# <Axes: >

# %%
# 2026-02-16_11-48-34-969

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = "2026-02-16_11-48-34-969.csv"
df=pd.read_csv(path)
t= df.time.values
vds=df.CH1.values
vgs = df.CH4.values	
df.CH1.plot()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
df.CH3.plot()
# Out:
# <Axes: >

# %%
path = "2026-02-16_11-55-19-204.csv"
df=pd.read_csv(path)
df.CH1.plot()
# Out:
# <Axes: >

# %%
V0 = df.CH1.mean()
V0
# Out:
# np.float64(0.9058331249999999)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path = "2026-02-16_11-54-09-770.csv"
df=pd.read_csv(path)
t= df.time.values
vds=df.CH1.values-V0 
vgs = df.CH4.values	
plt.plot(vds)# df.CH1.plot()

# %%
df.plot(x="time", y= ["CH1", "CH4"])
plt.xlim([0.305e-5,0.36e-5])
plt.grid()
