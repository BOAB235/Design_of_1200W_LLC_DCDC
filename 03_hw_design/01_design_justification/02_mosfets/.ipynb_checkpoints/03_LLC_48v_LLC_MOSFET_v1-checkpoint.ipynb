# %%
# imPORT LIBRARIES 
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from math import pi, sqrt
import handcalcs.render
import pandas as pd
import json 
# !pip install handcalcs

# %%
# CONFIGURATIONS
#help(handcalcs.set_option)
handcalcs.set_option("latex_block_start", "$")
handcalcs.set_option("latex_block_end", "$")
handcalcs.set_option("math_environment_end", "aligned")
handcalcs.set_option("use_scientific_notation",True)

# %% [markdown]
# ## Inputs and claculated parameters

# %%
with open("../01_llc_tank/04_outputs/inp_datas.json", "r", encoding="utf-8") as f:
    inp_datas = json.load(f)
print("Input datas:")
print("="*20)
display(inp_datas)

with open("../01_llc_tank/04_outputs/out_results.json", "r", encoding="utf-8") as f:
    out_datas = json.load(f)
print("Output datas:")
print("="*20)
display(out_datas)


# Load variables 
for key, value in inp_datas.items():
    globals()[key] = value
for key, value in out_datas.items():
    globals()[key] = value
# Out:
# Input datas:
# ====================
# {'V_In_min': 360.0,
#  'V_In_nom': 380.0,
#  'V_In_max': 400.0,
#  'Vo_min': 42.0,
#  'Vo_nom': 48.0,
#  'Vo_max': 54.0,
#  'Power': 1200.0,
#  'f_nom': 100000.0}
# Output datas:
# ====================
# {'Lnc': 3.0,
#  'Qec': 0.55,
#  'Cr_nF': 116.209,
#  'n': 4.0,
#  'Lr_uH': 21.797,
#  'Lm_uH': 65.392,
#  'fsw_min': 60170.0,
#  'fsw_max': 156220.0,
#  'Im_rms': 6.992,
#  'Io': 25.0,
#  'Ioe_rms': 7.636,
#  'Ios_rms': 30.545,
#  'Ir_rms': 10.354,
#  'L_second_uH': 4.087,
#  'Re_nom': 24.901,
#  'Re_110': 22.637,
#  'Cr': 1.16209e-07,
#  'Lr': 2.1796999999999998e-05,
#  'Lm': 6.539199999999999e-05}

# %%
arr=[]
for c in ["1","3","2"]:
    
    path = r"..\..\03_components\05_Mosfet\01_Primary\MouserSearchDownloadMosfet"+c+".csv"
 
    df = pd.read_csv(path)
    arr.append(df)
df= pd.concat(arr, axis = 0)
df = df[['Mfr Part Number', 'Mfr.',
       'Availability', 'Pricing', 
       'Technology', 'Mounting Style', 'Package/Case', 'Transistor Polarity',
        'Vds - Drain-Source Breakdown Voltage',
       'Id - Continuous Drain Current', 'Rds On - Drain-Source Resistance',
       'Vgs th - Gate-Source Threshold Voltage',
       'Qg - Gate Charge',  'Pd - Power Dissipation',
        ]]

# %%
list(df["Technology"].unique())
# Out:
# ['Si']

# %%
list(df["Mounting Style"].unique())
# Out:
# ['Through Hole']

# %%
list(df["Transistor Polarity"].unique())
# Out:
# ['N-Channel']

# %%
cols = list(df.columns)
for c in ["Technology", "Mounting Style", 
                             "Transistor Polarity"]:
    cols.remove(c)
df2= df[cols]

# %%
df3 = df2.copy() 
df3.loc[:,  "Pricing"] = df2["Pricing"].str.replace('="', "").str.replace(' €"', "").str.replace(',', ".")
df3.rename(columns={"Pricing": "Pricing €"}, inplace=True)

df3.loc[:,  "Vds - Drain-Source Breakdown Voltage"] = df2["Vds - Drain-Source Breakdown Voltage"].str.replace(' V', "")
df3.rename(columns={"Vds - Drain-Source Breakdown Voltage": "Vds (V)"}, inplace=True)


df3.loc[:,  "Id - Continuous Drain Current"] = df2["Id - Continuous Drain Current"].str.replace('="', "").str.replace(' A"', "")
df3.rename(columns={"Id - Continuous Drain Current": "Id A"}, inplace=True)


df3.loc[:,  "Rds On - Drain-Source Resistance"] = df2["Rds On - Drain-Source Resistance"].str.replace(' mOhms', "")
df3.rename(columns={"Rds On - Drain-Source Resistance": "Rds (mOhms)"}, inplace=True)

df3.loc[:,  "Vgs th - Gate-Source Threshold Voltage"] = df2["Vgs th - Gate-Source Threshold Voltage"].str.replace(' V', "")
df3.rename(columns={"Vgs th - Gate-Source Threshold Voltage": "Vgs th (V)"}, inplace=True)


df3.loc[:,  "Qg - Gate Charge"] = df2["Qg - Gate Charge"].str.replace(' nC', "")
df3.rename(columns={"Qg - Gate Charge": "Qg (nC)"}, inplace=True)


df3.loc[:,  "Pd - Power Dissipation"] = df2["Pd - Power Dissipation"].str.replace(' W', "")
df3.rename(columns={"Pd - Power Dissipation": "Pd - Power Dissipation (W)"}, inplace=True)

df3
# Out:
#       Mfr Part Number                   Mfr.     Availability Pricing €  \
# 0    IPW60R099P7XKSA1  Infineon Technologies  1 347  In Stock      3.67
# 1   IPZA60R080P7XKSA1  Infineon Technologies    174  In Stock      4.03
# 2   IPZA60R099P7XKSA1  Infineon Technologies    310  In Stock      4.19
# 3         STW65N60DM6     STMicroelectronics    587  In Stock      4.59
# 4         STW48N60DM2     STMicroelectronics    477  In Stock      4.73
# ..                ...                    ...              ...       ...
# 20         STW48NM60N     STMicroelectronics  1 186  In Stock      6.89
# 21      FCH47N60-F133     onsemi / Fairchild    413  In Stock      6.90
# 22        STWA75N60M6     STMicroelectronics    496  In Stock      6.92
# 23        IPZ65R065C7  Infineon Technologies    221  In Stock      6.94
# 24        IPW60R070C6  Infineon Technologies  1 227  In Stock      6.95
#
#    Package/Case Vds (V) Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 0      TO-247-3     600   31          77          3      45
# 1      TO-247-4     600   37          69          3      51
# 2      TO-247-4     600   31          77          3      45
# 3      TO-247-3     600   38          71       3.25      54
# 4      TO-247-3     600   40          65          3      70
# ..          ...     ...  ...         ...        ...     ...
# 20     TO-247-3     600   39          70          2     124
# 21     TO-247-3     600   47          70          3     270
# 22     TO-247-3     600   72          36       3.25     106
# 23     TO-247-4     650   33          58          3      64
# 24     TO-247-3     600   53          63        2.5     170
#
#    Pd - Power Dissipation (W)
# 0                         117
# 1                         129
# 2                         117
# 3                         250
# 4                         300
# ..                        ...
# 20                        255
# 21                        417
# 22                        446
# 23                        171
# 24                        391
#
# [75 rows x 11 columns]

# %%
for c in [ 'Pricing €',
       'Vds (V)', 'Id A', 'Rds (mOhms)', 'Vgs th (V)', 'Qg (nC)',
       'Pd - Power Dissipation (W)']:
    df3.loc[:,c]= df3[c].astype("float32")

# %%
fig, axs = plt.subplots(2,2,figsize=(10,10))
axs=axs.flatten()

ax = axs[0]
df3.plot(x="Id A", y="Rds (mOhms)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[1]
df3.plot(x="Id A", y="Pd - Power Dissipation (W)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[2]
df3.plot(x="Id A" , y="Qg (nC)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[3]
df3.plot(x="Id A" , y="Pricing €", kind = "scatter", ax = ax)
ax.grid()

# %%
dic1 ={'Mfr Part Number': 'SPW17N80C3A',
'renamrk': 'DCDC nissan 2kW',
'Mfr.': 'Infineon',
'Pricing €': 'NA',
'Package/Case': 'TO-247-3',
'Vds (V)': 800,
'Id A': 17,
'Rds (mOhms)': 290,
'Vgs th (V)': 3,
'Qg (nC)': 88,
'Pd - Power Dissipation (W)': 208,
'Rise Time ns': 15,
'Typical Turn-Off Delay Time ns': 72 ,
'Typical Turn-On Delay Time ns':25,
'Reverse diode dv /dt (v/ns)': 4,
'Thermal resistance, junction - case (K/W)': 0.55,
'Effective output capacitance, energy related (pF)': 72,
'Diode forward voltage (max V)': 1.2}
dic2= {'Mfr Part Number': 'STW48N60DM2',
'renamrk': 'LLC condidate',
'Mfr.': 'STMicroelectronics',
'Pricing €': 4.7,
'Package/Case': 'TO-247-3',
'Vds (V)': 600,
'Id A': 40,
'Rds (mOhms)': 65,
'Vgs th (V)': 3,
'Qg (nC)': 70,
'Pd - Power Dissipation (W)': 300,
'Rise Time ns': 25,
'Typical Turn-Off Delay Time ns': 131,
'Typical Turn-On Delay Time ns': 25,
'Reverse diode dv /dt (v/ns)': 50,
'Thermal resistance, junction - case (K/W)': 0.42,
'Effective output capacitance, energy related (pF)': 258 ,
'Diode forward voltage (max V)': 1}
dic3={'Mfr Part Number': 'SIHG039N60EF-GE3',
'renamrk': 'LLC condidate',
'Mfr.': 'Vishay / Siliconix',
'Pricing €': 7.52,
'Package/Case': 'TO-247-3',
'Vds (V)': 600.0,
'Id A': 61.0,
'Rds (mOhms)': 40.0,
'Vgs th (V)': 3.0,
'Qg (nC)': 84.0,
'Pd - Power Dissipation (W)': 357.0,
'Rise Time ns':179,
'Typical Turn-Off Delay Time ns': 152,
'Typical Turn-On Delay Time ns': 109,
'Reverse diode dv /dt (v/ns)': 50,
'Thermal resistance, junction - case (K/W)': 2.9,
'Effective output capacitance, energy related (pF)': 139,
'Diode forward voltage (max V)': 1.2}
df_ = pd.DataFrame([dic1, dic2, dic3])
df_= df_.set_index("Mfr Part Number")
df_.T
# Out:
# Mfr Part Number                                        SPW17N80C3A  \
# renamrk                                            DCDC nissan 2kW
# Mfr.                                                      Infineon
# Pricing €                                                       NA
# Package/Case                                              TO-247-3
# Vds (V)                                                      800.0
# Id A                                                          17.0
# Rds (mOhms)                                                  290.0
# Vgs th (V)                                                     3.0
# Qg (nC)                                                       88.0
# Pd - Power Dissipation (W)                                   208.0
# Rise Time ns                                                    15
# Typical Turn-Off Delay Time ns                                  72
# Typical Turn-On Delay Time ns                                   25
# Reverse diode dv /dt (v/ns)                                      4
# Thermal resistance, junction - case (K/W)                     0.55
# Effective output capacitance, energy related (pF)               72
# Diode forward voltage (max V)                                  1.2
#
# Mfr Part Number                                           STW48N60DM2  \
# renamrk                                                 LLC condidate
# Mfr.                                               STMicroelectronics
# Pricing €                                                         4.7
# Package/Case                                                 TO-247-3
# Vds (V)                                                         600.0
# Id A                                                             40.0
# Rds (mOhms)                                                      65.0
# Vgs th (V)                                                        3.0
# Qg (nC)                                                          70.0
# Pd - Power Dissipation (W)                                      300.0
# Rise Time ns                                                       25
# Typical Turn-Off Delay Time ns                                    131
# Typical Turn-On Delay Time ns                                      25
# Reverse diode dv /dt (v/ns)                                        50
# Thermal resistance, junction - case (K/W)                        0.42
# Effective output capacitance, energy related (pF)                 258
# Diode forward voltage (max V)                                     1.0
#
# Mfr Part Number                                      SIHG039N60EF-GE3
# renamrk                                                 LLC condidate
# Mfr.                                               Vishay / Siliconix
# Pricing €                                                        7.52
# Package/Case                                                 TO-247-3
# Vds (V)                                                         600.0
# Id A                                                             61.0
# Rds (mOhms)                                                      40.0
# Vgs th (V)                                                        3.0
# Qg (nC)                                                          84.0
# Pd - Power Dissipation (W)                                      357.0
# Rise Time ns                                                      179
# Typical Turn-Off Delay Time ns                                    152
# Typical Turn-On Delay Time ns                                     109
# Reverse diode dv /dt (v/ns)                                        50
# Thermal resistance, junction - case (K/W)                         2.9
# Effective output capacitance, energy related (pF)                 139
# Diode forward voltage (max V)                                     1.2

# %%
dic2= {'Mfr Part Number': 'STW48N60DM2',
 'Mfr.': 'STMicroelectronics',
 'Availability': '477  In Stock',
 'Pricing €': 4.7,
 'Package/Case': 'TO-247-3',
 'Vds (V)': 600,
 'Id A': 40,
 'Rds (mOhms)': 65,
 'Vgs th (V)': 3,
 'Qg (nC)': 70,
 'Pd - Power Dissipation (W)': 300}

# %%
s= df3["Qg (nC)"]
m1 = s<=70

s= df3["Rds (mOhms)"]
m2 = s<=70

df3[m1 & m2]
# Out:
#        Mfr Part Number                   Mfr.     Availability Pricing €  \
# 1    IPZA60R080P7XKSA1  Infineon Technologies    174  In Stock      4.03
# 4          STW48N60DM2     STMicroelectronics    477  In Stock      4.73
# 7     IPW60R060C7XKSA1  Infineon Technologies    410  In Stock      4.94
# 8     IPW60R080P7XKSA1  Infineon Technologies  2 778  In Stock      4.96
# 9           STW48N60M2     STMicroelectronics    987  In Stock      5.04
# 12        STWA48N60DM2     STMicroelectronics    560  In Stock      5.27
# 16  IPW60R070CFD7XKSA1  Infineon Technologies  3 559  In Stock      5.41
# 18    IPZ65R065C7XKSA1  Infineon Technologies    437  In Stock      5.45
# 19    IPW60R060P7XKSA1  Infineon Technologies  1 063  In Stock      5.51
# 9          STWA48N60M2     STMicroelectronics     93  In Stock      7.49
# 14      TK068N65Z5,S1F                Toshiba    205  In Stock      7.72
# 16        STW48N60M6-4     STMicroelectronics     58  In Stock      7.78
# 18       TK065N65Z,S1F                Toshiba     56  In Stock       8.0
# 20         STWA48N60M6     STMicroelectronics     16  In Stock      8.06
# 0          IPW65R065C7  Infineon Technologies     30  In Stock       6.1
# 3    IPZA60R060P7XKSA1  Infineon Technologies    391  In Stock      6.16
# 6     IPW65R065C7XKSA1  Infineon Technologies    170  In Stock      6.35
# 8   IPW65R060CFD7XKSA1  Infineon Technologies    276  In Stock      6.39
# 23         IPZ65R065C7  Infineon Technologies    221  In Stock      6.94
#
#    Package/Case Vds (V)  Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 1      TO-247-4   600.0  37.0        69.0        3.0    51.0
# 4      TO-247-3   600.0  40.0        65.0        3.0    70.0
# 7      TO-247-3   600.0  35.0        52.0        3.0    68.0
# 8      TO-247-3   600.0  37.0        69.0        3.0    51.0
# 9      TO-247-3   600.0  42.0        70.0        2.0    70.0
# 12     TO-247-3   600.0  40.0        65.0        3.0    70.0
# 16     TO-247-3   600.0  31.0        57.0        3.5    67.0
# 18     TO-247-4   650.0  33.0        58.0        3.0    64.0
# 19     TO-247-3   600.0  48.0        49.0        3.0    67.0
# 9      TO-247-3   650.0  42.0        70.0        2.0    70.0
# 14     TO-247-3   650.0  37.0        68.0        4.5    68.0
# 16     TO-247-4   600.0  39.0        69.0       3.25    57.0
# 18     TO-247-3   650.0  30.0        65.0        4.0    62.0
# 20     TO-247-3   600.0  39.0        69.0       3.25    57.0
# 0      TO-247-3   650.0  33.0        65.0        3.0    64.0
# 3      TO-247-4   600.0  48.0        49.0        3.0    67.0
# 6      TO-247-3   650.0  33.0        58.0        3.0    64.0
# 8      TO-247-3   650.0  36.0        60.0        3.5    68.0
# 23     TO-247-4   650.0  33.0        58.0        3.0    64.0
#
#    Pd - Power Dissipation (W)
# 1                       129.0
# 4                       300.0
# 7                       162.0
# 8                       129.0
# 9                       300.0
# 12                      300.0
# 16                      156.0
# 18                      171.0
# 19                      164.0
# 9                       300.0
# 14                      270.0
# 16                      250.0
# 18                      270.0
# 20                      250.0
# 0                       171.0
# 3                       164.0
# 6                       171.0
# 8                       171.0
# 23                      171.0

# %%
#IPW60R060C7XKSA1
#https://www.mouser.fr/datasheet/2/196/Infineon_IPW60R060C7_DS_v02_00_EN-1731945.pdf
#https://www.mouser.fr/ProductDetail/Infineon-Technologies/IPW60R060C7XKSA1?qs=QIiuLP2W41BeappdMvA3rg%3D%3D

# %% [markdown]
# ## Dead time to ZVS

# %% [markdown]
# <img src="../01_llc_tank/03_figs/tdeadZVS.png" style="width:10cm;">

# %% [markdown]
# $ t_{\text{dead}} \geq 16 \cdot C_{\text{eq}} \cdot f_{\text{sw}} \cdot L_m $

# %%
fsw_min = 60170

# %%
# %%render
# Co= 101 # pF
# fsw_max = 156 # kHz
# Tsw_min  =1e6/fsw_max # ns
# Lm_uH = 65.392 # uH
# t_dead_min = 16*(Co*1e-12)*(fsw_max*1e3)*(Lm_uH*1e-6)*1e9 # ns
# Out:
# $
# \begin{aligned}
# \mathrm{Co} &= 101 \; \;\textrm{(pF)}
# \\[10pt]
# \mathrm{fsw}_{max} &= 156 \; \;\textrm{(kHz)}
# \\[10pt]
# \mathrm{Tsw}_{min} &= \frac{ 1 \times 10 ^ {6} }{ \mathrm{fsw}_{max} }  = \frac{ 1 \times 10 ^ {6} }{ 156 } &= 6410.256 \; \;\textrm{(ns)}
# \\[10pt]
# \mathrm{Lm}_{uH} &= 65.392 \; \;\textrm{(uH)}
# \\[10pt]
# t_{dead_{min}} &= 16 \cdot \left( \mathrm{Co} \cdot 1 \times 10 ^ {-12} \right) \cdot \left( \mathrm{fsw}_{max} \cdot 1 \times 10 ^ {3} \right) \cdot \left( \mathrm{Lm}_{uH} \cdot 1 \times 10 ^ {-6} \right) \cdot 1 \times 10 ^ {9} \\&= 16 \cdot \left( 101 \cdot 1 \times 10 ^ {-12} \right) \cdot \left( 156 \cdot 1 \times 10 ^ {3} \right) \cdot \left( 65.392 \cdot 1 \times 10 ^ {-6} \right) \cdot 1 \times 10 ^ {9} \\&= 16.485 \; \;\textrm{(ns)}\\[10pt]
# \end{aligned}
# $

# %% [markdown]
# # Secondary

# %%
# Mouser

# %% [markdown]
# https://www.mouser.lu/c/semiconductors/discrete-semiconductors/transistors/mosfets/?id%20-%20continuous%20drain%20current=100%20A~~240%20A&package%20%2F%20case=TO-247-3&vds%20-%20drain-source%20breakdown%20voltage=150%20V&instock=y&rp=semiconductors%2Fdiscrete-semiconductors%2Ftransistors%2Fmosfets%7C~Id%20-%20Continuous%20Drain%20Current

# %%
arr=[]
for c in  ["1","3","2"]: #["3"]: #
    
    path = r"..\..\03_components\05_Mosfet\02_Secondary\MouserSearchDownload_V"+c+".csv"
 
    df = pd.read_csv(path)
    arr.append(df)
df= pd.concat(arr, axis = 0)
df = df[['Mfr Part Number', 'Mfr.',
       'Availability', 'Pricing', 
       'Technology', 'Mounting Style', 'Package/Case', 'Transistor Polarity',
        'Vds - Drain-Source Breakdown Voltage',
       'Id - Continuous Drain Current', 'Rds On - Drain-Source Resistance',
       'Vgs th - Gate-Source Threshold Voltage',
       'Qg - Gate Charge',  'Pd - Power Dissipation',
        ]]

# %%
df = df.dropna()

# %%
df
# Out:
#     Mfr Part Number                   Mfr.                    Availability  \
# 0     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 1       IXFR180N15P                   IXYS  Non-Stocked Lead-Time 39 Weeks
# 0       IXFH120N15P                   IXYS                   402  In Stock
# 1      IXTH150N15X4                   IXYS                   196  In Stock
# 2      IXTH240N15X4                   IXYS                   250  In Stock
# 3      IXFH160N15T2                   IXYS                   270  In Stock
# 4        AUIRFP4568  Infineon Technologies                 1.378  In Stock
# 5        FDH055N15A     onsemi / Fairchild                 1.249  In Stock
# 6        HUF75852G3     onsemi / Fairchild                   843  In Stock
# 7   IRF150P221AKMA1  Infineon Technologies                 1.241  In Stock
# 8        IXTH44P15T                   IXYS                 1.645  In Stock
# 9     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 10      IXFH150N15P                   IXYS                    50  In Stock
# 11      IXFH76N15T2                   IXYS                    10  In Stock
# 12     IXTH130N15X4                   IXYS                    78  In Stock
#
#        Pricing Technology Mounting Style Package/Case Transistor Polarity  \
# 0    ="4,79 €"         Si   Through Hole     TO-247-3           N-Channel
# 1   ="12,43 €"         Si   Through Hole     TO-247-3           N-Channel
# 0       8,89 €         Si   Through Hole     TO-247-3           N-Channel
# 1      10,56 €         Si   Through Hole     TO-247-3           N-Channel
# 2      11,78 €         Si   Through Hole     TO-247-3           N-Channel
# 3       7,79 €         Si   Through Hole     TO-247-3           N-Channel
# 4      10,55 €         Si   Through Hole     TO-247-3           N-Channel
# 5       6,29 €         Si   Through Hole     TO-247-3           N-Channel
# 6      11,40 €         Si   Through Hole     TO-247-3           N-Channel
# 7       6,18 €         Si   Through Hole     TO-247-3           N-Channel
# 8       7,48 €         Si   Through Hole     TO-247-3           P-Channel
# 9       4,79 €         Si   Through Hole     TO-247-3           N-Channel
# 10     10,92 €         Si   Through Hole     TO-247-3           N-Channel
# 11      6,26 €         Si   Through Hole     TO-247-3           N-Channel
# 12     11,31 €         Si   Through Hole     TO-247-3           N-Channel
#
#    Vds - Drain-Source Breakdown Voltage Id - Continuous Drain Current  \
# 0                                 150 V                      ="100 A"
# 1                                 150 V                      ="100 A"
# 0                                 150 V                         120 A
# 1                                 150 V                         150 A
# 2                                 150 V                         240 A
# 3                                 150 V                         160 A
# 4                                 150 V                         171 A
# 5                                 150 V                         167 A
# 6                                 150 V                          75 A
# 7                                 150 V                         186 A
# 8                                 150 V                          44 A
# 9                                 150 V                         100 A
# 10                                150 V                         150 A
# 11                                150 V                          76 A
# 12                                150 V                         130 A
#
#    Rds On - Drain-Source Resistance Vgs th - Gate-Source Threshold Voltage  \
# 0                         4.5 mOhms                                    2 V
# 1                          13 mOhms                                    5 V
# 0                          16 mOhms                                    3 V
# 1                         7.2 mOhms                                  2.5 V
# 2                         4.4 mOhms                                  4.5 V
# 3                           9 mOhms                                  4.5 V
# 4                         4.8 mOhms                                    3 V
# 5                         4.8 mOhms                                    4 V
# 6                          16 mOhms                                    2 V
# 7                         4.5 mOhms                                  4.6 V
# 8                          65 mOhms                                    4 V
# 9                         4.5 mOhms                                    2 V
# 10                         13 mOhms                                    5 V
# 11                         22 mOhms                                  2.5 V
# 12                        8.5 mOhms                                  2.5 V
#
#    Qg - Gate Charge Pd - Power Dissipation
# 0            165 nC                  500 W
# 1            240 nC                  300 W
# 0            150 nC                  600 W
# 1            105 nC                  480 W
# 2            195 nC                  940 W
# 3            253 nC                  880 W
# 4            227 nC                  517 W
# 5             92 nC                  429 W
# 6            480 nC                  500 W
# 7             80 nC                  341 W
# 8            175 nC                  298 W
# 9            165 nC                  500 W
# 10           190 nC                  714 W
# 11            97 nC                  350 W
# 12            87 nC                  400 W

# %%
cols = list(df.columns)
for c in ["Technology", "Mounting Style", 
                             "Transistor Polarity"]:
    cols.remove(c)
df2= df[cols]

# %%
df3 = df2.copy() 
df3.loc[:,  "Pricing"] = df2["Pricing"].str.replace('="', "").str.replace(' €"', "").str.replace(',', ".")
df3.loc[:,  "Pricing"] = df3["Pricing"].str.replace(' €', "").str.replace('="', "").str.replace('"', "")
df3.loc[:,  "Pricing"] = df3["Pricing"].str.replace('€', "").str.replace('"', "").str.replace('=', "")
df3.loc[:,  "Pricing"] = df3["Pricing"].str.replace(',', ".")


df3.rename(columns={"Pricing": "Pricing €"}, inplace=True)

df3.loc[:,  "Vds - Drain-Source Breakdown Voltage"] = df2["Vds - Drain-Source Breakdown Voltage"].str.replace(' V', "")
df3.rename(columns={"Vds - Drain-Source Breakdown Voltage": "Vds (V)"}, inplace=True)


df3.loc[:,  "Id - Continuous Drain Current"] = df2["Id - Continuous Drain Current"].str.replace('="', "").str.replace(' A"', "")
df3.rename(columns={"Id - Continuous Drain Current": "Id A"}, inplace=True)
df3.loc[:,  "Id A"] = df3["Id A"].str.replace('A', "")


df3.loc[:,  "Rds On - Drain-Source Resistance"] = df2["Rds On - Drain-Source Resistance"].str.replace(' mOhms', "")
df3.rename(columns={"Rds On - Drain-Source Resistance": "Rds (mOhms)"}, inplace=True)

df3.loc[:,  "Vgs th - Gate-Source Threshold Voltage"] = df2["Vgs th - Gate-Source Threshold Voltage"].str.replace(' V', "")
df3.rename(columns={"Vgs th - Gate-Source Threshold Voltage": "Vgs th (V)"}, inplace=True)


df3.loc[:,  "Qg - Gate Charge"] = df2["Qg - Gate Charge"].str.replace(' nC', "")
df3.rename(columns={"Qg - Gate Charge": "Qg (nC)"}, inplace=True)


df3.loc[:,  "Pd - Power Dissipation"] = df2["Pd - Power Dissipation"].str.replace(' W', "")
df3.rename(columns={"Pd - Power Dissipation": "Pd - Power Dissipation (W)"}, inplace=True)

df3
# Out:
#     Mfr Part Number                   Mfr.                    Availability  \
# 0     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 1       IXFR180N15P                   IXYS  Non-Stocked Lead-Time 39 Weeks
# 0       IXFH120N15P                   IXYS                   402  In Stock
# 1      IXTH150N15X4                   IXYS                   196  In Stock
# 2      IXTH240N15X4                   IXYS                   250  In Stock
# 3      IXFH160N15T2                   IXYS                   270  In Stock
# 4        AUIRFP4568  Infineon Technologies                 1.378  In Stock
# 5        FDH055N15A     onsemi / Fairchild                 1.249  In Stock
# 6        HUF75852G3     onsemi / Fairchild                   843  In Stock
# 7   IRF150P221AKMA1  Infineon Technologies                 1.241  In Stock
# 8        IXTH44P15T                   IXYS                 1.645  In Stock
# 9     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 10      IXFH150N15P                   IXYS                    50  In Stock
# 11      IXFH76N15T2                   IXYS                    10  In Stock
# 12     IXTH130N15X4                   IXYS                    78  In Stock
#
#    Pricing € Package/Case Vds (V)  Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 0       4.79     TO-247-3     150   100         4.5          2     165
# 1      12.43     TO-247-3     150   100          13          5     240
# 0       8.89     TO-247-3     150  120           16          3     150
# 1      10.56     TO-247-3     150  150          7.2        2.5     105
# 2      11.78     TO-247-3     150  240          4.4        4.5     195
# 3       7.79     TO-247-3     150  160            9        4.5     253
# 4      10.55     TO-247-3     150  171          4.8          3     227
# 5       6.29     TO-247-3     150  167          4.8          4      92
# 6      11.40     TO-247-3     150   75           16          2     480
# 7       6.18     TO-247-3     150  186          4.5        4.6      80
# 8       7.48     TO-247-3     150   44           65          4     175
# 9       4.79     TO-247-3     150  100          4.5          2     165
# 10     10.92     TO-247-3     150  150           13          5     190
# 11      6.26     TO-247-3     150   76           22        2.5      97
# 12     11.31     TO-247-3     150  130          8.5        2.5      87
#
#    Pd - Power Dissipation (W)
# 0                         500
# 1                         300
# 0                         600
# 1                         480
# 2                         940
# 3                         880
# 4                         517
# 5                         429
# 6                         500
# 7                         341
# 8                         298
# 9                         500
# 10                        714
# 11                        350
# 12                        400

# %%
for c in [ 'Pricing €',
       'Vds (V)', 'Id A', 'Rds (mOhms)', 'Vgs th (V)', 'Qg (nC)',
       'Pd - Power Dissipation (W)']:
    df3.loc[:,c]= df3[c].astype("float32")

# %%
df3
# Out:
#     Mfr Part Number                   Mfr.                    Availability  \
# 0     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 1       IXFR180N15P                   IXYS  Non-Stocked Lead-Time 39 Weeks
# 0       IXFH120N15P                   IXYS                   402  In Stock
# 1      IXTH150N15X4                   IXYS                   196  In Stock
# 2      IXTH240N15X4                   IXYS                   250  In Stock
# 3      IXFH160N15T2                   IXYS                   270  In Stock
# 4        AUIRFP4568  Infineon Technologies                 1.378  In Stock
# 5        FDH055N15A     onsemi / Fairchild                 1.249  In Stock
# 6        HUF75852G3     onsemi / Fairchild                   843  In Stock
# 7   IRF150P221AKMA1  Infineon Technologies                 1.241  In Stock
# 8        IXTH44P15T                   IXYS                 1.645  In Stock
# 9     SUG80050E-GE3  Vishay Semiconductors                   912  In Stock
# 10      IXFH150N15P                   IXYS                    50  In Stock
# 11      IXFH76N15T2                   IXYS                    10  In Stock
# 12     IXTH130N15X4                   IXYS                    78  In Stock
#
#    Pricing € Package/Case Vds (V)   Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 0       4.79     TO-247-3   150.0  100.0         4.5        2.0   165.0
# 1      12.43     TO-247-3   150.0  100.0        13.0        5.0   240.0
# 0       8.89     TO-247-3   150.0  120.0        16.0        3.0   150.0
# 1      10.56     TO-247-3   150.0  150.0         7.2        2.5   105.0
# 2      11.78     TO-247-3   150.0  240.0         4.4        4.5   195.0
# 3       7.79     TO-247-3   150.0  160.0         9.0        4.5   253.0
# 4      10.55     TO-247-3   150.0  171.0         4.8        3.0   227.0
# 5       6.29     TO-247-3   150.0  167.0         4.8        4.0    92.0
# 6       11.4     TO-247-3   150.0   75.0        16.0        2.0   480.0
# 7       6.18     TO-247-3   150.0  186.0         4.5        4.6    80.0
# 8       7.48     TO-247-3   150.0   44.0        65.0        4.0   175.0
# 9       4.79     TO-247-3   150.0  100.0         4.5        2.0   165.0
# 10     10.92     TO-247-3   150.0  150.0        13.0        5.0   190.0
# 11      6.26     TO-247-3   150.0   76.0        22.0        2.5    97.0
# 12     11.31     TO-247-3   150.0  130.0         8.5        2.5    87.0
#
#    Pd - Power Dissipation (W)
# 0                       500.0
# 1                       300.0
# 0                       600.0
# 1                       480.0
# 2                       940.0
# 3                       880.0
# 4                       517.0
# 5                       429.0
# 6                       500.0
# 7                       341.0
# 8                       298.0
# 9                       500.0
# 10                      714.0
# 11                      350.0
# 12                      400.0

# %%
fig, axs = plt.subplots(2,2,figsize=(10,10))
axs=axs.flatten()

ax = axs[0]
df3.plot(x="Id A", y="Rds (mOhms)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[1]
df3.plot(x="Id A", y="Pd - Power Dissipation (W)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[2]
df3.plot(x="Id A" , y="Qg (nC)", kind = "scatter", ax = ax)
ax.grid()

ax = axs[3]
df3.plot(x="Id A" , y="Pricing €", kind = "scatter", ax = ax)
ax.grid()

# %%
s= df3["Qg (nC)"]
m1 = s<=100

s= df3["Rds (mOhms)"]
m2 = s<=10

df3[m1 & m2]
# Out:
#     Mfr Part Number                   Mfr.     Availability Pricing €  \
# 5        FDH055N15A     onsemi / Fairchild  1.249  In Stock      6.29
# 7   IRF150P221AKMA1  Infineon Technologies  1.241  In Stock      6.18
# 12     IXTH130N15X4                   IXYS     78  In Stock     11.31
#
#    Package/Case Vds (V)   Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 5      TO-247-3   150.0  167.0         4.8        4.0    92.0
# 7      TO-247-3   150.0  186.0         4.5        4.6    80.0
# 12     TO-247-3   150.0  130.0         8.5        2.5    87.0
#
#    Pd - Power Dissipation (W)
# 5                       429.0
# 7                       341.0
# 12                      400.0

# %%
# IRF150P221AKMA1
# https://eu.mouser.com/ProductDetail/Infineon-Technologies/IRF150P221AKMA1?qs=iLbezkQI%252BsgFvQ9qK7vaNg%3D%3D
# https://eu.mouser.com/datasheet/2/196/Infineon_IRF150P221_DataSheet_v02_02_EN-3362781.pdf

# %%
df3[df3["Mfr Part Number"] =="IRF150P221AKMA1"]
# Out:
#    Mfr Part Number                   Mfr.     Availability Pricing €  \
# 7  IRF150P221AKMA1  Infineon Technologies  1.241  In Stock      6.18
#
#   Package/Case Vds (V)   Id A Rds (mOhms) Vgs th (V) Qg (nC)  \
# 7     TO-247-3   150.0  186.0         4.5        4.6    80.0
#
#   Pd - Power Dissipation (W)
# 7                      341.0

# %% [markdown]
# -----------

# %% [markdown]
# -----------

# %% [markdown]
# -----------

# %% [markdown]
# -----------

# %% [markdown]
# ## References <a class="title_class" id="title_7"></a>
#
# <a id="referencesID1"></a> [1] Hong Huang, *Designing an LLC Resonant
# Half-Bridge Power Converter*. Available: [https://bbs.dianyuan.com/upload/community/2013/12/01/1385867010-65563.pdf](https://bbs.dianyuan.com/upload/community/2013/12/01/1385867010-65563.pdf)
