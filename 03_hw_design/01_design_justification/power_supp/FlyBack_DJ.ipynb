# %% [markdown]
# ## Flyback design

# %%
from handcalcs import render
import pandas as pd
import numpy as np

# %% [markdown]
# ### Inputs

# %%
# %%render
# Vin_nom=380 # v
# Vin_max = 400 # v
# Vin_min = 360 # v
# Vout_nom=12 # v
# Power_out= 3.4 # w
# delta_Vout = 0.01 # 1 percent
# Out:
# \[
# \begin{aligned}
# \mathrm{Vin}_{nom} &= 380 \; \;\textrm{(v)}
# \\[10pt]
# \mathrm{Vin}_{max} &= 400 \; \;\textrm{(v)}
# \\[10pt]
# \mathrm{Vin}_{min} &= 360 \; \;\textrm{(v)}
# \\[10pt]
# \mathrm{Vout}_{nom} &= 12 \; \;\textrm{(v)}
# \\[10pt]
# \mathrm{Power}_{out} &= 3.400 \; \;\textrm{(w)}
# \\[10pt]
# \delta_{Vout} &= 0.010 \; \;\textrm{(1 percent)}
# \end{aligned}
# \]

# %% [markdown]
# <img src = "Schematic/schema1.png" />

# %% [markdown]
# ### The PWM controller

# %% [markdown]
# We will use a **TNY2xx family** controller
#
# **Why:**
# * This controller has an **integrated MOSFET**
# * It requires a **minimum BOM**
# * It can operate **without an auxiliary winding**
# * It provides integrated frequency jitter (**spread spectrum** to reduce EMI perturbation)
#
# **How this controller works ():**
# * This controller works with **max-current / max-duty-cycle**
# * It has an **internal clock** that fixes the maximum switching frequency
#   * example: **132 kHz**
# * In each cycle, it checks the **feedback pin**
#   * if the feedback pin is activated → **skip (escape) the cycle**
#   * otherwise → **turn on the MOSFET**
# * The MOSFET turns off when **one of the following conditions is met:**
#   * the **primary current** reaches the maximum value
#     * example: **250 mA**
#   * or the **duty cycle** reaches the maximum allowed value
#     * example: **62%**
#
# * This controller has an **internal 5.8 V generator**
#   * used for **self-powering**
#   * no external auxiliary supply is required
#
# For more information pease check the datasheet below [\[1\]](#referencesID8488445fd1).

# %% [markdown]
# <br><br>
# In this design, we will shose the **TNY-264** in open frame configuration
# * Breakdown Voltage = 700
# * Power = 9W
# * Frequancy = 132kHz with +/-8kHz of jitter
# * Rds(ON) = 28Ω @ 25°C and 42Ω @ 100°C (typ), 48Ω in the worst case
# * Ilim = 250mA (typ)
# * Max duty cycle = 65% (typ)

# %% [markdown]
# <br><br>
# Let’s estimate the theorical maximum power that this controller can extract

# %%
# %%render
# I_lim = 0.250 # A
# Freq = 132e3# Hz
# Freq_max = 140e3 # Hz
# DC_max = 0.65
# Vin_max = 400 # V
# di = I_lim-0
# dt =DC_max * (1/ Freq) # s
# L = Vin_max / (di/dt)# H because v = L di/dt
# L_uH = L*1e6 # µH
# E_cycle = 1e6 * 1/2 *L*I_lim**2 # µJ
# P_inp= Freq * E_cycle *1e-6  # W
# Efficiency = 0.8 # hypothesis
# P_out = P_inp*Efficiency # W
# Out:
# \[
# \begin{aligned}
# I_{lim} &= 0.250 \; \;\textrm{(A)}
# \\[10pt]
# \mathrm{Freq} &= 132000.000 \; \;\textrm{(Hz)}
# \\[10pt]
# \mathrm{Freq}_{max} &= 140000.000 \; \;\textrm{(Hz)}
# \\[10pt]
# \mathrm{DC}_{max} &= 0.650 \;
# \\[10pt]
# \mathrm{Vin}_{max} &= 400 \; \;\textrm{(V)}
# \\[10pt]
# \mathrm{di} &= I_{lim} - 0  = 0.250 - 0 &= 0.250
# \\[10pt]
# \mathrm{dt} &= \mathrm{DC}_{max} \cdot \left( \frac{ 1 }{ \mathrm{Freq} } \right)  = 0.650 \cdot \left( \frac{ 1 }{ 132000.000 } \right) &= 0.000 \; \;\textrm{(s)}
# \\[10pt]
# L &= \frac{ \mathrm{Vin}_{max} }{ \frac{ \mathrm{di} }{ \mathrm{dt} } }  = \frac{ 400 }{ \frac{ 0.250 }{ 0.000 } } &= 0.008 \; \;\textrm{(H because v = L di/dt)}
# \\[10pt]
# L_{uH} &= L \cdot 1 \times 10 ^ {6}  = 0.008 \cdot 1 \times 10 ^ {6} &= 7878.788 \; \;\textrm{(µH)}
# \\[10pt]
# E_{cycle} &= 1 \times 10 ^ {6} \cdot \frac{ 1 }{ 2 } \cdot L \cdot \left( I_{lim} \right) ^{ 2 }  = 1 \times 10 ^ {6} \cdot \frac{ 1 }{ 2 } \cdot 0.008 \cdot \left( 0.250 \right) ^{ 2 } &= 246.212 \; \;\textrm{(µJ)}
# \\[10pt]
# P_{inp} &= \mathrm{Freq} \cdot E_{cycle} \cdot 1 \times 10 ^ {-6}  = 132000.000 \cdot 246.212 \cdot 1 \times 10 ^ {-6} &= 32.500 \; \;\textrm{(W)}
# \\[10pt]
# \mathrm{Efficiency} &= 0.800 \; \;\textrm{(hypothesis)}
# \\[10pt]
# P_{out} &= P_{inp} \cdot \mathrm{Efficiency}  = 32.500 \cdot 0.800 &= 26.000 \; \;\textrm{(W)}
# \end{aligned}
# \]

# %% [markdown]
# Let's estimate the thermal discipation in this condition

# %%
# %%render
# Rds_max = 48
# Erds_cycle=(1/3)* Rds_max *I_lim**2 *dt*1e6 # uJ (current is a slope from 0 to I lim)
# Prds=Freq * Erds_cycle *1e-6  # W
# Rth_JA= 45 # °C/W see the datasheet
# Delta_T=Rth_JA*Prds # °C
# Out:
# \[
# \begin{aligned}
# \mathrm{Rds}_{max} &= 48 \;
# \\[10pt]
# \mathrm{Erds}_{cycle} &= \left( \frac{ 1 }{ 3 } \right) \cdot \mathrm{Rds}_{max} \cdot \left( I_{lim} \right) ^{ 2 } \cdot \mathrm{dt} \cdot 1 \times 10 ^ {6}  = \left( \frac{ 1 }{ 3 } \right) \cdot 48 \cdot \left( 0.250 \right) ^{ 2 } \cdot 0.000 \cdot 1 \times 10 ^ {6} &= 4.924 \; \;\textrm{(uJ (current is a slope from 0 to I lim))}
# \\[10pt]
# \mathrm{Prds} &= \mathrm{Freq} \cdot \mathrm{Erds}_{cycle} \cdot 1 \times 10 ^ {-6}  = 132000.000 \cdot 4.924 \cdot 1 \times 10 ^ {-6} &= 0.650 \; \;\textrm{(W)}
# \\[10pt]
# \mathrm{Rth}_{JA} &= 45 \; \;\textrm{(°C/W see the datasheet)}
# \\[10pt]
# \Delta_{T} &= 29.250 \; \;\textrm{(°C)}
# \end{aligned}
# \]

# %% [markdown]
# * The ΔT in this condition is relatively low, because in this quick calculation we assume that the only loss inside the IC is the ohmic loss caused by RDS_ON
# * In reality, there are additional losses, such as switching losses (especially at 132 kHz) and the internal power consumption of the controller.

# %% [markdown]
# In our design, the maximum output power will be 4 W, so we respect the datasheet.

# %% [markdown]
# ### The transformer design

# %% [markdown]
# let's start with this TDK planner small core
# **ELP 22/6/16 with I 22/2.5/16 N87**
# <img src='figs/core.png'>

# %%
# %%render
# Bs = 0.3            # Saturation Flux Density (T)
# Ae_mm2 = 78.5       # Effective Cross Section Area (mm2)
# le_mm = 26.1    # Magnetic Path Length (mm)
# ui = 1360           # Initial Permeability (N87 material)
# AL = 5200 # nH (type)
# Out:
# \[
# \begin{aligned}
# \mathrm{Bs} &= 0.300 \; \;\textrm{(Saturation Flux Density (T))}
# \\[10pt]
# \mathrm{Ae}_{mm2} &= 78.500 \; \;\textrm{(Effective Cross Section Area (mm2))}
# \\[10pt]
# \mathrm{le}_{mm} &= 26.100 \; \;\textrm{(Magnetic Path Length (mm))}
# \\[10pt]
# \mathrm{ui} &= 1360 \; \;\textrm{(Initial Permeability (N87 material))}
# \\[10pt]
# \mathrm{AL} &= 5200 \; \;\textrm{(nH (type))}
# \end{aligned}
# \]

# %% [markdown]
# For more information pease check the datasheet below [\[1\]](#referencesID8488445fd1).

# %%
# %%render
# u0 = 4 * np.pi * 1e-7 # Permeability of Free Space
# Ae = Ae_mm2 * 1e-6 # m2
# le = le_mm= 26.1e-3 #m
# Out:
# \[
# \begin{aligned}
# \mathrm{u0} &= 4 \cdot \mathrm{np.pi} \cdot 1 \times 10 ^ {-7}  = 4 \cdot np.pi \cdot 1 \times 10 ^ {-7} &= 0.000 \; \;\textrm{(Permeability of Free Space)}
# \\[10pt]
# \mathrm{Ae} &= \mathrm{Ae}_{mm2} \cdot 1 \times 10 ^ {-6}  = 78.500 \cdot 1 \times 10 ^ {-6} &= 0.000 \; \;\textrm{(m2)}
# \\[10pt]
# \mathrm{le} &= \mathrm{le}_{mm}  = 26.1 \times 10 ^ {-3} &= 0.026 &= 26.1 \times 10 ^ {-3} &= 0.026 \; \;\textrm{(m)}
# \end{aligned}
# \]

# %% [markdown]
# <u>**One example calculation**</u>

# %% [markdown]
# **For a generic flyback converter**, the calculation is like this:

# %%
# %%render
#
# Vd = 0.4        # Diode Forward Drop (V)
# Np=50
# Ns=10
#
#
#
#
#
# n = Np / Ns
# Vrefl = n * (Vout_nom + Vd)
# D = Vrefl / (Vin_max + Vrefl)
#
#
#
# Ton = D  / Freq
#
# # 2. Correct Bpeak calculation (No division by 2 for Flyback)
# Bpeak = (Vin_max * Ton) / (Np * Ae)
#
# # 3. Magnetizing Inductance (Lm)
# Lm = AL * (Np**2) * 1e-9 # convert nH to Henrys
#
# # 4. Peak Currents
# Ippeak = (Vin_max * Ton) / Lm
# Ispeak = Ippeak * n
#
# # 5. Air Gap Calculation (lg)
# # Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
# #lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)
#
# # 6. Output Power (DCM assumption)
# Effec = 0.8
# Ps = 0.5 * Lm * (Ippeak**2) * Freq * Effec
#
# Margin = (Bs - Bpeak) / Bs
#
# flux = Bs*Ae
#
# lamb= flux *Np
#
# I_sat = lamb *Np/Lm # please keep in mind the margin
# Out:
# \[
# \begin{aligned}
# \mathrm{Vd} &= 0.400 \; \;\textrm{(Diode Forward Drop (V))}
# \\[10pt]
# \mathrm{Np} &= 50 \;
# \\[10pt]
# \mathrm{Ns} &= 10 \;
# \\[10pt]
# n &= \frac{ \mathrm{Np} }{ \mathrm{Ns} }  = \frac{ 50 }{ 10 } &= 5.000
# \\[10pt]
# \mathrm{Vrefl} &= n \cdot \left( \mathrm{Vout}_{nom} + \mathrm{Vd} \right)  = 5.000 \cdot \left( 12 + 0.400 \right) &= 62.000
# \\[10pt]
# D &= \frac{ \mathrm{Vrefl} }{ \mathrm{Vin}_{max} + \mathrm{Vrefl} }  = \frac{ 62.000 }{ 400 + 62.000 } &= 0.134
# \\[10pt]
# \mathrm{Ton} &= \frac{ D }{ \mathrm{Freq} }  = \frac{ 0.134 }{ 132000.000 } &= 0.000
# \\[10pt]
# \mathrm{Bpeak} &= \frac{ \mathrm{Vin}_{max} \cdot \mathrm{Ton} }{ \mathrm{Np} \cdot \mathrm{Ae} }  = \frac{ 400 \cdot 0.000 }{ 50 \cdot 0.000 } &= 0.104
# \\[10pt]
# \mathrm{Lm} &= \mathrm{AL} \cdot \left( \mathrm{Np} \right) ^{ 2 } \cdot 1 \times 10 ^ {-9}  = 5200 \cdot \left( 50 \right) ^{ 2 } \cdot 1 \times 10 ^ {-9} &= 0.013 \; \;\textrm{(convert nH to Henrys)}
# \\[10pt]
# \mathrm{Ippeak} &= \frac{ \mathrm{Vin}_{max} \cdot \mathrm{Ton} }{ \mathrm{Lm} }  = \frac{ 400 \cdot 0.000 }{ 0.013 } &= 0.031
# \\[10pt]
# \mathrm{Ispeak} &= \mathrm{Ippeak} \cdot n  = 0.031 \cdot 5.000 &= 0.156
# \\[10pt]
# \mathrm{Effec} &= 0.800 \;
# \\[10pt]
# \mathrm{Ps} &= 0.5 \cdot \mathrm{Lm} \cdot \left( \mathrm{Ippeak} \right) ^{ 2 } \cdot \mathrm{Freq} \cdot \mathrm{Effec} \\&= 0.5 \cdot 0.013 \cdot \left( 0.031 \right) ^{ 2 } \cdot 132000.000 \cdot 0.800 \\&= 0.672  \\[10pt]
# \\[10pt]
# \mathrm{Margin} &= \frac{ \mathrm{Bs} - \mathrm{Bpeak} }{ \mathrm{Bs} }  = \frac{ 0.300 - 0.104 }{ 0.300 } &= 0.655
# \\[10pt]
# \mathrm{flux} &= \mathrm{Bs} \cdot \mathrm{Ae}  = 0.300 \cdot 0.000 &= 0.000
# \\[10pt]
# \lambda &= \mathrm{flux} \cdot \mathrm{Np}  = 0.000 \cdot 50 &= 0.001
# \\[10pt]
# I_{sat} &= \lambda \cdot \frac{ \mathrm{Np} }{ \mathrm{Lm} }  = 0.001 \cdot \frac{ 50 }{ 0.013 } &= 4.529 \; \;\textrm{(please keep in mind the margin)}
# \end{aligned}
# \]

# %% [markdown]
# But for our **max-current max-duty-cycle TNY-264** the calculation is below
#
# **In first time let's focus on the primary side**

# %% [markdown]
# * Initial time step:
#   $dt = DC_{\text{max}} \cdot \dfrac{1}{\text{Freq}}$
#
# * Calculate maximum DC current:
#   $I_{\text{dcmax}} = \dfrac{V_{\text{in\_nom}} \cdot dt}{L_m}$
#
# * Conditional calculation:
#
#   * If $I_{\text{dcmax}} < I_{\text{lim}}$:
#     $I_{\text{peak}} = I_{\text{dcmax}}$<br>
#     $D = DC_{\text{max}}$
#
#
#   * Else:
#     $I_{\text{peak}} = I_{\text{lim}}$
#     $dt = \dfrac{L_m \cdot I_{\text{lim}}}{V_{\text{in\_nom}}}$
#
#     $D = \dfrac{dt}{ Freq}$

# %%
# %%render
# Lm = AL * (Np**2) * 1e-9 # H
# dt =DC_max * (1/ Freq) # s
# I_dcmax= Vin_nom*dt/Lm # v = L di/dt
# Ipeak = I_dcmax # since Idcmax < Ilim
# Out:
# \[
# \begin{aligned}
# \mathrm{Lm} &= \mathrm{AL} \cdot \left( \mathrm{Np} \right) ^{ 2 } \cdot 1 \times 10 ^ {-9}  = 5200 \cdot \left( 50 \right) ^{ 2 } \cdot 1 \times 10 ^ {-9} &= 0.013 \; \;\textrm{(H)}
# \\[10pt]
# \mathrm{dt} &= \mathrm{DC}_{max} \cdot \left( \frac{ 1 }{ \mathrm{Freq} } \right)  = 0.650 \cdot \left( \frac{ 1 }{ 132000.000 } \right) &= 0.000 \; \;\textrm{(s)}
# \\[10pt]
# I_{dcmax} &= \mathrm{Vin}_{nom} \cdot \frac{ \mathrm{dt} }{ \mathrm{Lm} }  = 380 \cdot \frac{ 0.000 }{ 0.013 } &= 0.144 \; \;\textrm{(v = L di/dt)}
# \\[10pt]
# \mathrm{Ipeak} &= 0.144 \; \;\textrm{(since Idcmax < Ilim)}
# \end{aligned}
# \]

# %%
# %%render
# Bpeak = Vin_nom*dt/(Np*Ae) # > Bsat = 0.3 Wb
# Margin = (Bs - Bpeak) / Bs # NOK
# Out:
# \[
# \begin{aligned}
# \mathrm{Bpeak} &= \mathrm{Vin}_{nom} \cdot \frac{ \mathrm{dt} }{ \mathrm{Np} \cdot \mathrm{Ae} }  = 380 \cdot \frac{ 0.000 }{ 50 \cdot 0.000 } &= 0.477 \; \;\textrm{(> Bsat = 0.3 Wb)}
# \\[10pt]
# \mathrm{Margin} &= \frac{ \mathrm{Bs} - \mathrm{Bpeak} }{ \mathrm{Bs} }  = \frac{ 0.300 - 0.477 }{ 0.300 } &= -0.589 \; \;\textrm{(NOK)}
# \end{aligned}
# \]

# %%
# %%render
# Power_prim = Freq*(1/2)*Lm*Ipeak**2 # W
# Out:
# \[
# \begin{aligned}
# \mathrm{Power}_{prim} &= \mathrm{Freq} \cdot \left( \frac{ 1 }{ 2 } \right) \cdot \mathrm{Lm} \cdot \left( \mathrm{Ipeak} \right) ^{ 2 }  = 132000.000 \cdot \left( \frac{ 1 }{ 2 } \right) \cdot 0.013 \cdot \left( 0.144 \right) ^{ 2 } &= 17.777 \; \;\textrm{(W)}
# \end{aligned}
# \]

# %%
arr = []

for Np in range(10, 101, 10):  # Primary turns
    #for Ns in range(4, 9,2):     # Secondary turns
    if 1: 
        Lm = AL * (Np**2) * 1e-9 # H
        dt =DC_max * (1/ Freq) # s
        I_dcmax= Vin_nom*dt/Lm # v = L di/dt
        if I_dcmax < I_lim:
            Ipeak = I_dcmax # since Idcmax < Ilim
            D = DC_max
        else: 
            Ipeak = I_lim
            dt = Lm*I_lim/Vin_nom
            D = dt*Freq
        Bpeak = Vin_nom*dt/(Np*Ae) # 
        Margin = (Bs - Bpeak) / Bs # 
        Power_prim = Freq*(1/2)*Lm*Ipeak**2 # W
        #if Margin >= 0.15: # Only keep designs with 15% flux margin
        if 1:
            arr.append({
                "Np": Np, 
                #"Ns": Ns, 
                "D": round(D, 3), 
                "Ipeak":Ipeak , 
                 
                "Lm_uH": round(Lm*1e6, 1),
                #"Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                #"Gap_mm": round(lg * 1000, 3) , # convert to mm
                
                #"I_sat": I_sat
                "Power_prim":Power_prim, 
                "Bpeak": round(Bpeak, 3),
                "Margin": Margin, 
            })

df = pd.DataFrame(arr)#.sort_values('Bpeak')

#m =df.Margin>0
#df= df[m]
#print(df.to_string(index=False))
#from IPython.display import display
#display(df.style.hide(axis="index"))
df
# Out:
#     Np      D     Ipeak    Lm_uH  Power_prim  Bpeak    Margin
# 0   10  0.045  0.250000    520.0    2.145000  0.166  0.447983
# 1   20  0.181  0.250000   2080.0    8.580000  0.331 -0.104034
# 2   30  0.406  0.250000   4680.0   19.305000  0.497 -0.656051
# 3   40  0.650  0.224905   8320.0   27.775805  0.596 -0.986425
# 4   50  0.650  0.143939  13000.0   17.776515  0.477 -0.589140
# 5   60  0.650  0.099958  18720.0   12.344802  0.397 -0.324283
# 6   70  0.650  0.073438  25480.0    9.069651  0.341 -0.135100
# 7   80  0.650  0.056226  33280.0    6.943951  0.298  0.006788
# 8   90  0.650  0.044426  42120.0    5.486579  0.265  0.117145
# 9  100  0.650  0.035985  52000.0    4.444129  0.238  0.205430

# %% [markdown]
# Filter with dutyCycle > 10%

# %%
df[df.D>0.1]
# Out:
#     Np      D     Ipeak    Lm_uH  Power_prim  Bpeak    Margin
# 1   20  0.181  0.250000   2080.0    8.580000  0.331 -0.104034
# 2   30  0.406  0.250000   4680.0   19.305000  0.497 -0.656051
# 3   40  0.650  0.224905   8320.0   27.775805  0.596 -0.986425
# 4   50  0.650  0.143939  13000.0   17.776515  0.477 -0.589140
# 5   60  0.650  0.099958  18720.0   12.344802  0.397 -0.324283
# 6   70  0.650  0.073438  25480.0    9.069651  0.341 -0.135100
# 7   80  0.650  0.056226  33280.0    6.943951  0.298  0.006788
# 8   90  0.650  0.044426  42120.0    5.486579  0.265  0.117145
# 9  100  0.650  0.035985  52000.0    4.444129  0.238  0.205430

# %% [markdown]
# So we see that it is hard to meet our requirement without an air gap and with resonable Np, so let's try adding an air gap.

# %%
# %%render
# #Lm_uH = 2000 # uH : a chosen value
# #Np = 25 # example
# #AL= Lm_uH*1e3/Np**2 # nH
# AL = 2400 # nH : a chosen value
# K1=134 # see the core datasheet
# K2 = -0.806 # see the core datasheet
# air_gap = (AL/K1)**(1/K2) # AL in nH and gap in mm
# Out:
# \[
# \begin{aligned}
# \mathrm{AL} &= 2400 \; \;\textrm{(nH : a chosen value)}
# \\[10pt]
# \mathrm{K1} &= 134 \; \;\textrm{(see the core datasheet)}
# \\[10pt]
# \mathrm{K2} &= -0.806 \; \;\textrm{(see the core datasheet)}
# \\[10pt]
# \mathrm{air}_{gap} &= \left( \frac{ \mathrm{AL} }{ \mathrm{K1} } \right) ^{ \left( \frac{ 1 }{ \mathrm{K2} } \right) }  = \left( \frac{ 2400 }{ 134 } \right) ^{ \left( \frac{ 1 }{ -0.806 } \right) } &= 0.028 \; \;\textrm{(AL in nH and gap in mm)}
# \end{aligned}
# \]

# %% [markdown]
# For airgap calculation, see [\[2\]](#referencesID8488445fd2).

# %%
arr = []

for Np in range(16, 31, 2):  # Primary turns
    #for Ns in range(4, 9,2):     # Secondary turns
    if 1: 
        #AL= Lm_uH*1e3/Np**2 # nH
        Lm = AL * (Np**2) * 1e-9 # H
        dt =DC_max * (1/ Freq) # s
        I_dcmax= Vin_nom*dt/Lm # v = L di/dt
        if I_dcmax < I_lim:
            Ipeak = I_dcmax # since Idcmax < Ilim
            D = DC_max
        else: 
            Ipeak = I_lim
            dt = Lm*I_lim/Vin_nom
            D = dt*Freq
        Bpeak = Vin_nom*dt/(Np*Ae) # 
        Margin = (Bs - Bpeak) / Bs # 
        Power_prim = Freq*(1/2)*Lm*Ipeak**2 # W
        #if Margin >= 0.15: # Only keep designs with 15% flux margin
        if 1:
            arr.append({
                "Np": Np, 
                #"Ns": Ns, 
                "D": round(D, 3), 
                "Ipeak":Ipeak , 
                 
                "Lm_uH": round(Lm*1e6, 1),
                #"Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                #"Gap_mm": round(lg * 1000, 3) , # convert to mm
                
                #"I_sat": I_sat
                "Power_prim":Power_prim, 
                "Bpeak": round(Bpeak, 3),
                "Margin": Margin, 
            })

df = pd.DataFrame(arr)#.sort_values('Bpeak')

#m =df.Margin>0
#df= df[m]
#print(df.to_string(index=False))
#from IPython.display import display
#display(df.style.hide(axis="index"))
df
# Out:
#    Np      D  Ipeak   Lm_uH  Power_prim  Bpeak    Margin
# 0  16  0.053   0.25   614.4      2.5344  0.122  0.592357
# 1  18  0.068   0.25   777.6      3.2076  0.138  0.541401
# 2  20  0.083   0.25   960.0      3.9600  0.153  0.490446
# 3  22  0.101   0.25  1161.6      4.7916  0.168  0.439490
# 4  24  0.120   0.25  1382.4      5.7024  0.183  0.388535
# 5  26  0.141   0.25  1622.4      6.6924  0.199  0.337580
# 6  28  0.163   0.25  1881.6      7.7616  0.214  0.286624
# 7  30  0.188   0.25  2160.0      8.9100  0.229  0.235669

# %% [markdown]
# Let's start Np = 26 turns this value provide margin of 11%
# <br><br>**Let's chose an Ns**
# <br>
# To avoid saturation of the core, the magnetic flux ($B$) must return to 0 in each cycle. This means that the magnetizing inductance must discharge completely into the secondary before the end of the cycle. Therefore, the final magnetizing current must be 0A.

# %%
D = df[df.Np==26]["D"].values[0]
Ipeak  = df[df.Np==26]["Ipeak"].values[0]
Lm_uH  = df[df.Np==26]["Lm_uH"].values[0]

# %%
# %%render
# Np= 26
# Ns = 2 # example
# n= Np/Ns
# D = D  # see above table for Np = 26
# Ipeak = Ipeak # A see above table for Np = 26
# Lm_uH = Lm_uH#  uH see above table for Np = 26
# #dt_us = 1e6*(1-D)/Freq # us
# Isec_peak = n*Ipeak
# dIsec = Isec_peak-0
# Lms_uH = Lm_uH  /n**2 # uH secondary magnetic inductance
# Vo = (Vout_nom+Vd) # V
# dtSec_us = Lms_uH * dIsec / Vo # us reminder v=Ldi/dt
# D_secondary =dtSec_us * 1e-6 *Freq
# D_conduction = D + D_secondary   # must be < 1
# Vrefl= (Vout_nom+Vd)*n # V : This voltage stresses the primary MOSFET
# Out:
# \[
# \begin{aligned}
# \mathrm{Np} &= 26 \;
# \\[10pt]
# \mathrm{Ns} &= 2 \; \;\textrm{(example)}
# \\[10pt]
# n &= \frac{ \mathrm{Np} }{ \mathrm{Ns} }  = \frac{ 26 }{ 2 } &= 13.000
# \\[10pt]
# D &= 0.141 \; \;\textrm{(see above table for Np = 26)}
# \\[10pt]
# \mathrm{Ipeak} &= 0.250 \; \;\textrm{(A see above table for Np = 26)}
# \\[10pt]
# \mathrm{Lm}_{uH} &= 1622.400 \; \;\textrm{(uH see above table for Np = 26)}
# \\[10pt]
# \mathrm{Isec}_{peak} &= n \cdot \mathrm{Ipeak}  = 13.000 \cdot 0.250 &= 3.250
# \\[10pt]
# \mathrm{dIsec} &= \mathrm{Isec}_{peak} - 0  = 3.250 - 0 &= 3.250
# \\[10pt]
# \mathrm{Lms}_{uH} &= \frac{ \mathrm{Lm}_{uH} }{ \left( n \right) ^{ 2 } }  = \frac{ 1622.400 }{ \left( 13.000 \right) ^{ 2 } } &= 9.600 \; \;\textrm{(uH secondary magnetic inductance)}
# \\[10pt]
# \mathrm{Vo} &= 12.400 \; \;\textrm{(V)}
# \\[10pt]
# \mathrm{dtSec}_{us} &= \mathrm{Lms}_{uH} \cdot \frac{ \mathrm{dIsec} }{ \mathrm{Vo} }  = 9.600 \cdot \frac{ 3.250 }{ 12.400 } &= 2.516 \; \;\textrm{(us reminder v=Ldi/dt)}
# \\[10pt]
# D_{secondary} &= \mathrm{dtSec}_{us} \cdot 1 \times 10 ^ {-6} \cdot \mathrm{Freq}  = 2.516 \cdot 1 \times 10 ^ {-6} \cdot 132000.000 &= 0.332
# \\[10pt]
# D_{conduction} &= D + D_{secondary}  = 0.141 + 0.332 &= 0.473 \; \;\textrm{(must be < 1)}
# \\[10pt]
# \mathrm{Vrefl} &= \left( \mathrm{Vout}_{nom} + \mathrm{Vd} \right) \cdot n  = \left( 12 + 0.400 \right) \cdot 13.000 &= 161.200 \; \;\textrm{(V : This voltage stresses the primary MOSFET)}
# \end{aligned}
# \]

# %%
arr = []
for Ns in range(2,9):
    n= Np/Ns
    #D = 0.188 # see above table for Np = 26
    #Ipeak = 250e-3 # A see above table for Np = 26
    #Lm_uH = 2163.2#  uH see above table for Np = 26
    #dt_us = 1e6*(1-D)/Freq # us
    Isec_peak = n*Ipeak
    dIsec = Isec_peak-0
    Lms_uH = Lm_uH  /n**2 # uH secondary magnetic inductance
    Vo = (Vout_nom+Vd) # V
    dtSec_us = Lms_uH * dIsec / Vo # us reminder v=Ldi/dt
    D_secondary =dtSec_us * 1e-6 *Freq 
    D_conduction = D + D_secondary   # must be < 1 
    Vrefl= (Vout_nom+Vd)*n # V
    dic = {
        "Ns":Ns,
        "Isec_peak": Isec_peak, 
        "Lms_uH": Lms_uH, 
        "dtSec_us": dtSec_us, 
        "D_secondary": D_secondary, 
        "D_conduction": D_conduction, 
        "Vrefl": Vrefl}
    arr.append(dic)
        
pd.DataFrame(arr)
# Out:
#    Ns  Isec_peak  Lms_uH   dtSec_us  D_secondary  D_conduction       Vrefl
# 0   2   3.250000     9.6   2.516129     0.332129      0.473129  161.200000
# 1   3   2.166667    21.6   3.774194     0.498194      0.639194  107.466667
# 2   4   1.625000    38.4   5.032258     0.664258      0.805258   80.600000
# 3   5   1.300000    60.0   6.290323     0.830323      0.971323   64.480000
# 4   6   1.083333    86.4   7.548387     0.996387      1.137387   53.733333
# 5   7   0.928571   117.6   8.806452     1.162452      1.303452   46.057143
# 6   8   0.812500   153.6  10.064516     1.328516      1.469516   40.300000

# %% [markdown]
# The idea is to pick the highest Ns that ensures the secondary cycle discharges completely, in order to minimize the secondary peak current.
# <br>With **Ns = 4**, the full discharge of the magnetic tank is assured.

# %% [markdown]
# So we will start with **Np = 26 and Ns= 4 and an AL = 2400 nH that provide Lm = 1622 uH in primary side**

# %% [markdown]
# ### RCD snubber

# %% [markdown]
# For details of formulas, please check the document [\[3\]](#referencesID8488445fd3).

# %%
# %%render
# Lm_uH = 1622
# Leakage = 0.03 # Hypothesis
# Llk1_uH = Lm_uH*Leakage # uH
# Lm= Lm_uH*1e-6
# Llk1 =Llk1_uH *1e-6
# Np = 26
# Ns = 4
# V_breakDown = 700 # see Tny-264 datasheet
# V_maxRating = 0.8*V_breakDown # 20 percent of margin
# Out:
# \[
# \begin{aligned}
# \mathrm{Lm}_{uH} &= 1622 \;
# \\[10pt]
# \mathrm{Leakage} &= 0.030 \; \;\textrm{(Hypothesis)}
# \\[10pt]
# \mathrm{Llk1}_{uH} &= \mathrm{Lm}_{uH} \cdot \mathrm{Leakage}  = 1622 \cdot 0.030 &= 48.660 \; \;\textrm{(uH)}
# \\[10pt]
# \mathrm{Lm} &= \mathrm{Lm}_{uH} \cdot 1 \times 10 ^ {-6}  = 1622 \cdot 1 \times 10 ^ {-6} &= 0.002
# \\[10pt]
# \mathrm{Llk1} &= \mathrm{Llk1}_{uH} \cdot 1 \times 10 ^ {-6}  = 48.660 \cdot 1 \times 10 ^ {-6} &= 0.000
# \\[10pt]
# \mathrm{Np} &= 26 \;
# \\[10pt]
# \mathrm{Ns} &= 4 \;
# \\[10pt]
# V_{breakDown} &= 700 \; \;\textrm{(see Tny-264 datasheet)}
# \\[10pt]
# V_{maxRating} &= 0.8 \cdot V_{breakDown}  = 0.8 \cdot 700 &= 560.000 \; \;\textrm{(20 percent of margin)}
# \end{aligned}
# \]

# %% [markdown]
# The snubber allowed voltage is

# %%
# %%render
# Vsn = V_maxRating-Vin_max  # V
# Out:
# \[
# \begin{aligned}
# \mathrm{Vsn} &= V_{maxRating} - \mathrm{Vin}_{max}  = 560.000 - 400 &= 160.000 \; \;\textrm{(V)}
# \end{aligned}
# \]

# %%
# %%render
# Vrefl= (Vout_nom+Vd)*n # V
# FacV= Vsn/(Vsn-Vrefl)
# Rsn= Vsn**2/(0.5*Llk1*Ipeak**2*Freq*FacV) # Ω
# Out:
# \[
# \begin{aligned}
# \mathrm{Vrefl} &= \left( \mathrm{Vout}_{nom} + \mathrm{Vd} \right) \cdot n  = \left( 12 + 0.400 \right) \cdot 3.250 &= 40.300 \; \;\textrm{(V)}
# \\[10pt]
# \mathrm{FacV} &= \frac{ \mathrm{Vsn} }{ \mathrm{Vsn} - \mathrm{Vrefl} }  = \frac{ 160.000 }{ 160.000 - 40.300 } &= 1.337
# \\[10pt]
# \mathrm{Rsn} &= \frac{ \left( \mathrm{Vsn} \right) ^{ 2 } }{ 0.5 \cdot \mathrm{Llk1} \cdot \left( \mathrm{Ipeak} \right) ^{ 2 } \cdot \mathrm{Freq} \cdot \mathrm{FacV} }  = \frac{ \left( 160.000 \right) ^{ 2 } }{ 0.5 \cdot 0.000 \cdot \left( 0.250 \right) ^{ 2 } \cdot 132000.000 \cdot 1.337 } &= 95415.312 \; \;\textrm{(Ω)}
# \end{aligned}
# \]

# %% [markdown]
# Let's chose Rsn = 82 kΩ
# <br> with this value the Vsn will be

# %%
from math import *

# %%
# %%render
# Rsn = 82e3
# Vsn = (Vrefl + sqrt(Vrefl**2 + 2*Llk1*Ipeak**2*Freq*Rsn)) / 2
# Out:
# \[
# \begin{aligned}
# \mathrm{Rsn} &= 82000.000 \;
# \\[10pt]
# \mathrm{Vsn} &= \frac{ \mathrm{Vrefl} + \sqrt { \left( \mathrm{Vrefl} \right) ^{ 2 } + 2 \cdot \mathrm{Llk1} \cdot \left( \mathrm{Ipeak} \right) ^{ 2 } \cdot \mathrm{Freq} \cdot \mathrm{Rsn} } }{ 2 }  = \frac{ 40.300 + \sqrt { \left( 40.300 \right) ^{ 2 } + 2 \cdot 0.000 \cdot \left( 0.250 \right) ^{ 2 } \cdot 132000.000 \cdot 82000.000 } }{ 2 } &= 150.016
# \end{aligned}
# \]

# %% [markdown]
# The power of Rsn is

# %%
# %%render
# P_Rsn = Vsn**2/Rsn # W
# Out:
# \[
# \begin{aligned}
# P_{Rsn} &= \frac{ \left( \mathrm{Vsn} \right) ^{ 2 } }{ \mathrm{Rsn} }  = \frac{ \left( 150.016 \right) ^{ 2 } }{ 82000.000 } &= 0.274 \; \;\textrm{(W)}
# \end{aligned}
# \]

# %% [markdown]
# Let's choose **Rsn = 82kΩ / 2W** to avoid any under-designing.

# %% [markdown]
# * To define the snubber capacitor, let's start ith allowed ripple of **5Vpp**

# %%
# %%render
# Delta_Vsn = 5
# Csn_nF = 1e9*Vsn /(Delta_Vsn  *Rsn * Fmin) # nF
# Csn= 1e-9*Csn_nF # F
# Delta_Vsn_percent = 100*Delta_Vsn / Vsn # percent
# Out:
# \[
# \begin{aligned}
# \Delta_{Vsn} &= 5 \;
# \\[10pt]
# \mathrm{Csn}_{nF} &= 1 \times 10 ^ {9} \cdot \frac{ \mathrm{Vsn} }{ \Delta_{Vsn} \cdot \mathrm{Rsn} \cdot \mathrm{Fmin} }  = 1 \times 10 ^ {9} \cdot \frac{ 150.016 }{ 5 \cdot 82000.000 \cdot 124000.000 } &= 2.951 \; \;\textrm{(nF)}
# \\[10pt]
# \mathrm{Csn} &= 1 \times 10 ^ {-9} \cdot \mathrm{Csn}_{nF}  = 1 \times 10 ^ {-9} \cdot 2.951 &= 0.000 \; \;\textrm{(F)}
# \\[10pt]
# \Delta_{Vsn_{percent}} &= 100 \cdot \frac{ \Delta_{Vsn} }{ \mathrm{Vsn} }  = 100 \cdot \frac{ 5 }{ 150.016 } &= 3.333 \; \;\textrm{(percent)}
# \end{aligned}
# \]

# %% [markdown]
# Let's chose a **Cns = 10nF**
# <br>With this value the ripple will be:

# %%
# %%render
# Csn_nF =10 # nF
# Csn =Csn_nF*1e-9  # F
# Delta_Vsn = Vsn /(Csn *Rsn * Fmin) # V
# Delta_Vsn_percent = 100*Delta_Vsn / Vsn # percent
# Out:
# \[
# \begin{aligned}
# \mathrm{Csn}_{nF} &= 10 \; \;\textrm{(nF)}
# \\[10pt]
# \mathrm{Csn} &= \mathrm{Csn}_{nF} \cdot 1 \times 10 ^ {-9}  = 10 \cdot 1 \times 10 ^ {-9} &= 0.000 \; \;\textrm{(F)}
# \\[10pt]
# \Delta_{Vsn} &= \frac{ \mathrm{Vsn} }{ \mathrm{Csn} \cdot \mathrm{Rsn} \cdot \mathrm{Fmin} }  = \frac{ 150.016 }{ 0.000 \cdot 82000.000 \cdot 124000.000 } &= 1.475 \; \;\textrm{(V)}
# \\[10pt]
# \Delta_{Vsn_{percent}} &= 100 \cdot \frac{ \Delta_{Vsn} }{ \mathrm{Vsn} }  = 100 \cdot \frac{ 1.475 }{ 150.016 } &= 0.983 \; \;\textrm{(percent)}
# \end{aligned}
# \]

# %% [markdown]
# The current of this capacitor will be

# %%
# %%render
# Z_csn= 1/(2*pi*Csn*Freq) # Ω
# I_Csn= Delta_Vsn/Z_csn # App
# I_CsnRms= I_Csn/(2*sqrt(2)) # Arms
# I_CsnRms_mA= I_CsnRms*1e3 # mArms
# Out:
# \[
# \begin{aligned}
# Z_{csn} &= \frac{ 1 }{ 2 \cdot \pi \cdot \mathrm{Csn} \cdot \mathrm{Freq} }  = \frac{ 1 }{ 2 \cdot 3.142 \cdot 0.000 \cdot 132000.000 } &= 120.572 \; \;\textrm{(Ω)}
# \\[10pt]
# I_{Csn} &= \frac{ \Delta_{Vsn} }{ Z_{csn} }  = \frac{ 1.475 }{ 120.572 } &= 0.012 \; \;\textrm{(App)}
# \\[10pt]
# I_{CsnRms} &= \frac{ I_{Csn} }{ 2 \cdot \sqrt { 2 } }  = \frac{ 0.012 }{ 2 \cdot \sqrt { 2 } } &= 0.004 \; \;\textrm{(Arms)}
# \\[10pt]
# I_{CsnRms_{mA}} &= I_{CsnRms} \cdot 1 \times 10 ^ {3}  = 0.004 \cdot 1 \times 10 ^ {3} &= 4.326 \; \;\textrm{(mArms)}
# \end{aligned}
# \]

# %% [markdown]
# So the **Csn = 10nF** with minimum current of **5mA(rms)**

# %% [markdown]
# ### The output stage======== CHECK HOW TO DESING THIS PART FOR FLYBACK!!!

# %%
# %%render
# Freq # Hz
# Vout_nom # v
# Power_out # w
# delta_Vout # 1 percent
# D # duty cycle
# Out:
# \[
# \begin{aligned}
# \mathrm{Freq} &= 132000.000 \; \;\textrm{(Hz)}
# \\[10pt]
# \mathrm{Vout}_{nom} &= 12 \; \;\textrm{(v)}
# \\[10pt]
# \mathrm{Power}_{out} &= 3.400 \; \;\textrm{(w)}
# \\[10pt]
# \delta_{Vout} &= 0.010 \; \;\textrm{(1 percent)}
# \\[10pt]
# D &= 0.141 \; \;\textrm{(duty cycle)}
# \end{aligned}
# \]

# %%
# %%render
# I_out= Power_out/Vout_nom # A
# Delta_Vout = delta_Vout*Vout_nom # V
# C_out_uF= 1e6*I_out/(Delta_Vout*Freq) # uF
# C_out=C_out_uF*1e-6 # F
# Out:
# \[
# \begin{aligned}
# I_{out} &= \frac{ \mathrm{Power}_{out} }{ \mathrm{Vout}_{nom} }  = \frac{ 3.400 }{ 12 } &= 0.283 \; \;\textrm{(A)}
# \\[10pt]
# \Delta_{Vout} &= \delta_{Vout} \cdot \mathrm{Vout}_{nom}  = 0.010 \cdot 12 &= 0.120 \; \;\textrm{(V)}
# \\[10pt]
# C_{out_{uF}} &= 1 \times 10 ^ {6} \cdot \frac{ I_{out} }{ \Delta_{Vout} \cdot \mathrm{Freq} }  = 1 \times 10 ^ {6} \cdot \frac{ 0.283 }{ 0.120 \cdot 132000.000 } &= 17.887 \; \;\textrm{(uF)}
# \\[10pt]
# C_{out} &= 0.000 \; \;\textrm{(F)}
# \end{aligned}
# \]

# %%
# %%render
# Z_Cout = 1/(C_out*2*pi*Freq)
# I_Cout =Delta_Vout /Z_Cout # App
# I_Cout_RMS =I_Cout/(2*sqrt(2)) # Arms
# Out:
# \[
# \begin{aligned}
# Z_{Cout} &= \frac{ 1 }{ C_{out} \cdot 2 \cdot \pi \cdot \mathrm{Freq} }  = \frac{ 1 }{ 0.000 \cdot 2 \cdot 3.142 \cdot 132000.000 } &= 0.067
# \\[10pt]
# I_{Cout} &= \frac{ \Delta_{Vout} }{ Z_{Cout} }  = \frac{ 0.120 }{ 0.067 } &= 1.780 \; \;\textrm{(App)}
# \\[10pt]
# I_{Cout_{RMS}} &= \frac{ I_{Cout} }{ 2 \cdot \sqrt { 2 } }  = \frac{ 1.780 }{ 2 \cdot \sqrt { 2 } } &= 0.629 \; \;\textrm{(Arms)}
# \end{aligned}
# \]

# %% [markdown]
# The current is heigh, to reduce the current, let's chose heigh capacitor
# <br>Example **Cout = 470uF**

# %%
# %%render
# C_out_uF=470 # uF
# Delta_Vout = I_out/(C_out_uF*1e-6*Freq) # V
# delta_Vout = 100*Delta_Vout/Vout_nom  # percent
# Z_Cout = 1/(1e-6*C_out*2*pi*Freq)
# I_Cout =1e6*Delta_Vout /Z_Cout # µApp
# I_Cout_RMS =I_Cout/(2*sqrt(2)) # µArms
# Out:
# \[
# \begin{aligned}
# C_{out_{uF}} &= 470 \; \;\textrm{(uF)}
# \\[10pt]
# \Delta_{Vout} &= \frac{ I_{out} }{ C_{out_{uF}} \cdot 1 \times 10 ^ {-6} \cdot \mathrm{Freq} }  = \frac{ 0.283 }{ 470 \cdot 1 \times 10 ^ {-6} \cdot 132000.000 } &= 0.005 \; \;\textrm{(V)}
# \\[10pt]
# \delta_{Vout} &= 100 \cdot \frac{ \Delta_{Vout} }{ \mathrm{Vout}_{nom} }  = 100 \cdot \frac{ 0.005 }{ 12 } &= 0.038 \; \;\textrm{(percent)}
# \\[10pt]
# Z_{Cout} &= \frac{ 1 }{ 1 \times 10 ^ {-6} \cdot C_{out} \cdot 2 \cdot \pi \cdot \mathrm{Freq} }  = \frac{ 1 }{ 1 \times 10 ^ {-6} \cdot 0.000 \cdot 2 \cdot 3.142 \cdot 132000.000 } &= 2565.360
# \\[10pt]
# I_{Cout} &= 1 \times 10 ^ {6} \cdot \frac{ \Delta_{Vout} }{ Z_{Cout} }  = 1 \times 10 ^ {6} \cdot \frac{ 0.005 }{ 2565.360 } &= 1.780 \; \;\textrm{(µApp)}
# \\[10pt]
# I_{Cout_{RMS}} &= \frac{ I_{Cout} }{ 2 \cdot \sqrt { 2 } }  = \frac{ 1.780 }{ 2 \cdot \sqrt { 2 } } &= 0.629 \; \;\textrm{(µArms)}
# \end{aligned}
# \]

# %% [markdown]
# ### Test & Measurements

# %% [markdown]
# ### References

# %% [markdown]
# <a id="referencesID8488445fd1"></a> [1]  <u>**Datasheets**</u> <br>
#
# ***TNY-264***<br>
# https://www.farnell.com/datasheets/98510.pdf
#
# ***ELP 22/6/16 with I 22/2.5/16 N87***<br>
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf
#
#
# <a id="referencesID8488445fd2"></a> [2] [TDK, Ferrites and accessories, E cores General information](https://www.tdk-electronics.tdk.com/download/531516/f119bbe0ab3d6dd73ae31c6fa9dcf6b9/pdf-ecoresgeneralinformation.pdf)
# <br>

# %% [markdown]
# <a id="referencesID8488445fd3"></a> [3] [Fairchild: Application Note AN-4147](https://e2e.ti.com/cfs-file/__key/communityserver-discussions-components-files/196/Design-Guidelines-for-RCD-Snubber-of-Flyback-Converters_2D00_Fairchild-AN4147.pdf)
