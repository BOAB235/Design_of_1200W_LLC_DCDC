# %% [markdown]
# # all apps
#
# https://www.power.com/products/tinyswitch/tinyswitch-iii/tny280g
#
# # 20W power supp
#
# https://www.power.com/design-support/design-examples/di-176-20-w-air-conditioner-power-supply
#
#
# # datasheet
#
# https://www.power.com/sites/default/files/documents/tinyswitch-iii_family_datasheet.pdf

# %% [markdown]
# # flayback

# %%
from handcalcs import render

# %%
# %%render
# Vin = 400
# Vout=12
# n= 8 # Transfo
# Vd=0.7
# D= (Vout+Vd)/(Vout+Vd+Vin/n) # Flayback
# Out:
# \[
# \begin{aligned}
# \mathrm{Vin} &= 400 \;
# \\[10pt]
# \mathrm{Vout} &= 12 \;
# \\[10pt]
# n &= 8 \; \;\textrm{(Transfo)}
# \\[10pt]
# \mathrm{Vd} &= 0.700 \;
# \\[10pt]
# D &= \frac{ \mathrm{Vout} + \mathrm{Vd} }{ \mathrm{Vout} + \mathrm{Vd} + \frac{ \mathrm{Vin} }{ n } }  = \frac{ 12 + 0.700 }{ 12 + 0.700 + \frac{ 400 }{ 8 } } &= 0.203 \; \;\textrm{(Flayback)}
# \end{aligned}
# \]

# %%
D= 0.2
for n in (5,8,10,20):
    Vout = D*Vin/(n*(1-D))-Vd
    print(n, Vout)
# Out:
# 5 19.3
# 8 11.8
# 10 9.3
# 20 4.3

# %%
Vout=12
for n in (5,8,10,20):
    D= (Vout+Vd)/(Vout+Vd+Vin/n) # Flayback 
    print(n, D)
# Out:
# 5 0.13700107874865156
# 8 0.20255183413078148
# 10 0.24098671726755216
# 20 0.3883792048929663

# %% [markdown]
# # Trans

# %%
from handcalcs import render

# %% [markdown]
# **ELP 22/6/16 with I 22/2.5/16 N87**

# %%
# %%render
#
# Np= 8 # turns
# Ae = 78.5  # mm2 ELP 22/6/16 with I 22/2.5/16 N87
# Aemin = 77.9  # mm2
# le = 26.1 # mm
# AL = 5200 # nH
# Bs = 300
# mu_e = 1360
#
# Lm = AL * Np**2*1e-9
# Lm_uH = 1e6*Lm # uH
# Out:
# \[
# \begin{aligned}
# \mathrm{Np} &= 8 \; \;\textrm{(turns)}
# \\[10pt]
# \mathrm{Ae} &= 78.500 \; \;\textrm{(mm2 ELP 22/6/16 with I 22/2.5/16 N87)}
# \\[10pt]
# \mathrm{Aemin} &= 77.900 \; \;\textrm{(mm2)}
# \\[10pt]
# \mathrm{le} &= 26.100 \; \;\textrm{(mm)}
# \\[10pt]
# \mathrm{AL} &= 5200 \; \;\textrm{(nH)}
# \\[10pt]
# \mathrm{Bs} &= 300 \;
# \\[10pt]
# \mu_{e} &= 1360 \;
# \\[10pt]
# \mathrm{Lm} &= \mathrm{AL} \cdot \left( \mathrm{Np} \right) ^{ 2 } \cdot 1 \times 10 ^ {-9}  = 5200 \cdot \left( 8 \right) ^{ 2 } \cdot 1 \times 10 ^ {-9} &= 0.000
# \\[10pt]
# \mathrm{Lm}_{uH} &= 1 \times 10 ^ {6} \cdot \mathrm{Lm}  = 1 \times 10 ^ {6} \cdot 0.000 &= 332.800 \; \;\textrm{(uH)}
# \end{aligned}
# \]

# %%
from math import pi , sqrt

# %%
# %%render long
# mu_0 = 4*pi *1e-7 # H m−1
# R_core = le*1e-3/(mu_0*mu_e*Ae*1e-6)
# Out:
# \[
# \begin{aligned}
# \mu_{0} &= 4 \cdot \pi \cdot 1 \times 10 ^ {-7} \\&= 4 \cdot 3.142 \cdot 1 \times 10 ^ {-7} \\&= 0.000 \; \;\textrm{(H m−1)}\\[10pt]
# \\[10pt]
# R_{core} &= \mathrm{le} \cdot \frac{ 1 \times 10 ^ {-3} }{ \mu_{0} \cdot \mu_{e} \cdot \mathrm{Ae} \cdot 1 \times 10 ^ {-6} } \\&= 26.100 \cdot \frac{ 1 \times 10 ^ {-3} }{ 0.000 \cdot 1360 \cdot 78.500 \cdot 1 \times 10 ^ {-6} } \\&= 194545.898  \\[10pt]
# \end{aligned}
# \]

# %%
# %%render long
# Im_sat= Bs*1e-3*Ae*1e-6*(R_core)/Np # A
# Out:
# \[
# \begin{aligned}
# \mathrm{Im}_{sat} &= \mathrm{Bs} \cdot 1 \times 10 ^ {-3} \cdot \mathrm{Ae} \cdot 1 \times 10 ^ {-6} \cdot \frac{ R_{core} }{ \mathrm{Np} } \\&= 300 \cdot 1 \times 10 ^ {-3} \cdot 78.500 \cdot 1 \times 10 ^ {-6} \cdot \frac{ 194545.898 }{ 8 } \\&= 0.573 \; \;\textrm{(A)}\\[10pt]
# \end{aligned}
# \]

# %%
# %%render long
# dutyCycleMin = 0.62
# Vinp = 400 #V
# Freq= 135e3 # Hz
# Out:
# \[
# \begin{aligned}
# \mathrm{dutyCycleMin} &= 0.620 \;
# \\[10pt]
# \mathrm{Vinp} &= 400 \; \;\textrm{(V)}
# \\[10pt]
# \mathrm{Freq} &= 135000.000 \; \;\textrm{(Hz)}
# \end{aligned}
# \]

# %%
# %%render long
# Ipeak_max = Vinp*dutyCycleMin/(Freq*Lm) # A worst case
# Out:
# \[
# \begin{aligned}
# \mathrm{Ipeak}_{max} &= \mathrm{Vinp} \cdot \frac{ \mathrm{dutyCycleMin} }{ \mathrm{Freq} \cdot \mathrm{Lm} } \\&= 400 \cdot \frac{ 0.620 }{ 135000.000 \cdot 0.000 } \\&= 5.520 \; \;\textrm{(A worst case)}\\[10pt]
# \end{aligned}
# \]

# %%
for np in (8,20,25,30,40,50):
    Lmnp = AL * np**2*1e-9
    Ipeak_max_np = Vinp*dutyCycleMin/(Freq*Lmnp)
    Ipeak_max_np =Ipeak_max_np /2
    if Ipeak_max_np <  Im_sat: 
        margin =  100*(Im_sat-Ipeak_max_np)/Im_sat
    else :
        margin = None 
    print(np , Ipeak_max_np, Im_sat, margin)
# Out:
# 8 2.7599715099715096 0.572694487320561 None
# 20 0.44159544159544156 0.572694487320561 22.891619987209317
# 25 0.2826210826210826 0.572694487320561 50.650636791813966
# 30 0.19626464070908514 0.572694487320561 65.72960888320415
# 40 0.11039886039886039 0.572694487320561 80.72290499680234
# 50 0.07065527065527065 0.572694487320561 87.66265919795349

# %%
Ae # = 78.5 mm2
Vinp = 400
dutyCycleMin = 0.62
Freq = 135000
AL = 5200 # nH 
arr=[]
for Np in (8,18,20,25, 30, 40, 50):
    Lm = AL * Np**2*1e-9
    DELAT_Ipeak_max = Vinp*dutyCycleMin/(Freq*Lm)
    Ipeak_max =DELAT_Ipeak_max/2 # IDC = 0
    phi = Ipeak_max*Lm/Np # Wb (flux per core, not flux linkage)
    
    B = phi /(Ae*1e-6) # T
    Vs = (Vinp/Np)*dutyCycleMin
    print(Np, B, Bs*1e-3, Ipeak_max, Vs, 100*(Bs*1e-3-B)/(Bs*1e-3)) 
    dic  = {"Np":Np, "B_T":B, "Bs_T":Bs*1e-3, "Ipeak_max":Ipeak_max, "Vs":Vs, "B/Bs":B*1e3/Bs}
    arr.append(dic)
# Out:
# 8 1.4626091059212079 0.3 2.7599715099715096 31.0 -387.5363686404026
# 18 0.6500484915205369 0.3 0.5451795575252365 13.777777777777777 -116.68283050684565
# 20 0.5850436423684832 0.3 0.44159544159544156 12.4 -95.01454745616107
# 25 0.4680349138947865 0.3 0.2826210826210826 9.92 -56.01163796492884
# 30 0.39002909491232207 0.3 0.19626464070908514 8.266666666666667 -30.00969830410736
# 40 0.2925218211842416 0.3 0.11039886039886039 6.2 2.4927262719194694
# 50 0.23401745694739326 0.3 0.07065527065527065 4.96 21.994181017535578

# %%
B, Bs
# Out:
# (0.23401745694739326, 300)

# %%
import pandas as pd 
pd.DataFrame(arr)
# Out:
#    Np       B_T  Bs_T  Ipeak_max         Vs      B/Bs
# 0   8  1.462609   0.3   2.759972  31.000000  4.875364
# 1  18  0.650048   0.3   0.545180  13.777778  2.166828
# 2  20  0.585044   0.3   0.441595  12.400000  1.950145
# 3  25  0.468035   0.3   0.282621   9.920000  1.560116
# 4  30  0.390029   0.3   0.196265   8.266667  1.300097
# 5  40  0.292522   0.3   0.110399   6.200000  0.975073
# 6  50  0.234017   0.3   0.070655   4.960000  0.780058

# %%
mu0 = 4*pi *1e-7 # H m−1 
mu_r= mu_e
I_DC =0

# %%
le=le*1e-3
Ae=Ae*1e-6

# %%
le, Ae
# Out:
# (0.0261, 7.85e-05)

# %%
Bs = Bs/1000

# %%
R_core = le / (mu0 * mu_r * Ae)   # A/Wb (reluctance)

for Np in  (8,18,20,25, 30, 40, 50):
    Lm = AL * Np**2 * 1e-9           # H
    delta_I = Vinp * dutyCycleMin / (Lm * Freq)   # A peak-to-peak
    I_peak = I_DC + delta_I / 2.0

    # Method A: B from current
    phi = I_peak * Lm / Np
    B_from_I = phi / Ae

    # Method B: I_sat from Bs
    I_sat_from_B = (Bs * Ae * R_core) / Np

    if I_peak < I_sat_from_B:
        margin = 100*(I_sat_from_B - I_peak)/I_sat_from_B
    else:
        margin = None

    print(Np, f"I_peak={I_peak:.4f}A", f"B={B_from_I:.3f}T", f"I_sat={I_sat_from_B:.4f}A", "margin%", margin)
# Out:
# 8 I_peak=2.7600A B=1.463T I_sat=0.5727A margin% None
# 18 I_peak=0.5452A B=0.650T I_sat=0.2545A margin% None
# 20 I_peak=0.4416A B=0.585T I_sat=0.2291A margin% None
# 25 I_peak=0.2826A B=0.468T I_sat=0.1833A margin% None
# 30 I_peak=0.1963A B=0.390T I_sat=0.1527A margin% None
# 40 I_peak=0.1104A B=0.293T I_sat=0.1145A margin% 3.6145249840116107
# 50 I_peak=0.0707A B=0.234T I_sat=0.0916A margin% 22.891619987209285

# %% [markdown]
# # New study

# %% [markdown]
# Flybuck
#
# $$
# B = \frac{V_{\text{in}} \cdot D}{N \cdot A_e \cdot f}
# $$
#
# Where:
# - $ B $ = peak flux density (Tesla)
# - $ V_{\text{in}} $ = input voltage during ON time
# - $ D $ = duty cycle
# - $ N $ = number of primary turns
# - $ A_e $ = core cross-sectional area (m^2)
# - $ f $ = switching frequency (Hz)

# %%
Vin = 400
D = 0.62
N = 8
Ae = 78.5e-6  # mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
f= 132e3
Bs = 0.3
B = Vin *D/(N*Ae*f)
B
# Out:
# 2.9917004439297434

# %%
for N in  (8,18,20,25, 30, 40, 50, 60, 80):
    B = Vin *D/(N*Ae*f)
    print(N, B, Bs/B)
# Out:
# 8 2.9917004439297434 0.1002774193548387
# 18 1.3296446417465526 0.2256241935483871
# 20 1.1966801775718974 0.25069354838709673
# 25 0.957344142057518 0.3133669354838709
# 30 0.7977867850479315 0.3760403225806451
# 40 0.5983400887859487 0.5013870967741935
# 50 0.478672071028759 0.6267338709677418
# 60 0.3988933925239658 0.7520806451612903
# 80 0.29917004439297434 1.002774193548387

# %% [markdown]
# $$
# \frac{V_{\text{out}} + V_d}{V_{\text{in}}} = \frac{D}{1-D} \cdot \frac{N_s}{N_p}
# $$
#
# Solve for \( D \):
#
# $$
# D = \frac{\dfrac{V_{\text{out}} + V_d}{V_{\text{in}}} \cdot \dfrac{N_p}{N_s}}{1 + \dfrac{V_{\text{out}} + V_d}{V_{\text{in}}} \cdot \dfrac{N_p}{N_s}}
# $$

# %%
Vout = 12
Vin = 400
Np = 8
Ns = 1
Vd =0.7

for Vin in (350, 360,400):
    D_ = (Vout+Vd) / Vin 
    rate = Np/Ns 
    D = (D_*rate) /(1+D_*rate)
    print(f"Vin = {Vin: .0f}V, D= { D: .2f}")
# Out:
# Vin =  350V, D=  0.22
# Vin =  360V, D=  0.22
# Vin =  400V, D=  0.20

# %%
Ns = int((Np/8))
Ns
# Out:
# 1

# %%
for N in  (18,20,25, 30, 40, 50, 60, 80, 100):
    Np =N
    Ns = int((Np/6))
    D_ = (Vout+Vd) / Vin 
    rate = Np/Ns 
    D = (D_*rate) /(1+D_*rate)

    
    B = Vin *D/(N*Ae*f)
    #print(N, B, Bs/B)
    s= f"Vin = {Vin}, Vout = {Vout}, Vd = {Vd}, D={D:.3f},  Np = {N} , Ns = {Ns}, B= {B:.2f}, Bs ={Bs}"
    print(s)
# Out:
# Vin = 400, Vout = 12, Vd = 0.7, D=0.160,  Np = 18 , Ns = 3, B= 0.34, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.175,  Np = 20 , Ns = 3, B= 0.34, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.166,  Np = 25 , Ns = 4, B= 0.26, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.160,  Np = 30 , Ns = 5, B= 0.21, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.175,  Np = 40 , Ns = 6, B= 0.17, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.166,  Np = 50 , Ns = 8, B= 0.13, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.160,  Np = 60 , Ns = 10, B= 0.10, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.163,  Np = 80 , Ns = 13, B= 0.08, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.166,  Np = 100 , Ns = 16, B= 0.06, Bs =0.3

# %%
from math import floor

# %%
for div in (1, 2, 3, 4, 6, 8 ,10,14):
    print("-"*10)
    print("Np/Ns = ", div)
    for N in  (8,12,16, 18,20,25, 30, 40, 50):
        Np =N
        Ns = int(floor(Np/div))
        if Ns ==0:
            continue 
        #print(Np/Ns)
        D_ = (Vout+Vd) / Vin 
        rate = Np/Ns 
        D = (D_*rate) /(1+D_*rate)
    
        
        B = Vin *D/(N*Ae*f)
        #print(N, B, Bs/B)
        s= f"Vin = {Vin}, Vout = {Vout}, Vd = {Vd}, D={D:.3f},  Np = {N} , Ns = {Ns}, B= {B:.2f}, Bs ={Bs}"
        if B/Bs < 0.75 and B/Bs >0.25 : 
            print(s)
# Out:
# ----------
# Np/Ns =  1
# Vin = 400, Vout = 12, Vd = 0.7, D=0.031,  Np = 8 , Ns = 8, B= 0.15, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.031,  Np = 12 , Ns = 12, B= 0.10, Bs =0.3
# ----------
# Np/Ns =  2
# Vin = 400, Vout = 12, Vd = 0.7, D=0.060,  Np = 12 , Ns = 6, B= 0.19, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.060,  Np = 16 , Ns = 8, B= 0.14, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.060,  Np = 18 , Ns = 9, B= 0.13, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.060,  Np = 20 , Ns = 10, B= 0.12, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.062,  Np = 25 , Ns = 12, B= 0.10, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.060,  Np = 30 , Ns = 15, B= 0.08, Bs =0.3
# ----------
# Np/Ns =  3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.092,  Np = 16 , Ns = 5, B= 0.22, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.087,  Np = 18 , Ns = 6, B= 0.19, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.096,  Np = 20 , Ns = 6, B= 0.18, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.090,  Np = 25 , Ns = 8, B= 0.14, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.087,  Np = 30 , Ns = 10, B= 0.11, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.089,  Np = 40 , Ns = 13, B= 0.09, Bs =0.3
# ----------
# Np/Ns =  4
# Vin = 400, Vout = 12, Vd = 0.7, D=0.113,  Np = 20 , Ns = 5, B= 0.22, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.117,  Np = 25 , Ns = 6, B= 0.18, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.120,  Np = 30 , Ns = 7, B= 0.15, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.113,  Np = 40 , Ns = 10, B= 0.11, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.117,  Np = 50 , Ns = 12, B= 0.09, Bs =0.3
# ----------
# Np/Ns =  6
# Vin = 400, Vout = 12, Vd = 0.7, D=0.160,  Np = 30 , Ns = 5, B= 0.21, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.175,  Np = 40 , Ns = 6, B= 0.17, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.166,  Np = 50 , Ns = 8, B= 0.13, Bs =0.3
# ----------
# Np/Ns =  8
# Vin = 400, Vout = 12, Vd = 0.7, D=0.203,  Np = 40 , Ns = 5, B= 0.20, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.209,  Np = 50 , Ns = 6, B= 0.16, Bs =0.3
# ----------
# Np/Ns =  10
# Vin = 400, Vout = 12, Vd = 0.7, D=0.241,  Np = 50 , Ns = 5, B= 0.19, Bs =0.3
# ----------
# Np/Ns =  14

# %%
# DC min max is 3% and 62-65%

# %% [markdown]
# $$
# I_{\text{out}} = \frac{I_{\text{pk,sec}}}{2} \cdot (1 - D)
# $$
#
# Where:
# - \( I_{\text{out}} \) = average DC output current after the capacitor
# - \( I_{\text{pk,sec}} \) = peak secondary current
# - \( D \) = duty cycle (fraction of ON time)
#
# Also:
# $$
# I_{\text{pk,sec}} = I_{\text{pk,pri}} \cdot \frac{N_p}{N_s}
# $$
#
# And:
# $$
# I_{\text{pk,pri}} = \frac{V_{\text{in}} \cdot D}{L_m \cdot f}
# $$
#
# Where:
# - \( N_p, N_s \) = primary and secondary turns
# - \( V_{\text{in}} \) = input voltage
# - \( L_m \) = magnetizing inductance
# - \( f \) = switching frequency
# $$

# %% [markdown]
# <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Flyback_conventions_french.svg/525px-Flyback_conventions_french.svg.png"/>

# %%
Iout = 1
Vout = 12 
R_scond= 1
Vd = 0.7
Vin = 400
f= 132e3
Np = 30
Ns = 5
#D ?

# %% [markdown]
# $$
# D = \frac{\dfrac{(V_{\text{out}} + V_d + I_{\text{sec}} \cdot R_s) \cdot \dfrac{N_p}{N_s}}{V_{\text{in}}}}{1 + \dfrac{(V_{\text{out}} + V_d + I_{\text{sec}} \cdot R_s) \cdot \dfrac{N_p}{N_s}}{V_{\text{in}}}}
# $$
#
# Where:
# - \( V_{\text{out}} \) = output voltage
# - \( V_d \) = diode drop
# - \( I_{\text{sec}} \) = secondary current (approx. Iout for DC)
# - \( R_s \) = secondary winding resistance
# - \( N_p, N_s \) = primary and secondary turns
# - \( V_{\text{in}} \) = input voltage
# $$

# %% [markdown]
# You’re on the right track with your intuition. Let’s derive the formula for **duty cycle ( D )** when we include the secondary copper resistance ( R\_s ) and diode drop ( V\_d ).
#
# ***
#
# ### ✅ Steady-State Flyback Voltage Relation
#
# During OFF time, the secondary sees:
# $$
# V\_{\text{sec}} = V\_{\text{out}} + V\_d + I\_{\text{sec}} \cdot R\_s
# $$
#
# Reflected to the primary:
# $$
# V\_{\text{pri,ref}} = V\_{\text{sec}} \cdot \frac{N\_p}{N\_s}
# $$
#
# During ON time, the primary sees ( V\_{\text{in}} ). In steady state:
# $$
# V\_{\text{in}} \cdot D = V\_{\text{pri,ref}} \cdot (1-D)
# $$
#
# So:
# $$
# \frac{D}{1-D} = \frac{V\_{\text{pri,ref}}}{V\_{\text{in}}} = \frac{(V\_{\text{out}} + V\_d + I\_{\text{sec}} \cdot R\_s) \cdot \dfrac{N\_p}{N\_s}}{V\_{\text{in}}}
# $$
#
# ***
#
# ### ✅ Solve for ( D ):
#
# $$
# D = \frac{\dfrac{(V\_{\text{out}} + V\_d + I\_{\text{sec}} \cdot R\_s) \cdot \dfrac{N\_p}{N\_s}}{V\_{\text{in}}}}{1 + \dfrac{(V\_{\text{out}} + V\_d + I\_{\text{sec}} \cdot R\_s) \cdot \dfrac{N\_p}{N\_s}}{V\_{\text{in}}}}
# $$
#
# ***
#
# Here’s the **Markdown block for copy**:
#
#     $$
#     D = \frac{\dfrac{(V_{\text{out}} + V_d + I_{\text{sec}} \cdot R_s) \cdot \dfrac{N_p}{N_s}}{V_{\text{in}}}}{1 + \dfrac{(V_{\text{out}} + V_d + I_{\text{sec}} \cdot R_s) \cdot \dfrac{N_p}{N_s}}{V_{\text{in}}}}
#     $$
#
#     Where:
#     - \( V_{\text{out}} \) = output voltage
#     - \( V_d \) = diode drop
#     - \( I_{\text{sec}} \) = secondary current (approx. Iout for DC)
#     - \( R_s \) = secondary winding resistance
#     - \( N_p, N_s \) = primary and secondary turns
#     - \( V_{\text{in}} \) = input voltage
#     $$
#
# ***
#
# ✅ Do you want me to **compute D numerically for your case** (Iout = 1 A, Vout = 12 V, Rs = 1 Ω, Vd = 0.7 V, Vin = 400 V, Np = 30, Ns = 5)?

# %%
Ns = 1

for N in  (8,18,20,25, 30, 40, 50, 70,80, 100):
    Np =N
    #Ns = int(floor(Np/div))
    if Ns ==0:
        continue 
    #print(Np/Ns)
    D_ = (Vout+Vd) / Vin 
    rate = Np/Ns 
    D = (D_*rate) /(1+D_*rate)

    
    B = Vin *D/(N*Ae*f)
    #print(N, B, Bs/B)
    s= f"Vin = {Vin}, Vout = {Vout}, Vd = {Vd}, D={D:.3f},  Np = {N} , Ns = {Ns}, B= {B:.2f}, Bs ={Bs}"
    if True : # B < Bs : 
        print(s)
# Out:
# Vin = 400, Vout = 12, Vd = 0.7, D=0.203,  Np = 8 , Ns = 1, B= 0.98, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.364,  Np = 18 , Ns = 1, B= 0.78, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.388,  Np = 20 , Ns = 1, B= 0.75, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.443,  Np = 25 , Ns = 1, B= 0.68, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.488,  Np = 30 , Ns = 1, B= 0.63, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.559,  Np = 40 , Ns = 1, B= 0.54, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.614,  Np = 50 , Ns = 1, B= 0.47, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.690,  Np = 70 , Ns = 1, B= 0.38, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.718,  Np = 80 , Ns = 1, B= 0.35, Bs =0.3
# Vin = 400, Vout = 12, Vd = 0.7, D=0.760,  Np = 100 , Ns = 1, B= 0.29, Bs =0.3

# %%
import pandas as pd
arr= []
for div in (3, 4, 6,7, 8 ,10,14):
    #print("-"*10)
    #print("Np/Ns = ", div)
    for N in  (8,12,16, 18,20,25, 30):
        Np =N
        Ns = int(floor(Np/div))
        if Ns ==0:
            continue 
        #print(Np/Ns)
        D_ = (Vout+Vd) / Vin 
        rate = Np/Ns 
        D = (D_*rate) /(1+D_*rate)
    
        
        B = Vin *D/(N*Ae*f)
        #print(N, B, Bs/B)
        s= f"Vin = {Vin}, Vout = {Vout}, Vd = {Vd}, D={D:.3f},  Np = {N} , Ns = {Ns}, B= {B:.2f}, Bs ={Bs}"
        if B/Bs < 0.8 and B/Bs >0.25 : 
            #print(s)
            dic = {"div":div, "Vin": Vin, "Vout": Vout, "Vd": Vd,
                   "D": D, "Np": N, "Ns": Ns, "B": B, "Bs": Bs, 
                   "margin B%":-100*(B-Bs)/Bs}
            arr.append(dic)

pd.DataFrame(arr)
# Out:
#    div  Vin  Vout   Vd         D  Np  Ns         B   Bs  margin B%
# 0    3  400    12  0.7  0.092229  16   5  0.222519  0.3  25.827153
# 1    3  400    12  0.7  0.086966  18   6  0.186507  0.3  37.830931
# 2    3  400    12  0.7  0.095705  20   6  0.184722  0.3  38.425917
# 3    3  400    12  0.7  0.090263  25   8  0.139375  0.3  53.541545
# 4    3  400    12  0.7  0.086966  30  10  0.111904  0.3  62.698558
# 5    4  400    12  0.7  0.112689  20   5  0.217503  0.3  27.498840
# 6    4  400    12  0.7  0.116835  25   6  0.180406  0.3  39.864723
# 7    4  400    12  0.7  0.119774  30   7  0.154119  0.3  48.626968
# 8    6  400    12  0.7  0.160017  30   5  0.205902  0.3  31.365974

# %%
# Design Flyback  400V / 12V 1A to power MOSFET driver 
Vin_range =[360,400] # V
Vout =12 # V
DutyCycle_range =[0.05, 0.62] # controller tny280GN
freq_range=[124e3,140e3]
##### TRANSFORMER 
# Core ELP 22/6/16 with I 22/2.5/16 N87
Ae = 78.5e-6  # mm2=>m2 
Bs = 0.3
AL = 5200 #nH/tr2 +/-25%
mu_e = 1360
le = 26.1e-3 # mm ==> m 
Np = 30
Ns = 5 #2 secondary 30:5:5
# Output stage 
Vd  = 0.7 # MBRS340T3G 40V 3A Schottky D
Capa = 470 #uF + ceramic of 10 uF

# %%
##### TRANSFORMER 
# Core ELP 22/6/16 with I 22/2.5/16 N87
Ae = 78.5e-6  # mm2=>m2 
Bs = 0.3
AL = 5200 #nH/tr2 +/-25%
mu_e = 1360
le = 26.1e-3 # mm ==> m 
Np = 30
Ns = 5 #2 secondary 30:5:5
# Output stage 
Vd  = 0.7 # MBRS340T3G 40V 3A Schottky D
Capa = 470 #uF + ceramic of 10 uF 

Dmax = 0.62
Dmin = 0.05
Vinmin = 300
Vinmax = 420
Vout = 12
Iout = 1
Vd = 0.5

fmin , fmax=[124e3,140e3]

# %%
from handcalcs import render

# %%
Lm =AL*1e-9* Np**2
print(Lm)
eff = 0.8
Pout = Vout *Iout
E_cycle= Pout/(eff*fmin)
Ip_pk = sqrt(2*E_cycle/Lm)
print(Ip_pk)
phi = Lm*Ip_pk/Np
Bpk= phi /Ae
print(Bpk)
# Out:
# 0.00468
# 0.2273666998743335
# 0.4518370086674653

# %% [raw]
# Bpk= phi /Ae = Lm*Ip_pk/Np = Lm*Ip_pk/Np = Lm*sqrt(2*E_cycle/Lm)/Np
# = k sqrt(Lm)/Np = K2  Np/Np  = K2 (no dependacy of Np)
# !!!!!!!!!! it depend only of Pout

# %%
Np
# Out:
# 30

# %%
# %%render
# Nps=( Vinmin *Dmax) /(Vout *(1-Dmax))
# Out:
# \[
# \begin{aligned}
# \mathrm{Nps} &= \frac{ \mathrm{Vinmin} \cdot \mathrm{Dmax} }{ \mathrm{Vout} \cdot \left( 1 - \mathrm{Dmax} \right) }  = \frac{ 300 \cdot 0.620 }{ 12 \cdot \left( 1 - 0.620 \right) } &= 40.789
# \end{aligned}
# \]

# %%
Iout = 0.3
Lm =AL*1e-9* Np**2
print(Lm)
eff = 0.8
Pout = Vout *Iout
E_cycle= Pout/(eff*fmin)
Ip_pk = sqrt(2*E_cycle/Lm)
print(Ip_pk)
phi = Lm*Ip_pk/Np
Bpk= phi /Ae
print(Bpk)
# Out:
# 0.013000000000000001
# 0.07472032220800767
# 0.247481321962828

# %% [markdown]
# # bsat

# %%
Vin = 400
D = 0.62
N = 8
Ae = 78.5e-6  # mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf
f= 132e3
Bs = 0.3
B = Vin *D/(N*Ae*f)
AL = 5200 # nH

# %%
Vin = 400
D = 0.62

Ae = 78.5e-6  # mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
f= 132e3
Bs = 0.3

T= 1/f
Ton = D*T
for N in range( 40, 50):
    flux = (Vin * Ton /2 ) /N # 2 Because start from -flux to flux, so 2 flux
    Bpeak = flux/Ae
    Margin = (Bs-Bpeak) /Bs
    print(f"# N = {N} Bpeak = {Bpeak:.3f} Margin = {Margin:.3f}" )
# N = 40 Bpeak = 0.299 Margin = 0.003
# N = 41 Bpeak = 0.292 Margin = 0.027
# N = 42 Bpeak = 0.285 Margin = 0.050
# N = 43 Bpeak = 0.278 Margin = 0.072
# N = 44 Bpeak = 0.272 Margin = 0.093
# N = 45 Bpeak = 0.266 Margin = 0.114
# N = 46 Bpeak = 0.260 Margin = 0.133
# N = 47 Bpeak = 0.255 Margin = 0.151
# N = 48 Bpeak = 0.249 Margin = 0.169
# N = 49 Bpeak = 0.244 Margin = 0.186
# Out:
# # N = 40 Bpeak = 0.299 Margin = 0.003
# # N = 41 Bpeak = 0.292 Margin = 0.027
# # N = 42 Bpeak = 0.285 Margin = 0.050
# # N = 43 Bpeak = 0.278 Margin = 0.072
# # N = 44 Bpeak = 0.272 Margin = 0.093
# # N = 45 Bpeak = 0.266 Margin = 0.114
# # N = 46 Bpeak = 0.260 Margin = 0.133
# # N = 47 Bpeak = 0.255 Margin = 0.151
# # N = 48 Bpeak = 0.249 Margin = 0.169
# # N = 49 Bpeak = 0.244 Margin = 0.186

# %%
Vin = 400
D = 0.62
N = 8
Ae = 78.5e-6  # mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf
f= 132e3
Bs = 0.3
B = Vin *D/(N*Ae*f)
AL = 5200 # nH



# THIS IS CHAT GPT PROPOSITION 

# Constants for TDK N87 roughly at 100C (Steinmetz approximation)
# Pv = Cm * f^x * B^y (mW/cm3)
# Note: These are approximations. Consult datasheet for exact curves.
Cm = 9.5e-3  # Example coefficient (needs tuning for specific unit scaling)
x = 1.4
y = 2.5
Ve = 1000 # Effective volume in mm3 (Example for ELP 22, check datasheet)



Vout = 12
Vin = 300
Np = 8
Ns = 1
Vd =0.7

D_ = (Vout+Vd) / Vin 
rate = Np/Ns 
D = (D_*rate) /(1+D_*rate)
print(D)

f= 132e3
T= 1/f
Ton = D*T



#print(f"{'N':<4} {'Bpeak (T)':<10} {'Margin':<10} {'Est. Loss Factor'}")
#print("-" * 45)
arr = []
for N in range(10, 30): # Extended range
    flux = (Vin * Ton / 2) / N
    Bpeak = flux / Ae
    Margin = (Bs - Bpeak) / Bs
    Np = N
    Ns = N//8
    D_ = (Vout+Vd) / Vin 
    rate = Np/Ns 
    D = (D_*rate) /(1+D_*rate)
    
    # Relative loss factor (B^2.5) to compare heat
    # This shows how much cooler the core runs as you add turns.
    loss_factor = Bpeak ** 2.5 
    
    #print(f"{Ns:} {N:<4} {Bpeak:.3f}      {Margin:.3f}      {loss_factor:.3f}")
    Lm= AL *Np**2*1e-3
    # v = L di/dt
    Ippeak= 1e6*(Vin/Lm)*Ton
    Ispeak= Ippeak * Np/Ns

    
    E_cycle = (Ippeak*Vin)*Ton/2 # 2 because triangle 
    Pp = E_cycle *f
    Effec= 0.8
    Ps= Pp*Effec
    arr.append({"Ip_peak": Ippeak, "Ispeak" : Ispeak, "Ps": Ps, "Lm":Lm, "Ns":Ns, "Np":Np , "Bpeak":Bpeak, "Margin":Margin, "loss_factor":loss_factor})
import pandas as pd
pd.DataFrame(arr)
# Out:
# 0.25298804780876494
#      Ip_peak     Ispeak         Ps      Lm  Ns  Np     Bpeak    Margin  \
# 0   1.105717  11.057170  33.567982   520.0   1  10  0.366225 -0.220749
# 1   0.913816  10.051973  27.742134   629.2   1  11  0.332932 -0.109772
# 2   0.767859   9.214308  23.311099   748.8   1  12  0.305187 -0.017291
# 3   0.654270   8.505515  19.862711   878.8   1  13  0.281711  0.060962
# 4   0.564141   7.897979  17.126521  1019.2   1  14  0.261589  0.128036
# 5   0.491430   7.371447  14.919103  1170.0   1  15  0.244150  0.186167
# 6   0.431921   3.455366  13.112493  1331.2   2  16  0.228890  0.237032
# 7   0.382601   3.252109  11.615219  1502.8   2  17  0.215426  0.281912
# 8   0.341271   3.071436  10.360488  1684.8   2  18  0.203458  0.321806
# 9   0.306293   2.909782   9.298610  1877.2   2  19  0.192750  0.357500
# 10  0.276429   2.764292   8.391995  2080.0   2  20  0.183112  0.389625
# 11  0.250729   2.632660   7.611787  2293.2   2  21  0.174393  0.418691
# 12  0.228454   2.512993   6.935533  2516.8   2  22  0.166466  0.445114
# 13  0.209020   2.403733   6.345554  2750.8   2  23  0.159228  0.469240
# 14  0.191965   1.535718   5.827775  2995.2   3  24  0.152594  0.491355
# 15  0.176915   1.474289   5.370877  3250.0   3  25  0.146490  0.511700
# 16  0.163568   1.417586   4.965678  3515.2   3  26  0.140856  0.530481
# 17  0.151676   1.365083   4.604661  3790.8   3  27  0.135639  0.547871
# 18  0.141035   1.316330   4.281630  4076.8   3  28  0.130795  0.564018
# 19  0.131476   1.270939   3.991437  4373.2   3  29  0.126284  0.579052
#
#     loss_factor
# 0      0.081165
# 1      0.063957
# 2      0.051454
# 3      0.042122
# 4      0.034998
# 5      0.029454
# 6      0.025065
# 7      0.021540
# 8      0.018672
# 9      0.016311
# 10     0.014348
# 11     0.012701
# 12     0.011306
# 13     0.010117
# 14     0.009096
# 15     0.008213
# 16     0.007446
# 17     0.006776
# 18     0.006187
# 19     0.005667

# %%
Vin = 400
D = 0.62
N = 8
Ae = 78.5e-6  # mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf
f= 132e3
Bs = 0.3
B = Vin *D/(N*Ae*f)
AL = 5200 # nH








Vout = 12
Vin = 300
Np = 8
Ns = 1
Vd =0.7

D_ = (Vout+Vd) / Vin 
rate = Np/Ns 
D = (D_*rate) /(1+D_*rate)
print(D)

f= 132e3
T= 1/f
Ton = D*T



#print(f"{'N':<4} {'Bpeak (T)':<10} {'Margin':<10} {'Est. Loss Factor'}")
#print("-" * 45)
arr = []
for N in range(10, 30): # Extended range
    flux = (Vin * Ton / 2) / N
    Bpeak = flux / Ae
    Margin = (Bs - Bpeak) / Bs
    Np = N
    Ns = N//8
    D_ = (Vout+Vd) / Vin 
    rate = Np/Ns 
    D = (D_*rate) /(1+D_*rate)
    

    
    #print(f"{Ns:} {N:<4} {Bpeak:.3f}      {Margin:.3f}      {loss_factor:.3f}")
    Lm= AL *Np**2*1e-3
    # v = L di/dt
    Ippeak= 1e6*(Vin/Lm)*Ton
    Ispeak= Ippeak * Np/Ns

    
    E_cycle = (Ippeak*Vin)*Ton/2 # 2 because triangle 
    Pp = E_cycle *f
    Effec= 0.8
    Ps= Pp*Effec
    arr.append({"Np":Np ,"Ns":Ns, "Ip_peak": Ippeak, "Ispeak" : Ispeak, "Ps": Ps, "Lm":Lm,  "Bpeak":Bpeak, "Margin":Margin, "D":D})
import pandas as pd
df= pd.DataFrame(arr)
df=df[df.Margin >=0.15]
print(df.to_markdown())
# Out:
# 0.25298804780876494
# |    |   Np |   Ns |   Ip_peak |   Ispeak |       Ps |     Lm |    Bpeak |   Margin |        D |
# |---:|-----:|-----:|----------:|---------:|---------:|-------:|---------:|---------:|---------:|
# |  5 |   15 |    1 |  0.49143  |  7.37145 | 14.9191  | 1170   | 0.24415  | 0.186167 | 0.388379 |
# |  6 |   16 |    2 |  0.431921 |  3.45537 | 13.1125  | 1331.2 | 0.22889  | 0.237032 | 0.252988 |
# |  7 |   17 |    2 |  0.382601 |  3.25211 | 11.6152  | 1502.8 | 0.215426 | 0.281912 | 0.264616 |
# |  8 |   18 |    2 |  0.341271 |  3.07144 | 10.3605  | 1684.8 | 0.203458 | 0.321806 | 0.275887 |
# |  9 |   19 |    2 |  0.306293 |  2.90978 |  9.29861 | 1877.2 | 0.19275  | 0.3575   | 0.286818 |
# | 10 |   20 |    2 |  0.276429 |  2.76429 |  8.392   | 2080   | 0.183112 | 0.389625 | 0.297424 |
# | 11 |   21 |    2 |  0.250729 |  2.63266 |  7.61179 | 2293.2 | 0.174393 | 0.418691 | 0.307719 |
# | 12 |   22 |    2 |  0.228454 |  2.51299 |  6.93553 | 2516.8 | 0.166466 | 0.445114 | 0.317717 |
# | 13 |   23 |    2 |  0.20902  |  2.40373 |  6.34555 | 2750.8 | 0.159228 | 0.46924  | 0.32743  |
# | 14 |   24 |    3 |  0.191965 |  1.53572 |  5.82777 | 2995.2 | 0.152594 | 0.491355 | 0.252988 |
# | 15 |   25 |    3 |  0.176915 |  1.47429 |  5.37088 | 3250   | 0.14649  | 0.5117   | 0.26078  |
# | 16 |   26 |    3 |  0.163568 |  1.41759 |  4.96568 | 3515.2 | 0.140856 | 0.530481 | 0.268412 |
# | 17 |   27 |    3 |  0.151676 |  1.36508 |  4.60466 | 3790.8 | 0.135639 | 0.547871 | 0.275887 |
# | 18 |   28 |    3 |  0.141035 |  1.31633 |  4.28163 | 4076.8 | 0.130795 | 0.564018 | 0.283211 |
# | 19 |   29 |    3 |  0.131476 |  1.27094 |  3.99144 | 4373.2 | 0.126284 | 0.579052 | 0.290389 |

# %% [markdown]
# # ELP 22/6/16 with I 22/2.5/16 N87 with air gap

# %%
import pandas as pd
import numpy as np

# --- Input Parameters ---
Vin = 400           # Input Voltage (V)
Vout = 12           # Output Voltage (V)
Vd = 0.7            # Diode Forward Drop (V)
f = 132e3           # Switching Frequency (Hz)
Bs = 0.3            # Saturation Flux Density (T)
Ae = 78.5e-6        # Effective Cross Section Area (m^2)
le = 26.1e-3        # Magnetic Path Length (m) for ELP 22/6/16
ui = 1360           # Initial Permeability (N87 material)
u0 = 4 * np.pi * 1e-7 # Permeability of Free Space


# mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf

# Target AL for a gapped core (nH/N^2)
# We choose a lower AL to prevent saturation
#AL_target = 250 


# --- 1. Add these variables at the top ---
lg_target = 0.0002  # 0.2 mm in meters
# Calculate AL based on the physical gap
AL_target = (u0 * Ae / (lg_target + (le / ui))) * 1e9  # Result in nH

T = 1 / f
arr = []

for Np in range(20, 51, 2):  # Primary turns
    for Ns in [3, 4, 5, 8]:     # Secondary turns
        # 1. Recalculate Duty Cycle (D) based on Turns Ratio
        n = Np / Ns
        Vro = n * (Vout + Vd)
        D = Vro / (Vin + Vro)
        
        if D > 0.5: continue # Standard Flyback limit
        
        Ton = D * T
        
        # 2. Correct Bpeak calculation (No division by 2 for Flyback)
        Bpeak = (Vin * Ton) / (Np * Ae)
        
        # 3. Magnetizing Inductance (Lm)
        Lm = AL_target * (Np**2) * 1e-9 # convert nH to Henrys
        
        # 4. Peak Currents
        Ippeak = (Vin * Ton) / Lm
        Ispeak = Ippeak * n
        
        # 5. Air Gap Calculation (lg)
        # Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
        lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)
        
        # 6. Output Power (DCM assumption)
        Effec = 0.8
        Ps = 0.5 * Lm * (Ippeak**2) * f * Effec
        
        Margin = (Bs - Bpeak) / Bs
        
        if Margin >= 0.15: # Only keep designs with 15% flux margin
            arr.append({
                "Np": Np, "Ns": Ns, "D": round(D, 3), 
                "Bpeak": round(Bpeak, 3), "Lm_uH": round(Lm*1e6, 1),
                "Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                "Gap_mm": round(lg * 1000, 3) , # convert to mm
                "Margin": Margin
            })

df = pd.DataFrame(arr).sort_values('Bpeak')
print(df.to_string(index=False))
# Out:
#  Np  Ns     D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin
#  50   8 0.166  0.128 1125.1     0.45  11.8     0.2 0.573878
#  48   8 0.160  0.129 1036.9     0.47  12.0     0.2 0.571037
#  46   8 0.154  0.130  952.3     0.49  12.1     0.2 0.568158
#  44   8 0.149  0.130  871.3     0.52  12.3     0.2 0.565240
#  42   8 0.143  0.131  793.9     0.55  12.5     0.2 0.562282
#  40   8 0.137  0.132  720.1     0.58  12.6     0.2 0.559284
#  38   8 0.131  0.133  649.9     0.61  12.8     0.2 0.556244
#  36   8 0.125  0.134  583.3     0.65  13.0     0.2 0.553162
#  34   8 0.119  0.135  520.3     0.69  13.2     0.2 0.550037
#  32   8 0.113  0.136  460.8     0.74  13.4     0.2 0.546868
#  30   8 0.106  0.137  405.0     0.80  13.6     0.2 0.543654
#  28   8 0.100  0.138  352.8     0.86  13.7     0.2 0.540394
#  26   8 0.094  0.139  304.2     0.93  13.9     0.2 0.537087
#  24   8 0.087  0.140  259.2     1.02  14.1     0.2 0.533732
#  22   8 0.080  0.141  217.8     1.12  14.4     0.2 0.530328
#  20   8 0.074  0.142  180.0     1.24  14.6     0.2 0.526874
#  50   5 0.241  0.186 1125.1     0.65  25.0     0.2 0.379819
#  48   5 0.234  0.188 1036.9     0.68  25.5     0.2 0.373783
#  46   5 0.226  0.190  952.3     0.72  26.0     0.2 0.367628
#  44   5 0.218  0.192  871.3     0.76  26.5     0.2 0.361351
#  42   5 0.211  0.194  793.9     0.80  27.1     0.2 0.354947
#  40   5 0.203  0.195  720.1     0.85  27.6     0.2 0.348415
#  38   5 0.194  0.197  649.9     0.91  28.2     0.2 0.341748
#  36   5 0.186  0.200  583.3     0.97  28.8     0.2 0.334944
#  34   5 0.178  0.202  520.3     1.03  29.4     0.2 0.327997
#  32   5 0.169  0.204  460.8     1.11  30.0     0.2 0.320904
#  30   5 0.160  0.206  405.0     1.20  30.7     0.2 0.313660
#  28   5 0.151  0.208  352.8     1.30  31.3     0.2 0.306259
#  26   5 0.142  0.210  304.2     1.41  32.0     0.2 0.298697
#  24   5 0.132  0.213  259.2     1.55  32.7     0.2 0.290968
#  22   5 0.123  0.215  217.8     1.71  33.4     0.2 0.283067
#  20   5 0.113  0.218  180.0     1.90  34.2     0.2 0.274988
#  50   4 0.284  0.219 1125.1     0.77  34.8     0.2 0.268825
#  48   4 0.276  0.222 1036.9     0.81  35.6     0.2 0.260420
#  46   4 0.267  0.224  952.3     0.85  36.4     0.2 0.251819
#  44   4 0.259  0.227  871.3     0.90  37.3     0.2 0.243016
#  42   4 0.250  0.230  793.9     0.95  38.2     0.2 0.234004
#  40   4 0.241  0.233  720.1     1.01  39.1     0.2 0.224774
#  38   4 0.232  0.235  649.9     1.08  40.1     0.2 0.215319
#  36   4 0.222  0.238  583.3     1.15  41.1     0.2 0.205631
#  34   4 0.213  0.241  520.3     1.24  42.1     0.2 0.195700
#  32   4 0.203  0.244  460.8     1.33  43.2     0.2 0.185518
#  30   4 0.192  0.247  405.0     1.44  44.3     0.2 0.175075
#  28   4 0.182  0.251  352.8     1.56  45.4     0.2 0.164361
#  26   4 0.171  0.254  304.2     1.70  46.6     0.2 0.153364

# %% [raw]
# Np​:Ns​,Duty Cycle (D),Power (Ps​),Bpeak​,Why choose it?
# 32 : 8,0.113,13.4 W,0.136 T,"Extremely cool core, low output power."
# 32 : 4,0.203,54.0 W,0.204 T,Better balance; higher power capacity.
# 32 : 3,0.252,89.1 W,0.237 T,Maximum power; duty cycle is more efficient.

# %% [raw]
# 32:4 a good balance

# %%
df[(df.Np==32) & (df.Ns==5)]
# Out:
#     Np  Ns      D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm    Margin
# 16  32   5  0.169  0.204  460.8     1.11  30.0     0.2  0.320904

# %%
df[(df.Np==32) & (df.Ns==4)]
# Out:
#     Np  Ns      D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm    Margin
# 15  32   4  0.203  0.244  460.8     1.33  43.2     0.2  0.185518

# %%
import pandas as pd
import numpy as np

# --- Input Parameters ---
Vin = 400           # Input Voltage (V)
Vout = 12           # Output Voltage (V)
Vd = 0.7            # Diode Forward Drop (V)
f = 132e3           # Switching Frequency (Hz)
Bs = 0.3            # Saturation Flux Density (T)
Ae = 78.5e-6        # Effective Cross Section Area (m^2)
le = 26.1e-3        # Magnetic Path Length (m) for ELP 22/6/16
ui = 1360           # Initial Permeability (N87 material)
u0 = 4 * np.pi * 1e-7 # Permeability of Free Space


# mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf

# Target AL for a gapped core (nH/N^2)
# We choose a lower AL to prevent saturation
#AL_target = 250 


# --- 1. Add these variables at the top ---
lg_target = 0.0002  # 0.2 mm in meters
lg_target =lg_target*2
# Calculate AL based on the physical gap
AL_target = (u0 * Ae / (lg_target + (le / ui))) * 1e9  # Result in nH

T = 1 / f
arr = []

for Np in range(20, 51, 2):  # Primary turns
    for Ns in [3, 4, 5, 8]:     # Secondary turns
        # 1. Recalculate Duty Cycle (D) based on Turns Ratio
        n = Np / Ns
        Vro = n * (Vout + Vd)
        D = Vro / (Vin + Vro)
        
        if D > 0.5: continue # Standard Flyback limit
        
        Ton = D * T
        
        # 2. Correct Bpeak calculation (No division by 2 for Flyback)
        Bpeak = (Vin * Ton) / (Np * Ae)
        
        # 3. Magnetizing Inductance (Lm)
        Lm = AL_target * (Np**2) * 1e-9 # convert nH to Henrys
        
        # 4. Peak Currents
        Ippeak = (Vin * Ton) / Lm
        Ispeak = Ippeak * n
        
        # 5. Air Gap Calculation (lg)
        # Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
        lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)
        
        # 6. Output Power (DCM assumption)
        Effec = 0.8
        Ps = 0.5 * Lm * (Ippeak**2) * f * Effec
        
        Margin = (Bs - Bpeak) / Bs
        
        if Margin >= 0.15: # Only keep designs with 15% flux margin
            arr.append({
                "Np": Np, "Ns": Ns, "D": round(D, 3), 
                "Bpeak": round(Bpeak, 3), "Lm_uH": round(Lm*1e6, 1),
                "Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                "Gap_mm": round(lg * 1000, 3) , # convert to mm
                "Margin": Margin
            })

df = pd.DataFrame(arr).sort_values('Bpeak')
print(df.to_string(index=False))
# Out:
#  Np  Ns     D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin
#  50   8 0.166  0.128  588.3     0.85  22.6     0.4 0.573878
#  48   8 0.160  0.129  542.2     0.89  22.9     0.4 0.571037
#  46   8 0.154  0.130  497.9     0.94  23.2     0.4 0.568158
#  44   8 0.149  0.130  455.6     0.99  23.5     0.4 0.565240
#  42   8 0.143  0.131  415.1     1.04  23.8     0.4 0.562282
#  40   8 0.137  0.132  376.5     1.10  24.2     0.4 0.559284
#  38   8 0.131  0.133  339.8     1.17  24.5     0.4 0.556244
#  36   8 0.125  0.134  305.0     1.24  24.8     0.4 0.553162
#  34   8 0.119  0.135  272.0     1.32  25.2     0.4 0.550037
#  32   8 0.113  0.136  241.0     1.42  25.6     0.4 0.546868
#  30   8 0.106  0.137  211.8     1.52  25.9     0.4 0.543654
#  28   8 0.100  0.138  184.5     1.64  26.3     0.4 0.540394
#  26   8 0.094  0.139  159.1     1.78  26.7     0.4 0.537087
#  24   8 0.087  0.140  135.5     1.94  27.1     0.4 0.533732
#  22   8 0.080  0.141  113.9     2.14  27.4     0.4 0.530328
#  20   8 0.074  0.142   94.1     2.37  27.9     0.4 0.526874
#  50   5 0.241  0.186  588.3     1.24  47.9     0.4 0.379819
#  48   5 0.234  0.188  542.2     1.31  48.8     0.4 0.373783
#  46   5 0.226  0.190  497.9     1.38  49.8     0.4 0.367628
#  44   5 0.218  0.192  455.6     1.45  50.8     0.4 0.361351
#  42   5 0.211  0.194  415.1     1.54  51.8     0.4 0.354947
#  40   5 0.203  0.195  376.5     1.63  52.8     0.4 0.348415
#  38   5 0.194  0.197  339.8     1.73  53.9     0.4 0.341748
#  36   5 0.186  0.200  305.0     1.85  55.0     0.4 0.334944
#  34   5 0.178  0.202  272.0     1.98  56.2     0.4 0.327997
#  32   5 0.169  0.204  241.0     2.12  57.4     0.4 0.320904
#  30   5 0.160  0.206  211.8     2.29  58.6     0.4 0.313660
#  28   5 0.151  0.208  184.5     2.48  59.9     0.4 0.306259
#  26   5 0.142  0.210  159.1     2.70  61.2     0.4 0.298697
#  24   5 0.132  0.213  135.5     2.96  62.6     0.4 0.290968
#  22   5 0.123  0.215  113.9     3.26  64.0     0.4 0.283067
#  20   5 0.113  0.218   94.1     3.63  65.4     0.4 0.274988
#  50   4 0.284  0.219  588.3     1.46  66.5     0.4 0.268825
#  48   4 0.276  0.222  542.2     1.54  68.1     0.4 0.260420
#  46   4 0.267  0.224  497.9     1.63  69.7     0.4 0.251819
#  44   4 0.259  0.227  455.6     1.72  71.3     0.4 0.243016
#  42   4 0.250  0.230  415.1     1.83  73.0     0.4 0.234004
#  40   4 0.241  0.233  376.5     1.94  74.8     0.4 0.224774
#  38   4 0.232  0.235  339.8     2.07  76.6     0.4 0.215319
#  36   4 0.222  0.238  305.0     2.21  78.5     0.4 0.205631
#  34   4 0.213  0.241  272.0     2.37  80.5     0.4 0.195700
#  32   4 0.203  0.244  241.0     2.55  82.5     0.4 0.185518
#  30   4 0.192  0.247  211.8     2.75  84.7     0.4 0.175075
#  28   4 0.182  0.251  184.5     2.99  86.9     0.4 0.164361
#  26   4 0.171  0.254  159.1     3.26  89.2     0.4 0.153364

# %%
df[(df.Np==32) & (df.Ns==5)]
# Out:
#     Np  Ns      D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm    Margin
# 16  32   5  0.169  0.204  241.0     2.12  57.4     0.4  0.320904

# %% [raw]
# TNY266PN 15W
# https://www.farnell.com/datasheets/98510.pdf
# F = 132Hz +/-8Hz
# Dmax = 62/68%
# Ilim = 325 350 375 mA (min type max)
# 700V break down
# Auto-Restart Duty Cycle 5.6%

# %%
import pandas as pd
import numpy as np

# --- Input Parameters ---
Vin = 400           # Input Voltage (V)
Vout = 12           # Output Voltage (V)
Vd = 0.7            # Diode Forward Drop (V)
f = 132e3           # Switching Frequency (Hz)
Bs = 0.3            # Saturation Flux Density (T)
Ae = 78.5e-6        # Effective Cross Section Area (m^2)
le = 26.1e-3        # Magnetic Path Length (m) for ELP 22/6/16
ui = 1360           # Initial Permeability (N87 material)
u0 = 4 * np.pi * 1e-7 # Permeability of Free Space


# mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf

# Target AL for a gapped core (nH/N^2)
# We choose a lower AL to prevent saturation
AL_target = 5200


# --- 1. Add these variables at the top ---

lg = 0# 0.10e-3  # Total gap 2 * 0.05 mm
lg_target = lg  
# Calculate AL based on the physical gap
AL_target = (u0 * Ae / (lg_target + (le / ui))) * 1e9  # Result in nH

T = 1 / f
arr = []

for Np in range(10, 51, 2):  # Primary turns
    for Ns in range(2, 8):     # Secondary turns
        # 1. Recalculate Duty Cycle (D) based on Turns Ratio
        n = Np / Ns
        Vro = n * (Vout + Vd)
        D = Vro / (Vin + Vro)
        
        if D > 0.5: continue # Standard Flyback limit
        
        Ton = D * T
        
        # 2. Correct Bpeak calculation (No division by 2 for Flyback)
        Bpeak = (Vin * Ton) / (Np * Ae)
        
        # 3. Magnetizing Inductance (Lm)
        Lm = AL_target * (Np**2) * 1e-9 # convert nH to Henrys
        
        # 4. Peak Currents
        Ippeak = (Vin * Ton) / Lm
        Ispeak = Ippeak * n
        
        # 5. Air Gap Calculation (lg)
        # Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
        lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)
        
        # 6. Output Power (DCM assumption)
        Effec = 0.8
        Ps = 0.5 * Lm * (Ippeak**2) * f * Effec
        
        Margin = (Bs - Bpeak) / Bs
        
        if Margin >= 0.15: # Only keep designs with 15% flux margin
            arr.append({
                "Np": Np, "Ns": Ns, "D": round(D, 3), 
                "Bpeak": round(Bpeak, 3), "Lm_uH": round(Lm*1e6, 1),
                "Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                "Gap_mm": round(lg * 1000, 3) , # convert to mm
                "Margin": Margin
            })

df = pd.DataFrame(arr).sort_values('Bpeak')

m =df.Margin>0
df= df[m]
print(df.to_string(index=False))
# Out:
#  Np  Ns     D  Bpeak   Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin
#  50   7 0.185  0.143 12850.4     0.04   1.3    -0.0 0.524257
#  48   7 0.179  0.144 11843.0     0.05   1.3    -0.0 0.520713
#  46   7 0.173  0.145 10876.6     0.05   1.3     0.0 0.517116
#  44   7 0.166  0.146  9951.4     0.05   1.3    -0.0 0.513464
#  42   7 0.160  0.147  9067.3     0.05   1.4    -0.0 0.509757
#  40   7 0.154  0.148  8224.3     0.06   1.4     0.0 0.505993
#  38   7 0.147  0.149  7422.4     0.06   1.4     0.0 0.502170
#  36   7 0.140  0.151  6661.7     0.06   1.4     0.0 0.498288
#  34   7 0.134  0.152  5942.0     0.07   1.5    -0.0 0.494345
#  32   7 0.127  0.153  5263.5     0.07   1.5    -0.0 0.490339
#  30   7 0.120  0.154  4626.2     0.08   1.5    -0.0 0.486270
#  28   7 0.113  0.155  4029.9     0.08   1.5    -0.0 0.482135
#  26   7 0.105  0.157  3474.8     0.09   1.6    -0.0 0.477932
#  24   7 0.098  0.158  2960.7     0.10   1.6    -0.0 0.473661
#  22   7 0.091  0.159  2487.8     0.11   1.6    -0.0 0.469320
#  20   7 0.083  0.161  2056.1     0.12   1.6     0.0 0.464906
#  50   6 0.209  0.162 12850.4     0.05   1.7    -0.0 0.461556
#  18   7 0.075  0.162  1665.4     0.14   1.7     0.0 0.460419
#  16   7 0.068  0.163  1315.9     0.16   1.7    -0.0 0.455855
#  48   6 0.203  0.163 11843.0     0.05   1.7    -0.0 0.457012
#  46   6 0.196  0.164 10876.6     0.05   1.7     0.0 0.452391
#  14   7 0.060  0.165  1007.5     0.18   1.7    -0.0 0.451214
#  12   7 0.052  0.166   740.2     0.21   1.7    -0.0 0.446492
#  44   6 0.189  0.166  9951.4     0.06   1.7    -0.0 0.447690
#  42   6 0.182  0.167  9067.3     0.06   1.8    -0.0 0.442907
#  10   7 0.043  0.167   514.0     0.26   1.8     0.0 0.441689
#  40   6 0.175  0.169  8224.3     0.06   1.8     0.0 0.438041
#  38   6 0.167  0.170  7422.4     0.07   1.8     0.0 0.433090
#  36   6 0.160  0.172  6661.7     0.07   1.9     0.0 0.428050
#  34   6 0.152  0.173  5942.0     0.08   1.9    -0.0 0.422920
#  32   6 0.145  0.175  5263.5     0.08   1.9    -0.0 0.417697
#  30   6 0.137  0.176  4626.2     0.09   2.0    -0.0 0.412378
#  28   6 0.129  0.178  4029.9     0.10   2.0    -0.0 0.406962
#  26   6 0.121  0.180  3474.8     0.11   2.0    -0.0 0.401445
#  24   6 0.113  0.181  2960.7     0.12   2.1    -0.0 0.395824
#  22   6 0.104  0.183  2487.8     0.13   2.1    -0.0 0.390096
#  20   6 0.096  0.185  2056.1     0.14   2.2     0.0 0.384259
#  50   5 0.241  0.186 12850.4     0.06   2.2    -0.0 0.379819
#  18   6 0.087  0.187  1665.4     0.16   2.2     0.0 0.378309
#  16   6 0.078  0.188  1315.9     0.18   2.2    -0.0 0.372243
#  48   5 0.234  0.188 11843.0     0.06   2.2    -0.0 0.373783
#  14   6 0.069  0.190  1007.5     0.21   2.3    -0.0 0.366058
#  46   5 0.226  0.190 10876.6     0.06   2.3     0.0 0.367628
#  44   5 0.218  0.192  9951.4     0.07   2.3    -0.0 0.361351
#  12   6 0.060  0.192   740.2     0.24   2.3    -0.0 0.359749
#  10   6 0.050  0.194   514.0     0.30   2.4     0.0 0.353314
#  42   5 0.211  0.194  9067.3     0.07   2.4    -0.0 0.354947
#  40   5 0.203  0.195  8224.3     0.07   2.4     0.0 0.348415
#  38   5 0.194  0.197  7422.4     0.08   2.5     0.0 0.341748
#  36   5 0.186  0.200  6661.7     0.08   2.5     0.0 0.334944
#  34   5 0.178  0.202  5942.0     0.09   2.6    -0.0 0.327997
#  32   5 0.169  0.204  5263.5     0.10   2.6    -0.0 0.320904
#  30   5 0.160  0.206  4626.2     0.10   2.7    -0.0 0.313660
#  28   5 0.151  0.208  4029.9     0.11   2.7    -0.0 0.306259
#  26   5 0.142  0.210  3474.8     0.12   2.8    -0.0 0.298697
#  24   5 0.132  0.213  2960.7     0.14   2.9    -0.0 0.290968
#  22   5 0.123  0.215  2487.8     0.15   2.9    -0.0 0.283067
#  20   5 0.113  0.218  2056.1     0.17   3.0     0.0 0.274988
#  50   4 0.284  0.219 12850.4     0.07   3.0    -0.0 0.268825
#  18   5 0.103  0.220  1665.4     0.19   3.1     0.0 0.266725
#  48   4 0.276  0.222 11843.0     0.07   3.1    -0.0 0.260420
#  16   5 0.092  0.223  1315.9     0.21   3.1    -0.0 0.258272
#  46   4 0.267  0.224 10876.6     0.07   3.2     0.0 0.251819
#  14   5 0.082  0.225  1007.5     0.25   3.2    -0.0 0.249621
#  44   4 0.259  0.227  9951.4     0.08   3.3    -0.0 0.243016
#  12   5 0.071  0.228   740.2     0.29   3.3    -0.0 0.240766
#  42   4 0.250  0.230  9067.3     0.08   3.3    -0.0 0.234004
#  10   5 0.060  0.230   514.0     0.35   3.4     0.0 0.231699
#  40   4 0.241  0.233  8224.3     0.09   3.4     0.0 0.224774
#  38   4 0.232  0.235  7422.4     0.09   3.5     0.0 0.215319
#  36   4 0.222  0.238  6661.7     0.10   3.6     0.0 0.205631
#  34   4 0.213  0.241  5942.0     0.11   3.7    -0.0 0.195700
#  32   4 0.203  0.244  5263.5     0.12   3.8    -0.0 0.185518
#  30   4 0.192  0.247  4626.2     0.13   3.9    -0.0 0.175075
#  28   4 0.182  0.251  4029.9     0.14   4.0    -0.0 0.164361
#  26   4 0.171  0.254  3474.8     0.15   4.1    -0.0 0.153364

# %%
m1 =df.Ps_W>=4
m2 =df.Ip_peak<=0.300
m= m1 & m2
df2= df[m]
df2
# Out:
#     Np  Ns      D  Bpeak   Lm_uH  Ip_peak  Ps_W  Gap_mm    Margin
# 28  28   4  0.182  0.251  4029.9     0.14   4.0    -0.0  0.164361
# 24  26   4  0.171  0.254  3474.8     0.15   4.1    -0.0  0.153364

# %%
pd.DataFrame(arr).sort_values('Ip_peak')
# Out:
#     Np  Ns      D  Bpeak    Lm_uH  Ip_peak  Ps_W  Gap_mm    Margin
# 75  50   7  0.185  0.143  12850.4     0.04   1.3    -0.0  0.524257
# 63  44   7  0.166  0.146   9951.4     0.05   1.3    -0.0  0.513464
# 71  48   7  0.179  0.144  11843.0     0.05   1.3    -0.0  0.520713
# 59  42   7  0.160  0.147   9067.3     0.05   1.4    -0.0  0.509757
# 66  46   6  0.196  0.164  10876.6     0.05   1.7     0.0  0.452391
# ..  ..  ..    ...    ...      ...      ...   ...     ...       ...
# 6   14   5  0.082  0.225   1007.5     0.25   3.2    -0.0  0.249621
# 2   10   7  0.043  0.167    514.0     0.26   1.8     0.0  0.441689
# 3   12   5  0.071  0.228    740.2     0.29   3.3    -0.0  0.240766
# 1   10   6  0.050  0.194    514.0     0.30   2.4     0.0  0.353314
# 0   10   5  0.060  0.230    514.0     0.35   3.4     0.0  0.231699
#
# [76 rows x 9 columns]

# %%
import pandas as pd
import numpy as np

# --- Input Parameters ---
Vin = 400           # Input Voltage (V)
Vout = 12           # Output Voltage (V)
Vd = 0.7            # Diode Forward Drop (V)
f = 132e3           # Switching Frequency (Hz)
Bs = 0.3            # Saturation Flux Density (T)
Ae = 78.5e-6        # Effective Cross Section Area (m^2)
le = 26.1e-3        # Magnetic Path Length (m) for ELP 22/6/16
ui = 1360           # Initial Permeability (N87 material)
u0 = 4 * np.pi * 1e-7 # Permeability of Free Space


# mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf

# Target AL for a gapped core (nH/N^2)
# We choose a lower AL to prevent saturation
#AL_target = 250 


# --- 1. Add these variables at the top ---

lg = 0  # Total gap 2 * 0.05 mm
lg_target = lg  
# Calculate AL based on the physical gap
AL_target = (u0 * Ae / (lg_target + (le / ui))) * 1e9  # Result in nH

T = 1 / f
arr = []

for Np in range(10, 51, 2):  # Primary turns
    for Ns in range(2, 8):     # Secondary turns
        # 1. Recalculate Duty Cycle (D) based on Turns Ratio
        n = Np / Ns
        Vro = n * (Vout + Vd)
        D = Vro / (Vin + Vro)
        
        if D > 0.5: continue # Standard Flyback limit
        
        Ton = D * T
        
        # 2. Correct Bpeak calculation (No division by 2 for Flyback)
        Bpeak = (Vin * Ton) / (Np * Ae)
        
        # 3. Magnetizing Inductance (Lm)
        Lm = AL_target * (Np**2) * 1e-9 # convert nH to Henrys
        
        # 4. Peak Currents
        Ippeak = (Vin * Ton) / Lm
        Ispeak = Ippeak * n
        
        # 5. Air Gap Calculation (lg)
        # Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
        #lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)
        
        # 6. Output Power (DCM assumption)
        Effec = 0.8
        Ps = 0.5 * Lm * (Ippeak**2) * f * Effec
        
        Margin = (Bs - Bpeak) / Bs

        flux = Bs*Ae
        # L*i = N*flux 
        I_sat = flux*Np/Lm

        
        if Margin >= 0.15: # Only keep designs with 15% flux margin
            arr.append({
                "Np": Np, "Ns": Ns, "D": round(D, 3), 
                "Bpeak": round(Bpeak, 3), "Lm_uH": round(Lm*1e6, 1),
                "Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
                "Gap_mm": round(lg * 1000, 3) , # convert to mm
                "Margin": Margin, 
                "I_sat": I_sat
            })

df = pd.DataFrame(arr).sort_values('Bpeak')

m =df.Margin>0
df= df[m]
print(df.to_string(index=False))
# Out:
#  Np  Ns     D  Bpeak   Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin    I_sat
#  50   7 0.185  0.143 12850.4     0.04   1.3       0 0.524257 0.091631
#  48   7 0.179  0.144 11843.0     0.05   1.3       0 0.520713 0.095449
#  46   7 0.173  0.145 10876.6     0.05   1.3       0 0.517116 0.099599
#  44   7 0.166  0.146  9951.4     0.05   1.3       0 0.513464 0.104126
#  42   7 0.160  0.147  9067.3     0.05   1.4       0 0.509757 0.109085
#  40   7 0.154  0.148  8224.3     0.06   1.4       0 0.505993 0.114539
#  38   7 0.147  0.149  7422.4     0.06   1.4       0 0.502170 0.120567
#  36   7 0.140  0.151  6661.7     0.06   1.4       0 0.498288 0.127265
#  34   7 0.134  0.152  5942.0     0.07   1.5       0 0.494345 0.134752
#  32   7 0.127  0.153  5263.5     0.07   1.5       0 0.490339 0.143174
#  30   7 0.120  0.154  4626.2     0.08   1.5       0 0.486270 0.152719
#  28   7 0.113  0.155  4029.9     0.08   1.5       0 0.482135 0.163627
#  26   7 0.105  0.157  3474.8     0.09   1.6       0 0.477932 0.176214
#  24   7 0.098  0.158  2960.7     0.10   1.6       0 0.473661 0.190898
#  22   7 0.091  0.159  2487.8     0.11   1.6       0 0.469320 0.208253
#  20   7 0.083  0.161  2056.1     0.12   1.6       0 0.464906 0.229078
#  50   6 0.209  0.162 12850.4     0.05   1.7       0 0.461556 0.091631
#  18   7 0.075  0.162  1665.4     0.14   1.7       0 0.460419 0.254531
#  16   7 0.068  0.163  1315.9     0.16   1.7       0 0.455855 0.286347
#  48   6 0.203  0.163 11843.0     0.05   1.7       0 0.457012 0.095449
#  46   6 0.196  0.164 10876.6     0.05   1.7       0 0.452391 0.099599
#  14   7 0.060  0.165  1007.5     0.18   1.7       0 0.451214 0.327254
#  12   7 0.052  0.166   740.2     0.21   1.7       0 0.446492 0.381796
#  44   6 0.189  0.166  9951.4     0.06   1.7       0 0.447690 0.104126
#  42   6 0.182  0.167  9067.3     0.06   1.8       0 0.442907 0.109085
#  10   7 0.043  0.167   514.0     0.26   1.8       0 0.441689 0.458156
#  40   6 0.175  0.169  8224.3     0.06   1.8       0 0.438041 0.114539
#  38   6 0.167  0.170  7422.4     0.07   1.8       0 0.433090 0.120567
#  36   6 0.160  0.172  6661.7     0.07   1.9       0 0.428050 0.127265
#  34   6 0.152  0.173  5942.0     0.08   1.9       0 0.422920 0.134752
#  32   6 0.145  0.175  5263.5     0.08   1.9       0 0.417697 0.143174
#  30   6 0.137  0.176  4626.2     0.09   2.0       0 0.412378 0.152719
#  28   6 0.129  0.178  4029.9     0.10   2.0       0 0.406962 0.163627
#  26   6 0.121  0.180  3474.8     0.11   2.0       0 0.401445 0.176214
#  24   6 0.113  0.181  2960.7     0.12   2.1       0 0.395824 0.190898
#  22   6 0.104  0.183  2487.8     0.13   2.1       0 0.390096 0.208253
#  20   6 0.096  0.185  2056.1     0.14   2.2       0 0.384259 0.229078
#  50   5 0.241  0.186 12850.4     0.06   2.2       0 0.379819 0.091631
#  18   6 0.087  0.187  1665.4     0.16   2.2       0 0.378309 0.254531
#  16   6 0.078  0.188  1315.9     0.18   2.2       0 0.372243 0.286347
#  48   5 0.234  0.188 11843.0     0.06   2.2       0 0.373783 0.095449
#  14   6 0.069  0.190  1007.5     0.21   2.3       0 0.366058 0.327254
#  46   5 0.226  0.190 10876.6     0.06   2.3       0 0.367628 0.099599
#  44   5 0.218  0.192  9951.4     0.07   2.3       0 0.361351 0.104126
#  12   6 0.060  0.192   740.2     0.24   2.3       0 0.359749 0.381796
#  10   6 0.050  0.194   514.0     0.30   2.4       0 0.353314 0.458156
#  42   5 0.211  0.194  9067.3     0.07   2.4       0 0.354947 0.109085
#  40   5 0.203  0.195  8224.3     0.07   2.4       0 0.348415 0.114539
#  38   5 0.194  0.197  7422.4     0.08   2.5       0 0.341748 0.120567
#  36   5 0.186  0.200  6661.7     0.08   2.5       0 0.334944 0.127265
#  34   5 0.178  0.202  5942.0     0.09   2.6       0 0.327997 0.134752
#  32   5 0.169  0.204  5263.5     0.10   2.6       0 0.320904 0.143174
#  30   5 0.160  0.206  4626.2     0.10   2.7       0 0.313660 0.152719
#  28   5 0.151  0.208  4029.9     0.11   2.7       0 0.306259 0.163627
#  26   5 0.142  0.210  3474.8     0.12   2.8       0 0.298697 0.176214
#  24   5 0.132  0.213  2960.7     0.14   2.9       0 0.290968 0.190898
#  22   5 0.123  0.215  2487.8     0.15   2.9       0 0.283067 0.208253
#  20   5 0.113  0.218  2056.1     0.17   3.0       0 0.274988 0.229078
#  50   4 0.284  0.219 12850.4     0.07   3.0       0 0.268825 0.091631
#  18   5 0.103  0.220  1665.4     0.19   3.1       0 0.266725 0.254531
#  48   4 0.276  0.222 11843.0     0.07   3.1       0 0.260420 0.095449
#  16   5 0.092  0.223  1315.9     0.21   3.1       0 0.258272 0.286347
#  46   4 0.267  0.224 10876.6     0.07   3.2       0 0.251819 0.099599
#  14   5 0.082  0.225  1007.5     0.25   3.2       0 0.249621 0.327254
#  44   4 0.259  0.227  9951.4     0.08   3.3       0 0.243016 0.104126
#  12   5 0.071  0.228   740.2     0.29   3.3       0 0.240766 0.381796
#  42   4 0.250  0.230  9067.3     0.08   3.3       0 0.234004 0.109085
#  10   5 0.060  0.230   514.0     0.35   3.4       0 0.231699 0.458156
#  40   4 0.241  0.233  8224.3     0.09   3.4       0 0.224774 0.114539
#  38   4 0.232  0.235  7422.4     0.09   3.5       0 0.215319 0.120567
#  36   4 0.222  0.238  6661.7     0.10   3.6       0 0.205631 0.127265
#  34   4 0.213  0.241  5942.0     0.11   3.7       0 0.195700 0.134752
#  32   4 0.203  0.244  5263.5     0.12   3.8       0 0.185518 0.143174
#  30   4 0.192  0.247  4626.2     0.13   3.9       0 0.175075 0.152719
#  28   4 0.182  0.251  4029.9     0.14   4.0       0 0.164361 0.163627
#  26   4 0.171  0.254  3474.8     0.15   4.1       0 0.153364 0.176214

# %%
m1 =df.Ps_W>=4
m2 =df.Ip_peak<=0.325
m= m1 & m2
df2= df[m]
print(df2.to_string(index=False))
# Out:
#  Np  Ns     D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin    I_sat
#  28   4 0.182  0.251 4029.9     0.14   4.0       0 0.164361 0.163627
#  26   4 0.171  0.254 3474.8     0.15   4.1       0 0.153364 0.176214

# %%
AL = 5200 # nH
Np =28
AL*Np**2/1000
# Out:
# 4076.8

# %%
import pandas as pd
import numpy as np

# --- Input Parameters ---
Vin = 340           # Input Voltage (V)
Vout = 11.35           # Output Voltage (V)
Vd = 0.7            # Diode Forward Drop (V)
f = 132e3           # Switching Frequency (Hz)
Bs = 0.3            # Saturation Flux Density (T)
Ae = 78.5e-6        # Effective Cross Section Area (m^2)
le = 26.1e-3        # Magnetic Path Length (m) for ELP 22/6/16
ui = 1360           # Initial Permeability (N87 material)
u0 = 4 * np.pi * 1e-7 # Permeability of Free Space


# mm2=>m2 ELP 22/6/16 with I 22/2.5/16 N87
# https://www.tdk-electronics.tdk.com/inf/80/db/fer/elp_22_6_16.pdf

# Target AL for a gapped core (nH/N^2)
# We choose a lower AL to prevent saturation
#AL_target = 250 


# --- 1. Add these variables at the top ---

#lg = 0  # Total gap 2 * 0.05 mm
#lg_target = lg  
# Calculate AL based on the physical gap
#AL_target = (u0 * Ae / (lg_target + (le / ui))) * 1e9  # Result in nH

T = 1 / f
arr = []

Np = 26
Ns=4
# 1. Recalculate Duty Cycle (D) based on Turns Ratio
n = Np / Ns
Vro = n * (Vout + Vd)
D = Vro / (Vin + Vro)

#if D > 0.5: continue # Standard Flyback limit

Ton = D * T

# 2. Correct Bpeak calculation (No division by 2 for Flyback)
Bpeak = (Vin * Ton) / (Np * Ae)

# 3. Magnetizing Inductance (Lm)
#Lm = AL_target * (Np**2) * 1e-9 # convert nH to Henrys
Lm=1700e-6

# 4. Peak Currents
Ippeak = (Vin * Ton) / Lm
Ispeak = Ippeak * n

# 5. Air Gap Calculation (lg)
# Formula: lg = (u0 * Np^2 * Ae / Lm) - (le / ui)
#lg = ((u0 * (Np**2) * Ae) / Lm) - (le / ui)

# 6. Output Power (DCM assumption)
Effec = 0.8
Ps = 0.5 * Lm * (Ippeak**2) * f * Effec

Margin = (Bs - Bpeak) / Bs

flux = Bs*Ae
# L*i = N*flux 
I_sat = flux*Np/Lm



AL_exp = Lm / Np**2        # H / turn^2
lg = (u0 * Ae / AL_exp) - (le / ui)   # meters
lg_um = lg * 1e6

#if Margin >= 0.15: # Only keep designs with 15% flux margin
arr.append({
    "Np": Np, "Ns": Ns, "D": round(D, 3), 
    "Bpeak": round(Bpeak, 3), "Lm_uH": round(Lm*1e6, 1),
    "Ip_peak": round(Ippeak, 2), "Ps_W": round(Ps, 1),
    "Gap_mm": round(lg * 1000, 3) , # convert to mm
    "Margin": Margin, 
    "I_sat": I_sat, 
    "lg_um":lg_um
})

df = pd.DataFrame(arr).sort_values('Bpeak')

m =df.Margin>0
df= df[m]
print(df.to_string(index=False))
arr[0]
# Out:
#  Np  Ns     D  Bpeak  Lm_uH  Ip_peak  Ps_W  Gap_mm   Margin    I_sat     lg_um
#  26   4 0.187  0.236 1700.0     0.28   7.2    0.02 0.212361 0.360176 20.035119
# {'Np': 26,
#  'Ns': 4,
#  'D': 0.187,
#  'Bpeak': 0.236,
#  'Lm_uH': 1700.0,
#  'Ip_peak': 0.28,
#  'Ps_W': 7.2,
#  'Gap_mm': 0.02,
#  'Margin': 0.2123608220713715,
#  'I_sat': 0.3601764705882353,
#  'lg_um': 20.035119001269635}

# %%
# Saturation current
I_sat = Bs * Ae * Np / Lm
print(I_sat)  # Amps
# Out:
# 0.3601764705882353
