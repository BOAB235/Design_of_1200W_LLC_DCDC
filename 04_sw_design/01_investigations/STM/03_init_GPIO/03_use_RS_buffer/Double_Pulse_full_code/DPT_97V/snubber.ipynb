# %%
from math import pi, sqrt
f= 60.4e6 # rining freq 

# f = 1/2pi sqrt(lc)
c = 43e-12
c=133e-12 # energy capa datasheet 
l= 1/((2*pi*f)**2*c)
print("loop inductance nH = ", l*1e9)
#a=input("press any keys to exit")

c = 220e-12
r = sqrt (l/c)
print("R = ", r , "ohm")

vds = 400
e = 0.5*c*vds**2
fsw=100e3 
p= fsw*e
print("r power w",p)
Q = (1/r) *sqrt (l/c)
print(Q)
# Out:
# loop inductance nH =  52.205317944158494
# R =  15.404444155703086 ohm
# r power w 1.7599999999999998
# 0.9999999999999999

# %%
c=1e-9

r = sqrt (l/c)
r
# Out:
# 7.225324763922967

# %%
from handcalcs import render

# %%
# %%render
# I = 15
# C_all = 200e-12+220e-12 # mosfet capa must be larger in 100V
# L = 20e-9 # probabely L is lower that 50n
# E = 0.5*L*I**2
# delta_V = sqrt(2*E/C_all) # V
# Out:
# \[
# \begin{aligned}
# I &= 15 \;
# \\[10pt]
# C_{all} &= 200 \times 10 ^ {-12} + 220 \times 10 ^ {-12} &= 0.000 \; \;\textrm{(mosfet capa must be larger in 100V)}
# \\[10pt]
# L &= 0.000 \; \;\textrm{(probabely L is lower that 50n)}
# \\[10pt]
# E &= 0.5 \cdot L \cdot \left( I \right) ^{ 2 }  = 0.5 \cdot 0.000 \cdot \left( 15 \right) ^{ 2 } &= 0.000
# \\[10pt]
# \delta_{V} &= \sqrt { 2 \cdot \frac{ E }{ C_{all} } }  = \sqrt { 2 \cdot \frac{ 0.000 }{ 0.000 } } &= 103.510 \; \;\textrm{(V)}
# \end{aligned}
# \]

# %%
# %%render
# L_loop = 52e-9
# I = 15
# E = (1/2)*L_loop*I**2
# DV_target = 25
# #E= 1/2 *V**2*C
# C = E/(0.5*DV_target**2)
# Cn= 1e9*C # nF
# #
# fsw= 100e3
# To = 0.3/fsw # discharge in 30% of periode
# R = To /C
# Pr = fsw*E
# Out:
# \[
# \begin{aligned}
# L_{loop} &= 0.000 \;
# \\[10pt]
# I &= 15 \;
# \\[10pt]
# E &= \left( \frac{ 1 }{ 2 } \right) \cdot L_{loop} \cdot \left( I \right) ^{ 2 }  = \left( \frac{ 1 }{ 2 } \right) \cdot 0.000 \cdot \left( 15 \right) ^{ 2 } &= 0.000
# \\[10pt]
# \mathrm{DV}_{target} &= 25 \;
# \\[10pt]
# C &= \frac{ E }{ 0.5 \cdot \left( \mathrm{DV}_{target} \right) ^{ 2 } }  = \frac{ 0.000 }{ 0.5 \cdot \left( 25 \right) ^{ 2 } } &= 0.000
# \\[10pt]
# \mathrm{Cn} &= 1 \times 10 ^ {9} \cdot C  = 1 \times 10 ^ {9} \cdot 0.000 &= 18.720 \; \;\textrm{(nF)}
# \\[10pt]
# \mathrm{fsw} &= 100000.000 \;
# \\[10pt]
# \mathrm{To} &= \frac{ 0.3 }{ \mathrm{fsw} }  = \frac{ 0.3 }{ 100000.000 } &= 0.000 \; \;\textrm{(discharge in 30% of periode)}
# \\[10pt]
# R &= \frac{ \mathrm{To} }{ C }  = \frac{ 0.000 }{ 0.000 } &= 160.256
# \\[10pt]
# \mathrm{Pr} &= \mathrm{fsw} \cdot E  = 100000.000 \cdot 0.000 &= 0.585
# \end{aligned}
# \]
